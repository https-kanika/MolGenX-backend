# %%
from rdkit import Chem
import numpy as np
import pandas as pd
import os
import time

def preprocess_smiles(smiles_list, canonical=True, show_progress=True):
    """
    Process a list of SMILES strings and return valid ones
    
    Args:
        smiles_list: List of SMILES strings to process
        canonical: Whether to convert to canonical SMILES
        show_progress: Whether to show progress updates
    
    Returns:
        List of valid SMILES strings
    """
    clean_smiles = []
    invalid_count = 0
    total = len(smiles_list)
    
    start_time = time.time()
    
    if show_progress:
        print(f"Processing {total} SMILES strings...")
    
    batch_size = 5000
    for i in range(0, total, batch_size):
        batch = smiles_list[i:i+batch_size]
        
        for smi in batch:
            mol = Chem.MolFromSmiles(smi)
            if mol:
                if canonical:
                    clean_smiles.append(Chem.MolToSmiles(mol, canonical=True))
                else:
                    clean_smiles.append(smi)
            else:
                invalid_count += 1
        
        if show_progress and i > 0:
            progress = min(i + batch_size, total) / total * 100
            elapsed = time.time() - start_time
            est_total = elapsed / progress * 100
            remaining = est_total - elapsed
            
            print(f"Progress: {progress:.1f}% ({i+batch_size}/{total}) | "
                  f"Valid: {len(clean_smiles)} | Invalid: {invalid_count} | "
                  f"Time remaining: {remaining:.1f}s")
    
    if show_progress:
        print(f"Completed in {time.time() - start_time:.1f}s")
        print(f"Total SMILES: {total}")
        print(f"Valid SMILES: {len(clean_smiles)} ({len(clean_smiles)/total*100:.1f}%)")
        print(f"Invalid SMILES: {invalid_count} ({invalid_count/total*100:.1f}%)")
    
    return clean_smiles

def process_smi_file(file_path, output_path=None):
    """Process a .smi file and save valid SMILES"""
    with open(file_path, 'r') as f:
        smiles_list = [line.strip() for line in f if line.strip() and not line.startswith('//')]
    
    print(f"Loaded {len(smiles_list)} SMILES from {file_path}")
    clean_smiles = preprocess_smiles(smiles_list)

    if output_path is None:
        base_name, ext = os.path.splitext(file_path)
        output_path = f"{base_name}_cleaned{ext}"
    
    with open(output_path, 'w') as f:
        for smi in clean_smiles:
            f.write(f"{smi}\n")
    
    print(f"Saved {len(clean_smiles)} valid SMILES to {output_path}")
    return clean_smiles

process_smi_file('./data/chembl.raw.smi')
# Out:
# Loaded 888657 SMILES from ./data/chembl.raw.smi
# Processing 888657 SMILES strings...
# [17:21:48] SMILES Parse Error: extra close parentheses while parsing: N3C2C(=O)[O-])cc(CCC(=O)O)[n+]1CCc1cccs1
# [17:21:48] SMILES Parse Error: check for mistakes around position 14:
# [17:21:48] N3C2C(=O)[O-])cc(CCC(=O)O)[n+]1CCc1cccs1
# [17:21:48] ~~~~~~~~~~~~~^
# [17:21:48] SMILES Parse Error: Failed parsing SMILES ' for input: '
# Progress: 1.1% (10000/888657) | Valid: 9999 | Invalid: 1 | Time remaining: 296.3s
# Progress: 1.7% (15000/888657) | Valid: 14999 | Invalid: 1 | Time remaining: 293.3s
# Progress: 2.3% (20000/888657) | Valid: 19999 | Invalid: 1 | Time remaining: 290.6s
# Progress: 2.8% (25000/888657) | Valid: 24999 | Invalid: 1 | Time remaining: 288.6s
# Progress: 3.4% (30000/888657) | Valid: 29999 | Invalid: 1 | Time remaining: 286.5s
# Progress: 3.9% (35000/888657) | Valid: 34999 | Invalid: 1 | Time remaining: 284.7s
# Progress: 4.5% (40000/888657) | Valid: 39999 | Invalid: 1 | Time remaining: 282.7s
# Progress: 5.1% (45000/888657) | Valid: 44999 | Invalid: 1 | Time remaining: 280.9s
# Progress: 5.6% (50000/888657) | Valid: 49999 | Invalid: 1 | Time remaining: 279.0s
# Progress: 6.2% (55000/888657) | Valid: 54999 | Invalid: 1 | Time remaining: 277.3s
# Progress: 6.8% (60000/888657) | Valid: 59999 | Invalid: 1 | Time remaining: 275.7s
# Progress: 7.3% (65000/888657) | Valid: 64999 | Invalid: 1 | Time remaining: 274.1s
# Progress: 7.9% (70000/888657) | Valid: 69999 | Invalid: 1 | Time remaining: 272.5s
# Progress: 8.4% (75000/888657) | Valid: 74999 | Invalid: 1 | Time remaining: 270.8s
# Progress: 9.0% (80000/888657) | Valid: 79999 | Invalid: 1 | Time remaining: 269.1s
# Progress: 9.6% (85000/888657) | Valid: 84999 | Invalid: 1 | Time remaining: 267.4s
# Progress: 10.1% (90000/888657) | Valid: 89999 | Invalid: 1 | Time remaining: 265.7s
# Progress: 10.7% (95000/888657) | Valid: 94999 | Invalid: 1 | Time remaining: 264.1s
# Progress: 11.3% (100000/888657) | Valid: 99999 | Invalid: 1 | Time remaining: 262.3s
# Progress: 11.8% (105000/888657) | Valid: 104999 | Invalid: 1 | Time remaining: 260.6s
# Progress: 12.4% (110000/888657) | Valid: 109999 | Invalid: 1 | Time remaining: 259.0s
# Progress: 12.9% (115000/888657) | Valid: 114999 | Invalid: 1 | Time remaining: 257.3s
# Progress: 13.5% (120000/888657) | Valid: 119999 | Invalid: 1 | Time remaining: 255.6s
# Progress: 14.1% (125000/888657) | Valid: 124999 | Invalid: 1 | Time remaining: 254.0s
# Progress: 14.6% (130000/888657) | Valid: 129999 | Invalid: 1 | Time remaining: 252.3s
# Progress: 15.2% (135000/888657) | Valid: 134999 | Invalid: 1 | Time remaining: 250.6s
# Progress: 15.8% (140000/888657) | Valid: 139999 | Invalid: 1 | Time remaining: 249.0s
# Progress: 16.3% (145000/888657) | Valid: 144999 | Invalid: 1 | Time remaining: 247.3s
# Progress: 16.9% (150000/888657) | Valid: 149999 | Invalid: 1 | Time remaining: 245.6s
# Progress: 17.4% (155000/888657) | Valid: 154999 | Invalid: 1 | Time remaining: 243.9s
# Progress: 18.0% (160000/888657) | Valid: 159999 | Invalid: 1 | Time remaining: 242.3s
# Progress: 18.6% (165000/888657) | Valid: 164999 | Invalid: 1 | Time remaining: 240.6s
# Progress: 19.1% (170000/888657) | Valid: 169999 | Invalid: 1 | Time remaining: 238.9s
# Progress: 19.7% (175000/888657) | Valid: 174999 | Invalid: 1 | Time remaining: 237.2s
# Progress: 20.3% (180000/888657) | Valid: 179999 | Invalid: 1 | Time remaining: 235.5s
# Progress: 20.8% (185000/888657) | Valid: 184999 | Invalid: 1 | Time remaining: 233.9s
# [17:22:51] SMILES Parse Error: extra open parentheses while parsing: Cc1ccc(NC(=O)C2CCCN(S(=O)(=O)c3cccs3)
# [17:22:51] SMILES Parse Error: check for mistakes around position 7:
# [17:22:51] Cc1ccc(NC(=O)C2CCCN(S(=O)(=O)c3cccs3)
# [17:22:51] ~~~~~~^
# [17:22:51] SMILES Parse Error: Failed parsing SMILES 'Cc1ccc(NC(=O)C2CCCN(S(=O)(=O)c3cccs3) for input: 'Cc1ccc(NC(=O)C2CCCN(S(=O)(=O)c3cccs3)
# Progress: 21.4% (190000/888657) | Valid: 189998 | Invalid: 2 | Time remaining: 232.8s
# Progress: 21.9% (195000/888657) | Valid: 194998 | Invalid: 2 | Time remaining: 231.1s
# Progress: 22.5% (200000/888657) | Valid: 199998 | Invalid: 2 | Time remaining: 229.4s
# Progress: 23.1% (205000/888657) | Valid: 204998 | Invalid: 2 | Time remaining: 227.7s
# Progress: 23.6% (210000/888657) | Valid: 209998 | Invalid: 2 | Time remaining: 226.0s
# Progress: 24.2% (215000/888657) | Valid: 214998 | Invalid: 2 | Time remaining: 224.3s
# Progress: 24.8% (220000/888657) | Valid: 219998 | Invalid: 2 | Time remaining: 222.6s
# Progress: 25.3% (225000/888657) | Valid: 224998 | Invalid: 2 | Time remaining: 221.0s
# Progress: 25.9% (230000/888657) | Valid: 229998 | Invalid: 2 | Time remaining: 219.3s
# Progress: 26.4% (235000/888657) | Valid: 234998 | Invalid: 2 | Time remaining: 217.6s
# Progress: 27.0% (240000/888657) | Valid: 239998 | Invalid: 2 | Time remaining: 215.9s
# Progress: 27.6% (245000/888657) | Valid: 244998 | Invalid: 2 | Time remaining: 214.2s
# Progress: 28.1% (250000/888657) | Valid: 249998 | Invalid: 2 | Time remaining: 212.5s
# Progress: 28.7% (255000/888657) | Valid: 254998 | Invalid: 2 | Time remaining: 210.9s
# Progress: 29.3% (260000/888657) | Valid: 259998 | Invalid: 2 | Time remaining: 209.2s
# Progress: 29.8% (265000/888657) | Valid: 264998 | Invalid: 2 | Time remaining: 207.5s
# Progress: 30.4% (270000/888657) | Valid: 269998 | Invalid: 2 | Time remaining: 205.8s
# Progress: 30.9% (275000/888657) | Valid: 274998 | Invalid: 2 | Time remaining: 204.2s
# Progress: 31.5% (280000/888657) | Valid: 279998 | Invalid: 2 | Time remaining: 202.5s
# Progress: 32.1% (285000/888657) | Valid: 284998 | Invalid: 2 | Time remaining: 200.8s
# Progress: 32.6% (290000/888657) | Valid: 289998 | Invalid: 2 | Time remaining: 199.2s
# Progress: 33.2% (295000/888657) | Valid: 294998 | Invalid: 2 | Time remaining: 197.5s
# Progress: 33.8% (300000/888657) | Valid: 299998 | Invalid: 2 | Time remaining: 195.8s
# Progress: 34.3% (305000/888657) | Valid: 304998 | Invalid: 2 | Time remaining: 194.1s
# Progress: 34.9% (310000/888657) | Valid: 309998 | Invalid: 2 | Time remaining: 192.5s
# Progress: 35.4% (315000/888657) | Valid: 314998 | Invalid: 2 | Time remaining: 190.9s
# Progress: 36.0% (320000/888657) | Valid: 319998 | Invalid: 2 | Time remaining: 189.2s
# Progress: 36.6% (325000/888657) | Valid: 324998 | Invalid: 2 | Time remaining: 187.5s
# Progress: 37.1% (330000/888657) | Valid: 329998 | Invalid: 2 | Time remaining: 185.9s
# Progress: 37.7% (335000/888657) | Valid: 334998 | Invalid: 2 | Time remaining: 184.2s
# Progress: 38.3% (340000/888657) | Valid: 339998 | Invalid: 2 | Time remaining: 182.5s
# Progress: 38.8% (345000/888657) | Valid: 344998 | Invalid: 2 | Time remaining: 180.9s
# Progress: 39.4% (350000/888657) | Valid: 349998 | Invalid: 2 | Time remaining: 179.2s
# Progress: 39.9% (355000/888657) | Valid: 354998 | Invalid: 2 | Time remaining: 177.5s
# Progress: 40.5% (360000/888657) | Valid: 359998 | Invalid: 2 | Time remaining: 175.9s
# Progress: 41.1% (365000/888657) | Valid: 364998 | Invalid: 2 | Time remaining: 174.2s
# Progress: 41.6% (370000/888657) | Valid: 369998 | Invalid: 2 | Time remaining: 172.6s
# Progress: 42.2% (375000/888657) | Valid: 374998 | Invalid: 2 | Time remaining: 170.9s
# Progress: 42.8% (380000/888657) | Valid: 379998 | Invalid: 2 | Time remaining: 169.2s
# Progress: 43.3% (385000/888657) | Valid: 384998 | Invalid: 2 | Time remaining: 167.6s
# Progress: 43.9% (390000/888657) | Valid: 389998 | Invalid: 2 | Time remaining: 165.9s
# Progress: 44.4% (395000/888657) | Valid: 394998 | Invalid: 2 | Time remaining: 164.3s
# Progress: 45.0% (400000/888657) | Valid: 399998 | Invalid: 2 | Time remaining: 162.6s
# Progress: 45.6% (405000/888657) | Valid: 404998 | Invalid: 2 | Time remaining: 160.9s
# Progress: 46.1% (410000/888657) | Valid: 409998 | Invalid: 2 | Time remaining: 159.3s
# Progress: 46.7% (415000/888657) | Valid: 414998 | Invalid: 2 | Time remaining: 157.6s
# Progress: 47.3% (420000/888657) | Valid: 419998 | Invalid: 2 | Time remaining: 155.9s
# Progress: 47.8% (425000/888657) | Valid: 424998 | Invalid: 2 | Time remaining: 154.3s
# Progress: 48.4% (430000/888657) | Valid: 429998 | Invalid: 2 | Time remaining: 152.6s
# Progress: 49.0% (435000/888657) | Valid: 434998 | Invalid: 2 | Time remaining: 151.0s
# Progress: 49.5% (440000/888657) | Valid: 439998 | Invalid: 2 | Time remaining: 149.3s
# [17:24:16] SMILES Parse Error: extra open parentheses while parsing: COc1ccc(NC(=O)c2c
# [17:24:16] SMILES Parse Error: check for mistakes around position 8:
# [17:24:16] COc1ccc(NC(=O)c2c
# [17:24:16] ~~~~~~~^
# [17:24:16] SMILES Parse Error: Failed parsing SMILES 'COc1ccc(NC(=O)c2c for input: 'COc1ccc(NC(=O)c2c
# Progress: 50.1% (445000/888657) | Valid: 444997 | Invalid: 3 | Time remaining: 147.7s
# Progress: 50.6% (450000/888657) | Valid: 449997 | Invalid: 3 | Time remaining: 146.0s
# Progress: 51.2% (455000/888657) | Valid: 454997 | Invalid: 3 | Time remaining: 144.4s
# Progress: 51.8% (460000/888657) | Valid: 459997 | Invalid: 3 | Time remaining: 142.7s
# Progress: 52.3% (465000/888657) | Valid: 464997 | Invalid: 3 | Time remaining: 141.0s
# Progress: 52.9% (470000/888657) | Valid: 469997 | Invalid: 3 | Time remaining: 139.4s
# Progress: 53.5% (475000/888657) | Valid: 474997 | Invalid: 3 | Time remaining: 137.7s
# Progress: 54.0% (480000/888657) | Valid: 479997 | Invalid: 3 | Time remaining: 136.1s
# Progress: 54.6% (485000/888657) | Valid: 484997 | Invalid: 3 | Time remaining: 134.4s
# Progress: 55.1% (490000/888657) | Valid: 489997 | Invalid: 3 | Time remaining: 132.7s
# Progress: 55.7% (495000/888657) | Valid: 494997 | Invalid: 3 | Time remaining: 131.1s
# Progress: 56.3% (500000/888657) | Valid: 499997 | Invalid: 3 | Time remaining: 129.4s
# Progress: 56.8% (505000/888657) | Valid: 504997 | Invalid: 3 | Time remaining: 127.7s
# Progress: 57.4% (510000/888657) | Valid: 509997 | Invalid: 3 | Time remaining: 126.1s
# Progress: 58.0% (515000/888657) | Valid: 514997 | Invalid: 3 | Time remaining: 124.4s
# Progress: 58.5% (520000/888657) | Valid: 519997 | Invalid: 3 | Time remaining: 122.7s
# Progress: 59.1% (525000/888657) | Valid: 524997 | Invalid: 3 | Time remaining: 121.1s
# Progress: 59.6% (530000/888657) | Valid: 529997 | Invalid: 3 | Time remaining: 119.4s
# Progress: 60.2% (535000/888657) | Valid: 534997 | Invalid: 3 | Time remaining: 117.7s
# Progress: 60.8% (540000/888657) | Valid: 539997 | Invalid: 3 | Time remaining: 116.1s
# Progress: 61.3% (545000/888657) | Valid: 544997 | Invalid: 3 | Time remaining: 114.4s
# Progress: 61.9% (550000/888657) | Valid: 549997 | Invalid: 3 | Time remaining: 112.7s
# Progress: 62.5% (555000/888657) | Valid: 554997 | Invalid: 3 | Time remaining: 111.1s
# Progress: 63.0% (560000/888657) | Valid: 559997 | Invalid: 3 | Time remaining: 109.4s
# Progress: 63.6% (565000/888657) | Valid: 564997 | Invalid: 3 | Time remaining: 107.7s
# Progress: 64.1% (570000/888657) | Valid: 569997 | Invalid: 3 | Time remaining: 106.1s
# Progress: 64.7% (575000/888657) | Valid: 574997 | Invalid: 3 | Time remaining: 104.4s
# Progress: 65.3% (580000/888657) | Valid: 579997 | Invalid: 3 | Time remaining: 102.7s
# Progress: 65.8% (585000/888657) | Valid: 584997 | Invalid: 3 | Time remaining: 101.1s
# Progress: 66.4% (590000/888657) | Valid: 589997 | Invalid: 3 | Time remaining: 99.4s
# Progress: 67.0% (595000/888657) | Valid: 594997 | Invalid: 3 | Time remaining: 97.7s
# Progress: 67.5% (600000/888657) | Valid: 599997 | Invalid: 3 | Time remaining: 96.1s
# Progress: 68.1% (605000/888657) | Valid: 604997 | Invalid: 3 | Time remaining: 94.4s
# Progress: 68.6% (610000/888657) | Valid: 609997 | Invalid: 3 | Time remaining: 92.7s
# Progress: 69.2% (615000/888657) | Valid: 614997 | Invalid: 3 | Time remaining: 91.1s
# Progress: 69.8% (620000/888657) | Valid: 619997 | Invalid: 3 | Time remaining: 89.4s
# Progress: 70.3% (625000/888657) | Valid: 624997 | Invalid: 3 | Time remaining: 87.7s
# Progress: 70.9% (630000/888657) | Valid: 629997 | Invalid: 3 | Time remaining: 86.1s
# Progress: 71.5% (635000/888657) | Valid: 634997 | Invalid: 3 | Time remaining: 84.4s
# Progress: 72.0% (640000/888657) | Valid: 639997 | Invalid: 3 | Time remaining: 82.7s
# Progress: 72.6% (645000/888657) | Valid: 644997 | Invalid: 3 | Time remaining: 81.1s
# Progress: 73.1% (650000/888657) | Valid: 649997 | Invalid: 3 | Time remaining: 79.4s
# Progress: 73.7% (655000/888657) | Valid: 654997 | Invalid: 3 | Time remaining: 77.8s
# Progress: 74.3% (660000/888657) | Valid: 659997 | Invalid: 3 | Time remaining: 76.1s
# Progress: 74.8% (665000/888657) | Valid: 664997 | Invalid: 3 | Time remaining: 74.4s
# Progress: 75.4% (670000/888657) | Valid: 669997 | Invalid: 3 | Time remaining: 72.8s
# [17:25:31] SMILES Parse Error: syntax error while parsing: COc1cc(-c2ccc3[nH]cc(C(C)=O)c(=
# [17:25:31] SMILES Parse Error: check for mistakes around position 32:
# [17:25:31] cc3[nH]cc(C(C)=O)c(=
# [17:25:31] ~~~~~~~~~~~~~~~~~~~~^
# [17:25:31] SMILES Parse Error: Failed parsing SMILES 'COc1cc(-c2ccc3[nH]cc(C(C)=O)c(= for input: 'COc1cc(-c2ccc3[nH]cc(C(C)=O)c(=
# Progress: 76.0% (675000/888657) | Valid: 674996 | Invalid: 4 | Time remaining: 71.1s
# Progress: 76.5% (680000/888657) | Valid: 679996 | Invalid: 4 | Time remaining: 69.4s
# Progress: 77.1% (685000/888657) | Valid: 684996 | Invalid: 4 | Time remaining: 67.8s
# Progress: 77.6% (690000/888657) | Valid: 689996 | Invalid: 4 | Time remaining: 66.1s
# Progress: 78.2% (695000/888657) | Valid: 694996 | Invalid: 4 | Time remaining: 64.5s
# Progress: 78.8% (700000/888657) | Valid: 699996 | Invalid: 4 | Time remaining: 62.8s
# Progress: 79.3% (705000/888657) | Valid: 704996 | Invalid: 4 | Time remaining: 61.1s
# Progress: 79.9% (710000/888657) | Valid: 709996 | Invalid: 4 | Time remaining: 59.5s
# Progress: 80.5% (715000/888657) | Valid: 714996 | Invalid: 4 | Time remaining: 57.8s
# Progress: 81.0% (720000/888657) | Valid: 719996 | Invalid: 4 | Time remaining: 56.1s
# Progress: 81.6% (725000/888657) | Valid: 724996 | Invalid: 4 | Time remaining: 54.5s
# Progress: 82.1% (730000/888657) | Valid: 729996 | Invalid: 4 | Time remaining: 52.8s
# Progress: 82.7% (735000/888657) | Valid: 734996 | Invalid: 4 | Time remaining: 51.1s
# Progress: 83.3% (740000/888657) | Valid: 739996 | Invalid: 4 | Time remaining: 49.5s
# Progress: 83.8% (745000/888657) | Valid: 744996 | Invalid: 4 | Time remaining: 47.8s
# Progress: 84.4% (750000/888657) | Valid: 749996 | Invalid: 4 | Time remaining: 46.1s
# Progress: 85.0% (755000/888657) | Valid: 754996 | Invalid: 4 | Time remaining: 44.5s
# [17:26:00] SMILES Parse Error: extra open parentheses while parsing: COc1ccc(C2(c3ccc(OC)cc3)NC(=O)N(CC(=O)Nc3ccccc3C(F)(F)F
# [17:26:00] SMILES Parse Error: check for mistakes around position 8:
# [17:26:00] COc1ccc(C2(c3ccc(OC)cc3)NC(=O)N(CC(=O)Nc3
# [17:26:00] ~~~~~~~^
# [17:26:00] SMILES Parse Error: extra open parentheses while parsing: COc1ccc(C2(c3ccc(OC)cc3)NC(=O)N(CC(=O)Nc3ccccc3C(F)(F)F
# [17:26:00] SMILES Parse Error: check for mistakes around position 32:
# [17:26:00] c3ccc(OC)cc3)NC(=O)N(CC(=O)Nc3ccccc3C(F)(
# [17:26:00] ~~~~~~~~~~~~~~~~~~~~^
# [17:26:00] SMILES Parse Error: Failed parsing SMILES 'COc1ccc(C2(c3ccc(OC)cc3)NC(=O)N(CC(=O)Nc3ccccc3C(F)(F)F for input: 'COc1ccc(C2(c3ccc(OC)cc3)NC(=O)N(CC(=O)Nc3ccccc3C(F)(F)F
# Progress: 85.5% (760000/888657) | Valid: 759995 | Invalid: 5 | Time remaining: 42.8s
# Progress: 86.1% (765000/888657) | Valid: 764995 | Invalid: 5 | Time remaining: 41.2s
# Progress: 86.6% (770000/888657) | Valid: 769995 | Invalid: 5 | Time remaining: 39.5s
# Progress: 87.2% (775000/888657) | Valid: 774995 | Invalid: 5 | Time remaining: 37.8s
# Progress: 87.8% (780000/888657) | Valid: 779995 | Invalid: 5 | Time remaining: 36.2s
# Progress: 88.3% (785000/888657) | Valid: 784995 | Invalid: 5 | Time remaining: 34.5s
# Progress: 88.9% (790000/888657) | Valid: 789995 | Invalid: 5 | Time remaining: 32.8s
# Progress: 89.5% (795000/888657) | Valid: 794995 | Invalid: 5 | Time remaining: 31.2s
# Progress: 90.0% (800000/888657) | Valid: 799995 | Invalid: 5 | Time remaining: 29.5s
# Progress: 90.6% (805000/888657) | Valid: 804995 | Invalid: 5 | Time remaining: 27.8s
# Progress: 91.1% (810000/888657) | Valid: 809995 | Invalid: 5 | Time remaining: 26.2s
# Progress: 91.7% (815000/888657) | Valid: 814995 | Invalid: 5 | Time remaining: 24.5s
# Progress: 92.3% (820000/888657) | Valid: 819995 | Invalid: 5 | Time remaining: 22.8s
# Progress: 92.8% (825000/888657) | Valid: 824995 | Invalid: 5 | Time remaining: 21.2s
# Progress: 93.4% (830000/888657) | Valid: 829995 | Invalid: 5 | Time remaining: 19.5s
# Progress: 94.0% (835000/888657) | Valid: 834995 | Invalid: 5 | Time remaining: 17.9s
# Progress: 94.5% (840000/888657) | Valid: 839995 | Invalid: 5 | Time remaining: 16.2s
# Progress: 95.1% (845000/888657) | Valid: 844995 | Invalid: 5 | Time remaining: 14.5s
# Progress: 95.6% (850000/888657) | Valid: 849995 | Invalid: 5 | Time remaining: 12.9s
# Progress: 96.2% (855000/888657) | Valid: 854995 | Invalid: 5 | Time remaining: 11.2s
# Progress: 96.8% (860000/888657) | Valid: 859995 | Invalid: 5 | Time remaining: 9.5s
# [17:26:36] SMILES Parse Error: syntax error while parsing: CN1CCN(c2cc(=NCc3cccnc3)n3[nH]cc(
# [17:26:36] SMILES Parse Error: check for mistakes around position 34:
# [17:26:36] NCc3cccnc3)n3[nH]cc(
# [17:26:36] ~~~~~~~~~~~~~~~~~~~~^
# [17:26:36] SMILES Parse Error: Failed parsing SMILES 'CN1CCN(c2cc(=NCc3cccnc3)n3[nH]cc( for input: 'CN1CCN(c2cc(=NCc3cccnc3)n3[nH]cc(
# Progress: 97.3% (865000/888657) | Valid: 864994 | Invalid: 6 | Time remaining: 7.9s
# Progress: 97.9% (870000/888657) | Valid: 869994 | Invalid: 6 | Time remaining: 6.2s
# Progress: 98.5% (875000/888657) | Valid: 874994 | Invalid: 6 | Time remaining: 4.5s
# Progress: 99.0% (880000/888657) | Valid: 879994 | Invalid: 6 | Time remaining: 2.9s
# Progress: 99.6% (885000/888657) | Valid: 884994 | Invalid: 6 | Time remaining: 1.2s
# Progress: 100.0% (890000/888657) | Valid: 888651 | Invalid: 6 | Time remaining: 0.0s
# Completed in 295.7s
# Total SMILES: 888657
# Valid SMILES: 888651 (100.0%)
# Invalid SMILES: 6 (0.0%)
# Saved 888651 valid SMILES to ./data/chembl.raw_cleaned.smi
# ['NCc1cn(S(=O)(=O)c2ccc(N)cc2)c2ccccc12',
#  'FC(F)(F)c1nc2ccccc2[nH]c1=NN=Cc1ccccc1',
#  'CCN(CC)CC(=O)N(C)c1nc2cc3nc(N(C)C(=O)CN(CC)CC)sc3cc2s1',
#  'CCOc1cc2[nH]c(=O)n(CCc3ccc(OC)c(OC)c3)c(=O)c2cc1OCC',
#  'COc1cccc(NC(=O)c2[nH]nc3ccccc23)c1',
#  'CC(=NN=c1[nH]c(C)c(N=Nc2ccc(Cl)cc2)s1)c1[nH]c(-c2ccccc2)nc1C',
#  'O=c1cc(CCc2ccc(C(F)(F)F)cc2)[nH][nH]c1=O',
#  'CC(C)(C)C(NC(=O)CC(N)C(=O)N1CCCC1C#N)c1ccccc1',
#  'CC(C)c1ccc(-c2cc(-c3ccc4c(c3)CCCC4)nc3[nH][nH]c(=N)c23)cc1',
#  'O=C1COc2ccc(NC(=O)C3CCN(c4cccc(Br)c4)CC3)cc2N1',
#  'CCN(CC)C(O)c1cc(CC(=O)NCCN2CCOCC2)c(=O)n(CCC2=CCCCC2)c1C',
#  'C=c1sc2ccc(O)c3c(O)c4c(O)cccc4c1c23',
#  'CC(CCC(C)C)=NNC(=O)COc1ccccc1-c1ccccc1',
#  'Cc1c[nH]nc1C1CCCCN1C(=O)Cn1cc(Cl)cn1',
#  'COC(=O)CC(NC(=O)C(C)NC(=O)C(NC(=O)CCCCCNC(=O)CCCCC1SCC2NC(=O)NC21)C(C)C)C(=O)CF',
#  'CN1c2ccc(NS(=O)(=O)c3cccc(C(F)(F)F)c3)cc2N=C(c2ccc(C(=O)O)cc2)c2cc3c(cc21)C(C)(C)CCC3(C)C',
#  'CCOC(=O)CNC(=O)C(C)NC(=O)C(NC(=O)OCc1ccccc1)C(C)C',
#  'O=C1c2c(c3c4ccc(O)cc4n(OC4OC(CO)C(O)C(O)C4O)c3c3[nH]c4cc(O)ccc4c23)C(=O)N1NCc1cccc(CO)c1',
#  'Cc1ccc(=NC(=O)CCn2nc([N+](=O)[O-])cc2C)[nH]c1',
#  'O=C(Oc1cncc(Cl)c1)c1ccc(Cl)cc1',
#  'O=C(O)CC(c1ccc2ccccc2c1)n1ccc2cc(OCCc3ccc4c(n3)NCCC4)ccc21',
#  'Fc1ccc2c(C3CCN(CCOc4cccc5c4OCCO5)CC3)c[nH]c2c1',
#  'Cc1cc(OCC2(CON=C(N)N)CC2)cc(OS(=O)(=O)c2ccccc2S(C)(=O)=O)c1',
#  'O=C(NN1C(=O)CS(=O)(=O)C1c1ccc(Cl)c(Cl)c1)c1ccncc1',
#  'CC1(C)Oc2cc(C(=O)Nc3cccc(C(F)(F)F)c3)ccc2-c2[nH]c(-c3c(F)cccc3Cl)nc21',
#  'CNC(=O)c1cc2c(cc1OC)C1CCC3(C)C(O)CCC3C1CC2',
#  'Cc1ccc2nc3ccc(N)cc3nc2c1',
#  'COc1ccc(C2C(C#N)C(=N)N(Nc3ccccc3)C3=CC(C)(C)CC(=O)C32)cc1C',
#  'CC(C)(C)OC(=O)C1CC12C(=O)Nc1ccc(Br)cc12',
#  'CN(C(=O)CSc1n[nH]c2nc(=O)cc(-c3ccccc3)n12)c1ccccc1',
#  'COCCN(C)CC1CCC(c2nnn3cnc4[nH]ccc4c23)CC1',
#  'O=C(Nc1ccc(Br)cc1[N+](=O)[O-])c1cc(O)c(O)c(O)c1',
#  'O=c1ccn(-c2ccc3ncccc3c2)nc1-c1ccnn1-c1cccc(Cl)c1',
#  'Cc1ccccc1-c1nc(CN(C)Cc2ccco2)co1',
#  'CCC(=NN=c1c(Cl)c(Cl)[nH]c(C(=O)O)c1Cl)c1ccccc1',
#  'COc1ccc(Cc2noc(CN(C)Cc3ccc(-n4cccn4)cc3)n2)cc1OC',
#  'NCc1cccc(CN2CCCC(Nc3ccc4[nH]ncc4c3)C2)c1',
#  'N#Cc1cc(F)cc(S(=O)(=O)c2sc3ncc(N)cc3c2-c2cccc(F)c2)c1',
#  'CC(=O)Nc1ccc(S(=O)(=O)N=c2[nH]c3ccccc3[nH]c2=Nc2ccc(C(=O)O)cc2)cc1',
#  'Cc1[nH]nc2ccc(-c3cncc(OCC(N)Cc4cc(Cl)cc(Cl)c4)c3)cc12',
#  'CC(=O)NCc1ccc(-c2csc(=NC(=N)NCCc3ccccc3)[nH]2)o1',
#  'CC(C)c1ccc(NC(=S)N2CCN(C)CC2)cc1',
#  'COc1cccc(-c2nc(-c3cnccn3)n(COCCO)n2)c1',
#  'CN1CCN(C2=Nc3ccccc3Cn3cccc32)CC1',
#  'Cc1ccc(CNC(=O)C(CCCN)N=c2[nH]c(=NCC3CCCCC3)[nH]cc2C)cc1',
#  'NC1(C(=O)O)CC(C(=O)O)N(Cc2ccc([N+](=O)[O-])cc2)C1',
#  'CCCCN1CCC(COC(=O)c2cc(C#N)c(NC)c3c2OCCO3)CC1',
#  'Cn1c(=O)c2c(-c3ccccc3)n3c(c2n(C)c1=O)C(c1ccccc1)OCC3',
#  'O=C(Cn1c(O)csc1=O)N1CCCCC1',
#  'CC1Oc2cc(O)c(Br)cc2C(=O)C1n1ccnc1',
#  'CCC(C)C(N=c1[nH]c(-c2ccccc2)nc2c1oc1ccccc12)C(=O)O',
#  'COc1ccc(S(=O)(=O)N(CC(=O)NC(C)c2ccccc2)c2ccc(C)cc2)cc1OC',
#  'O=[N+]([O-])c1cccc(N=Nc2c(O)ccc3ccccc23)c1',
#  'COCc1ccccc1-c1cncc(-c2cnc3c(c2)CCCN3C(N)=O)c1',
#  'NCC(=O)N1CSCC1C(=O)NC(CCC(=O)O)C(=O)O',
#  'CCOC(=O)c1cc(-c2ccc(Cl)cc2)[nH]c1NNC(=O)Cc1ccc(OC)cc1',
#  'CCC(C)NC(=O)c1c(C)cc(=O)oc1C',
#  'COc1c(C)c(O)c2c(c1O)=C1C3C=c4c(O)c(C)c(OC)c(O)c4=C(COC(=O)c4ccc5ccccc5n4)N3C(C#N)C(C=2)N1C',
#  'C=c1[nH]n(-c2ccccc2)c(=O)c1=Cc1ccccc1OC',
#  'NC(=S)N1N=C(c2ccccc2)CC1c1ccccc1',
#  'COc1ccc(-c2cc(C(=O)Nc3ccc(Oc4ccnc5cc(OCCCN6CCCCC6)c(OC)cc45)c(F)c3)c3ccccc3n2)cc1',
#  'N#Cc1c(NCc2ccccc2)cc[nH]c1=NCc1cccnc1',
#  'Cn1c(=O)n(CCOC(=O)CNC(=O)c2cccs2)c(=O)c2ccccc21',
#  'O=C1C(=Cc2ccc(OCCCCN3CCOCC3)cc2)CCC1=Cc1ccc(OCCCCN2CCOCC2)cc1',
#  'Cc1c(C)[n+](C)c(SCC(=O)CCC(NC(=O)C(Cc2ccccc2)NC(=O)OCc2ccccc2)C(=O)O)n1Cc1ccccc1',
#  'Cc1nn(C)c(C)c1N(C)S(=O)(=O)c1ccc(-c2cccc(CC3CCNCC3)c2)cc1',
#  'CCN1CCN(Cc2ccc(NC(=O)Nc3ccc(SC)cc3)cc2)CC1',
#  'COc1cccc(Cc2cc(C)nn(CCNC(=O)Nc3ccc(Br)cc3)c2=O)c1',
#  'COc1nc(C2=NC(COc3ccc(F)cc3C)CON2)ccc1-c1ocnc1C',
#  'COc1ccc(-n2c(O)c3c(c2O)C2CC(c4ccccc4)CCC2c2c-3[nH]c3ccccc23)cc1',
#  'CCOCc1cccc(NC(=O)c2cc3sccc3n2C)c1COc1ccc(OCC2CCNC2)cc1',
#  'CCn1nc(C)c(CCn2ccnc2-c2cc3n(n2)CCNC3)c1C',
#  'COC1CCC(NC(=O)c2[nH]ncc2NC(=O)c2ncoc2-c2ccccc2)CC1',
#  'CN(C)C(=O)c1sc(-c2ccncc2)nc1O',
#  'CCc1ncc2c(n1)CN(CC(=O)Nc1cccnc1)CC2',
#  'COc1ccc2nc(-c3ccc(N)cc3)sc2c1',
#  'CCN(C(=O)c1ccc(CN=c2nc(N3CCc4ccc(F)cc4C3)nc[nH]2)cc1)c1cccc(C)c1',
#  'CNC(=O)C(Cc1c[nH]c2ccccc12)NC(=O)C(CC(=O)NNc1ccc(OC)cc1)CC(C)C',
#  'CC(=NCc1ccccc1F)Nc1ccc2c(c1)C(NC(=O)c1ccc(Br)cc1)C(O)C2',
#  'CN(CCCOc1ccc(Cc2ccccc2)cc1)CCn1cnnn1',
#  'c1ccc(CCn2nnc3c(=NC4CCCCC4)[nH]cnc32)cc1',
#  'CCc1cc(C(N)=O)c(NC(=O)c2ccc([N+](=O)[O-])o2)s1',
#  'COc1ccc2nc(C)cc(N3CCOCC3)c2c1',
#  'O=C(CSc1nnc(SCc2ccc(F)cc2)s1)Nc1ccc(C(=O)O)cc1',
#  'Cc1cc(N=c2nc(-c3cn(C)cn3)cc[nH]2)cc2cc(C(=O)N(C)Cc3nccn3C)[nH]c12',
#  'O=C(CCCCC#Cc1cccnc1)c1ncc(-c2ccccn2)o1',
#  'Cc1nc2cnccc2n1CC1CCN(C(=O)CC(C)(C)c2ccc(N=Nc3ccc(O)c(C(=O)O)c3)cc2)CC1',
#  'CCc1ccc(Nc2cc(=O)n(C)c(=S)[nH]2)cc1',
#  'COc1cc(C)c(OC)c2c1CC(C(=O)O)CC2c1ccccc1',
#  'COC(=O)C(c1ccccc1)C1CCCCN1Cc1ccncc1',
#  'CCN(c1ccccc1)S(=O)(=O)c1cccc(C(=O)NCCOc2ccccc2OC)c1',
#  'COc1ccc(-c2csc(=NC(=O)C[n+]3cccc(C=NO)c3)[nH]2)cc1',
#  'Cn1c(=O)c2[nH]c(=NCc3ccccc3)cnc2n(C)c1=O',
#  'Cc1cccc(-n2c(SCC(=O)N=c3[nH]cc(Cl)cc3Cl)nc3ccccc32)c1',
#  'Cc1c(C(=O)NC2CCCc3ccccc32)oc2ccc(S(=O)(=O)N3CCOCC3)cc12',
#  'NC(=O)c1nn(-c2ccc(F)cc2)c2c1CCc1ccc(NC(=O)c3cc(-c4ccncc4)ncc3Cl)cc1-2',
#  'COc1cc2c(c(OC)c1OC)-c1ccc(OC)c(=O)cc1C(NC(=O)CCCO[N+](=O)[O-])CC2',
#  'CCc1ccc(C2CC3C(CN2S(=O)(=O)c2ccc(C)cc2)C(=O)CC(c2ccc(Cl)cc2)N3S(=O)(=O)c2ccccc2C)cc1',
#  'O=C1C=NC(c2ncccn2)c2cc(Cl)ccc2N1',
#  'O=C(C1CCN(c2ccncc2)CC1)N1CCC(CNS(=O)(=O)C=Cc2ccc(-c3ccc(Cl)s3)s2)C1',
#  'Oc1ccc(-c2sc3cc(O)ccc3c2C(O)c2ccc(OCCN3CCCCC3)cc2)cc1',
#  'CN1C(C(=O)N=c2cccc[nH]2)C(=O)c2c(ccc3ccccc23)S1(=O)=O',
#  'CS(=O)(=O)N1CCCCN2C(CO)C(c3ccc(C#Cc4ccccn4)cc3)C2C1',
#  'COc1ccc(S(=O)(=O)Nc2cccc(-c3ccc4[nH]c(=NC(C)=O)sc4c3)c2)cc1',
#  'Cc1nc(-c2ccc[nH]c2=Nc2cnc(Cl)c(N)c2)[nH]c(=N)n1',
#  'O=C(Nc1ccc(Oc2ccccc2)cc1)c1ccc(F)c(S(=O)(=O)N2CCN(c3cccc(Cl)c3)CC2)c1',
#  'NC(=O)N1c2ccc(F)cc2C=Cc2cc(F)ccc21',
#  'O=[N+]([O-])c1c[nH]c(=Nc2ccccc2)[nH]c1=Nc1ccccc1',
#  'Cc1ccccc1NC(=O)CC1C(=O)Nc2ccccc2[S+]1[O-]',
#  'C=CCOC(=O)c1cnc(Cl)cn1',
#  'CCCNC(=O)c1cc(C2CCCN(Cc3ccccn3)C2)no1',
#  'NC1CCN(C(=O)c2cn3c(ccc4c(C(F)(F)F)cc(C(F)(F)F)nc43)n2)CC1',
#  'N=c1[nH]c(=O)[nH]c2c1cnn2COCCO',
#  'CCC1(CC)C(=O)NC(=O)N=C1Nc1ccccc1',
#  'CC(C)(O)CCCC(CCCC(C)(C)O)C1CCC2C(=CC=C3CC(O)CC(O)C3)CCCC21C',
#  'CC(N)C(=O)NC(C(=O)N1CCCC1C(=O)OCc1ccccc1)C1CCCCC1',
#  'CC1CCCC2CC(NC(=O)c3cc(C(=O)c4ccccc4)ccc3O)CCN12',
#  'CNC(=O)CC1N=C(c2ccc(Cl)cc2)c2c(sc(C)c2C)-n2c(C)nnc21',
#  'O=C(NCCc1ccc(Cl)cc1)c1ccc(=O)[nH]c1',
#  'COc1ccc(C(=O)O)c(-c2ccc3c(c2)OCC(Cc2ccccc2)C3O)c1',
#  'O=C(CNC(=O)c1ccccc1)NC1(C(=O)NC2CCCC2)CCCCC1',
#  'O=S(=O)(c1ccccc1)N(Cc1ccc(C(F)(F)F)c(F)c1)c1cc2ncccc2s1',
#  'Cc1cc(N=c2nc(C(F)(F)C(F)(F)F)cc[nH]2)cc(-c2cnc(C3(O)CCC(C(=O)OC(C)(C)C)CC3)s2)c1',
#  'COc1c(C(O)CC(C)C)ccc2c1C(=O)Oc1c(Cl)c(C)c(C)c(OC(=O)C3(C)C4CCC3CC4)c1O2',
#  'O=c1c(C=NC2CCN(Cc3ccccc3)CC2)c2ccccc2c(O)n1Cc1ccc2c(c1)OCO2',
#  'O=C(CCCC1CCCCC1)N=c1[nH]nc2n1CCS2',
#  'O=C1CCC=C2N=C3CCS(=O)(=O)C3C(c3ccc(F)c(F)c3)C12',
#  'Cc1ccc2ncc(S(=O)(=O)c3cc(Cl)cc(Cl)c3)c(N3CCOCC3)c2c1',
#  'COc1cc2c(cc1OC)CN(CCCCNC(=O)c1cc(Br)cc(OC)c1OC)CC2',
#  'COc1ccc(-c2ccc(C(=O)O)cc2)cc1OC(C)CCCc1ccccc1',
#  'CCNC(=O)N=c1[nH]c2c(s1)CN(c1cncc(OC)c1)CC2',
#  'CCOC(=O)C(=O)CC(=O)C=Cc1cc(C(=O)c2ccc(F)cc2)cn1-c1ccccc1',
#  'CCc1ccc(N(C2C=CS(=O)(=O)C2)S(=O)(=O)c2ccc(C)cc2)cc1',
#  'COc1cccc(N2CCN(CC(=O)N3CCN(c4nnc(-c5ccc(Cl)cc5)c(-c5ccc(Cl)cc5)n4)CC3)CC2)c1',
#  'CC1OC(n2cc(-c3ccccc3)c3c(=NCC(=O)Nc4ccc(Cl)cc4)[nH]cnc32)C(O)C1O',
#  'C=C1C(=O)C23C(OC(=O)c4cccc(C)c4C)C1CCC2C12C=CCC(C)(C)C1C(O)C3(O)OC2',
#  'COc1cc2c(cc1OC)C(=O)N1C=C(c3ccc(N(C)C)cc3)CC1C=N2',
#  'COC(=O)NC(C)C(=O)NC(CC(C)C)C(=O)NC(Cc1ccccc1)C(=O)COC(=O)c1c(F)cccc1F',
#  'CC1c2nnc(C(F)(F)F)n2CCN1C(=O)c1cccc(Cc2n[nH]c(=O)c3ccccc23)c1',
#  'Cc1cc(=NS(=O)(=O)c2ccc(NC(=O)c3cc(-c4ccccc4Cl)nc4ccccc34)cc2)[nH]o1',
#  'O=c1c2ccccc2c(Cc2ccc(Cl)cc2Cl)nn1-c1ccc(Br)cc1',
#  'CN(N=Cc1cnn2ccc(C#N)cc12)S(=O)(=O)c1cc([N+](=O)[O-])ccc1NCc1ccccn1',
#  'O=C(Nc1ccc(Cl)cc1)c1cc(S(=O)(=O)N=c2[nH]nc3c(Cl)cc(C(F)(F)F)cn23)c(S)cc1Cl',
#  'CCCN(Cc1ccc(-c2ccccc2-c2nn[nH]n2)cc1)c1nsnc1C(=O)O',
#  'O=C(Nc1ccc(C(=O)N2CCc3cc(-c4nc5cc(Cl)ccc5[nH]4)sc3-c3ccccc32)cc1)c1cccnc1N1CC2(CCOCC2)C1',
#  'CCN(CC)C(O)c1cc(CC(=O)NCCN2CCOCC2)c(=O)n(Cc2ccccc2)c1C',
#  'CCCCCCCNC(=O)Oc1ccc2c(c1)C1(C)CCN(CCC)C1C2',
#  'O=c1[nH]cnc2cc(Cl)ccc12',
#  'O=C(c1ccccc1)N1CC2CC(C1)CN(C(=O)C1CCC(=O)N1Cc1ccccc1Br)C2',
#  'CCOC(=O)Cn1cc(C#N)c2cccc(CC)c21',
#  'O=C(COc1ccccc1F)N1CCN(S(=O)(=O)C=Cc2ccccc2)CC1',
#  'CCCC(F)(F)CC(NC(=O)N1CCC2(CC1)CC2)C(=O)NC1(C#N)CC1',
#  'Cc1ccc(=N)n(Cc2cccc(F)c2)c1',
#  'Cn1cc(-c2c[nH]n3c(=N)c(-c4cccs4)c(C4CCCNC4)nc23)cn1',
#  'c1cc(-c2cnc3cccnn23)c2cccnc2c1',
#  'NC(=O)c1ccccc1Br',
#  'CC(=O)NC(C)CCc1ccccc1',
#  'CCCCCCCNC(=S)Nc1cc(C=CC(O)=NO)ccc1SCCN(CC)CC',
#  'COc1ccc(N2C(=O)c3ccccc3C2=O)cc1OC',
#  'Cc1cccc2c3nn4cnnc4sc-3cc12',
#  'CC(C)(C)c1noc(C=NO)n1',
#  'CC(=N)NCCCCC(N)C(=O)N=c1nn[nH][nH]1',
#  'COc1cc(C(=O)OCC2OC(OC(CO)C(O)c3cc(OC)c(O)c(OC)c3)C(O)C(O)C2O)cc(OC)c1O',
#  'CC(C)CC(NC(CCN1C(=O)c2cc3ccccc3cc2C1=O)C(=O)O)C(=O)NC(C)c1ccccc1',
#  'COc1ccccc1-c1cc(-c2ccccc2-c2ccccc2)[nH]n1',
#  'CC(C)C(C)N=c1cc(-c2[nH]c(=O)[nH]c2-c2ccc(F)cc2)cc[nH]1',
#  'O=C(O)CC1CCCc2c1n(Cc1ccc(Cl)cc1)c1ccc(F)cc21',
#  'CC(=O)N=c1nc(OCc2ccccc2)c2[nH]cnc2[nH]1',
#  'Cc1ccc(C)c(N2CCN(C(=O)CCS(=O)(=O)c3ccc4c(c3)CCN4C(=O)C3CC3)CC2)c1',
#  'O=C(NCCN1CCOCC1)C(OC1CCCC1)c1ccccc1',
#  'CC1(C)CC(=O)C=C(c2ccc(COC(=O)c3ccc(-c4ccccc4)cc3)cc2)C1=O',
#  'CCOc1ccc2[nH]c(C)cc(=Nc3ccc(N4CCOCC4)cc3)c2c1',
#  'CN(C)CCN(C)c1cc2c(c3c1ccn3C)C1CCC2O1',
#  'CCCCNC(=O)C1CCN(CC(C)=Cc2ccccc2)CC1',
#  'COc1ccc(C=C2C(=O)Nc3ccc(Cl)cc32)cc1',
#  'CC1OC(OC2CCC3(C=O)C(CCC4C3CCC3(C)C(c5coc(O)c5)CCC43O)C2)C(O)C(O)C1O',
#  'Nc1cccc(OCCCN2CCN(c3ccccc3)CC2)c1',
#  'CC(=O)NCC(C)(C)c1ccc(C#Cc2cnc(OC3CCC3)nc2)cc1',
#  'CCOc1ccc2c(c1)[nH]c(=S)n2C',
#  'CC(C)COc1cccc(N2CCCNCC2)n1',
#  'C=c1cc(O)c2c(c1O)N=c1cc(OC)ccc1=2',
#  'O=C(CC1C(=O)NCCN1C(=O)Nc1ccccc1)Nc1ccc2c(c1)OCCO2',
#  'Oc1ccc(N2CCN(c3cc(O)n(Cc4ccccc4)c3O)CC2)cc1',
#  'COc1ccccc1N(CC(=O)NCC1CCCO1)C(=O)CNS(=O)(=O)c1ccc(Cl)cc1',
#  'CC(C)(O)CCCC1(C)CC(=O)c2cc(O)c(Br)cc2O1',
#  'COc1cc(-c2cn[nH]c2)ccc1C(=O)NC(CO)C(O)c1ccccc1',
#  'CCOc1cc(C)c(Cl)cc1S(=O)(=O)NC1CC(C)(C)NC(C)(C)C1',
#  'Cc1cccc(-c2nc(CNc3ccc(C(N)=O)cc3)cn2-c2ccc3c(c2)OCO3)n1',
#  'CNC(=O)CN1C(=O)CN=C(c2ccccc2)c2cc(Cl)ccc21',
#  'Nc1ccccc1NC(=O)c1ccc(CSc2nc3ccccc3s2)cc1',
#  'O=C(CC1CCCCC1)Nc1ccccc1CO',
#  'COc1ccc(N=c2[nH]cnc3c2sc2nccnc23)cc1OC',
#  'Cc1ccccc1N1CCN(CC(O)CN2CCC(c3ccccc3)(c3ccccc3)C2=O)CC1',
#  'O=C(O)Cc1ccc(COc2c(C3CCC3)ccc(-c3cnc4c(c3)OCCN4)c2F)cc1',
#  'CC(=O)OC1CC2C(C)(C)OC(=O)CC(OC(C)=O)C2(C)C2CCC3(C)C(=CCC3C3COC(O)(C(C)(C)O)C(O)C3)C12C',
#  'COc1cccc(-c2nc(CNCc3ccccc3OC(F)(F)F)co2)c1',
#  'CC1CCN(C(=O)N2c3ccccc3Sc3ccccc32)CC1',
#  'CC(C)=CCN=c1[nH]cnc2c1nc(-c1cccs1)n2C1OC(CO)C(O)C1O',
#  'COC(=N)Cc1ccc(-c2cnc(C(=O)CCCCCCc3ccccc3)o2)nc1',
#  'O=C(Cn1c(=O)cnc2ccccc21)NNC(=O)c1ccccc1Cl',
#  'CN(C)CC#CC(=O)Nc1ccc2[nH]cnc(=Nc3cccc(Br)c3)c2c1',
#  'O=C(Nc1ccc2ncccc2c1)C(=O)c1cn(Cc2cscn2)c2ccccc12',
#  'COc1cc(N2CCC(F)(F)CC2)ccc1-c1nc(=O)c2c(C3CCCCC3)nsc2[nH]1',
#  'CCc1c(Sc2ccc(OC)cc2)[nH]c2[nH]c(=N)[nH]c(=N)c12',
#  'O=C(NCCN1CCOCC1)c1ccc2c(c1)N(Cc1cccc(F)c1)C(=O)c1ccccc1S2',
#  'CCCCCC(=O)NC(C)C(=O)SC(Cc1ccc(-c2ccccc2)cc1)C(=O)O',
#  'Cc1ccc(F)c(S(=O)(=O)NC(=O)C2(C)CCN2C(=O)COc2ccc(Cl)cc2)c1',
#  'Cc1cc(C(C)(O)C#Cc2ccc3c(c2)-c2nc(C(N)=O)c(-c4cnn(CC(C)(C)O)c4)n2C2CC3C2)no1',
#  'COc1ccc(-c2c(C(=O)c3ccc(C)cc3)c(O)c(O)n2C)cc1',
#  'CC(=O)Nc1ccc(NC(=O)CCC(=O)c2ccc(C)cc2)cc1',
#  'c1ccc(C2=NOC3(C2)CN2CCC3CC2)cc1',
#  'O=C(OC1CCC2CCCCC2C1)c1ccc(O)c(O)c1',
#  'CNC(=O)C(C)(C(O)=NO)N(C)C(=O)c1ccc(C#Cc2ccc(CNC3CC3)cc2)cc1',
#  'O=C1c2c(O)cc(O)cc2OCC1c1ccc(O)cc1',
#  'CCCCc1ccc(C2=NCCN2)cc1',
#  'CCOCCC1(Oc2ccc(Oc3ccc(C(=O)NC)cc3)cc2)C(=O)NC(=O)C(N)C1=O',
#  'COc1ccc2c(c1)C1CN=C(CC(=O)c3ccccc3F)C(=O)N1CC2',
#  'c1ccc(C(CN2CCN(CCCNCc3cccnc3)CC2)c2ccccc2)cc1',
#  'CNC(=O)Nc1ccc(-c2cc(-c3cc[nH]c(=Nc4ccc(Cl)c(S(=O)(=O)NC)c4)n3)ccn2)cc1',
#  'CCOC(=O)C(C)Oc1ccc(C(c2cn(CC)c3ccccc23)c2cn(CC)c3ccccc23)cc1',
#  'Cc1c(F)c(N2CCC(N(C)C)C2)n2c(nc3ccccc32)c1C#N',
#  'Clc1ccc2c(=NCCN(CCN(Cc3ccccc3)Cc3ccccc3)CCN(Cc3ccccc3)Cc3ccccc3)cc[nH]c2c1',
#  'CC(=O)NC1C(C(O)C(O)CO)OC(C(=O)O)=CC1N1CCN(c2cccc(C(F)(F)F)c2)CC1',
#  'Oc1ccc(N=c2[nH]cc(-c3ccccc3F)o2)cc1',
#  'COc1ccccc1-c1cc(CO)on1',
#  'CN(C)c1ccc(C(=O)C=Cc2ccco2)cc1',
#  'O=C1CN=COc2ccccc21',
#  'N#Cc1cc(NS(=O)(=O)c2ccccc2OC(F)(F)F)ccc1Cl',
#  'CC(C)c1cccc(C(C)C)c1NC(=O)N=c1[nH]c2ccccc2n1-c1ccccc1N(C)C',
#  'COc1c(C)cc2c(c1O)C(=O)c1c(O)cccc1C2=O',
#  'CCC1c2c(C3=CCN(CC(=O)N(C)C)CC3)[nH]c3nccc(c23)-c2cc(F)ccc2N1C',
#  'O=c1ccc(-n2ccc3ccccc32)nn1CCCCN1CCN(c2ncccn2)CC1',
#  'C=C(C)CN1CCCC(NS(C)(=O)=O)C1',
#  'NC(=O)c1ccc(Oc2ccc3c(c2)CN(Cc2ccccc2)C3)nc1',
#  'COc1ccc(Cl)cc1C(=O)NNC(=O)CNC(=O)c1ccco1',
#  'Cc1ccc(Oc2nc(C)ccc2C(=NO)N(C)Cc2ccco2)c(C)c1',
#  'CSc1ccc(C(=S)N2CCN(Cc3ccccc3)CC2)cc1',
#  'CCn1cc(C(=O)N2CCN(c3cccc(C)c3C)CC2)c(=O)c2ccc(C)nc21',
#  'CCN(C(=O)CN(C)S(=O)(=O)c1ccc2c(c1)c(=O)n(C)c(=O)n2C)c1ccc(OC)cc1',
#  'NCC1CNC(=O)C(=O)N1',
#  'O=C(Nc1cc(-c2csc(=O)[nH]2)cc(S(=O)(=O)NC2CCCC2)c1)c1cccs1',
#  'COC(=O)C1=C(C)N=C(C)C(C(=O)OC)C1c1cccc([N+]([O-])=Cc2ccccc2)c1',
#  'CC(c1ccc(-c2cc(Br)c(=O)n(C)c2)cc1)C(N)C(=O)N1CCC(F)C1',
#  'COc1ccc2[nH]c3c(c2c1)C1c2cccc(CO)c2C1(O)CC3',
#  'O=C(NC1CC1)N1CCc2ccc(=O)n(Cc3ccncc3)c2CC1',
#  'CC(=O)N1CCN(C(=O)COC(=O)C=Cc2ccccc2[N+](=O)[O-])CC1',
#  'O=C(CON=Cc1ccc(Cl)cc1Cl)NNCCC(=S)Nc1cc(Cl)ccc1Cl',
#  'CCCCCCCCCCCC(=O)CC(O)S(=O)(=O)O',
#  'N=c1[nH][nH]c2cccc(-c3ccc(C(=O)N4CCN(C(=O)c5ccc(Cl)cc5Cl)CC4)cc3)c12',
#  'Cc1cc(C)cc(NC(O)c2cc(O)n(C3CCCCC3)c2)c1',
#  'CCc1cccc(CC)c1NC(=O)n1cc2[nH][nH]c(=NC(O)c3ccc(C(C)(C)C)cc3)c2c1',
#  'CCc1cc(=O)oc2c3c(cc(OCC(=O)NC4CC4)c12)OC(C)(C)CC3',
#  'CCCCN(C(=O)C1CCN(C(=O)c2ccccc2C)CC1)c1c(N)n(CCCC)c(=O)[nH]c1=O',
#  'CC1(C)C2CCC1(C)C(O)C2SCc1ccccc1',
#  'CN(C)CCn1nc2c3c(c(NCCC#CCCN4CC4)ccc31)C(=O)c1ccncc1-2',
#  'O=C1C(=Cc2ccccc2F)Cc2cccc(O)c21',
#  'Fc1ccc(-n2cc(CN(Cc3cn(-c4ccc(F)c(Cl)c4)nn3)c3nc4ccccc4s3)nn2)cc1Cl',
#  'c1coc(C2=NC(c3ccco3)C(c3ccco3)N2)c1',
#  'COC(=O)c1c(C)nc(C)c2c1C(=O)C(Cl)C(=Nc1ccc(C#N)cc1)C2=O',
#  'CCn1c(SCC(=O)Nc2cccnc2Cl)nnc1-c1ccccc1',
#  'O=C(c1ccc(Br)cc1)N1N=C(c2ccc(Cl)cc2)CC1c1ccc2c(c1)OCO2',
#  'FC(F)(F)c1ccc(N=c2[nH]c(Oc3ccccc3)nc3c2CCN(c2ncccc2C(F)(F)F)CC3)cc1',
#  'CC1C2Cc3ccc(O)cc3C1(c1ccccc1)CCN2',
#  'NS(=O)(=O)c1ccc2[nH]c(=NC(=O)COc3ccc(Cl)cc3Cl)sc2c1',
#  'CN1CCN(c2ccc(-c3cnn4c(-c5cc(NC(=O)c6cccc(C(F)(F)F)c6)ccc5F)ccnc34)cn2)CC1',
#  'CC1(CO)CCCC2(C)C1CCC13CC(CCC12)C(O)(CO)C3',
#  'Cn1cc(S(=O)(=O)NCCc2ccccc2)c(=O)n(C)c1=O',
#  'Oc1ccc(-c2cc(-c3ccco3)cc(-c3ccccc3Cl)n2)cc1',
#  'CCOc1ccc(N2CC(c3nc4ccccc4n3CCOc3ccccc3OC)CC2=O)cc1',
#  'CCOC(=O)c1cc(S(=O)(=O)N2CCN(c3ccccc3OC)CC2)cn1C',
#  'CCc1cc(-c2cc[nH]n2)c(O)cc1OCCCOc1cccc(CCC(=O)O)c1',
#  'COc1ccccc1NC(=O)COc1ccccc1C(=O)c1cnn(-c2ccccc2)c1',
#  'CCC(NC(=O)c1cc(C(=O)N2CCCC2C)n2c1COCC2)c1ccc(Cl)nc1',
#  'COc1ccc(CN(CC(=O)NCc2ccc(F)cc2)C(=O)CCC(=O)N=c2cc(C)cc[nH]2)cc1',
#  'COc1ccccc1OCC(=O)NCCS(=O)(=O)N1CCN(c2ccccc2)CC1',
#  'CCC(=O)OC1CC2CCCC1N2',
#  'Cc1nnc2n1CCN(Cc1ncc(-c3ccc(F)cc3)o1)C2',
#  'O=C(Nc1ccccc1C(=O)NCCc1ccccc1)c1cc2ccccc2[nH]1',
#  'O=S(=O)(N=C(Nc1cccc2ccccc12)c1ccccc1)c1ccc(F)cc1',
#  'COc1nc(=NCCC(c2ccccc2)c2ccccc2)c2ncn(C3OC(CO)C(O)C3O)c2[nH]1',
#  'COc1ccc(N=CC=C2OC(C)(C)C(C)(C)O2)cc1OC',
#  'CNC(=O)OCCN1c2ccccc2Sc2ccccc21',
#  'CCC(=O)Nc1ccc(NC(=O)c2ccco2)cc1',
#  'NC(c1c(Cl)cc(O)cc1Cl)C(N)c1c(Cl)cc(O)cc1Cl',
#  'CCOc1cccc(CN2CCCC(C(=O)c3cccc(C(F)(F)F)c3)C2)c1O',
#  'c1ccc2oc(-c3ccncc3)nc2c1',
#  'COc1ccccc1CC(O)CC1c2c(cc3c(c2OC)OCO3)CCN1C',
#  'Cc1ccc(C(=O)NC(C)CN2CCC(n3c(=O)[nH]c4cc(Cl)ccc43)CC2)cc1',
#  'CCN1C(=O)c2ccc(-c3nc4ccccc4c(=O)o3)cc2C1=O',
#  'Cc1ccc(-c2nc(C)c(C(OC(C)(C)C)C(=O)O)c(-c3ccc4c(c3)CCCO4)c2C)cc1',
#  'CCOC(=O)c1[nH]c(C=NO)c(-c2ccc(OC)c(OC)c2OC)c1Br',
#  'O=C(N=c1[nH]nc(-c2ccccc2)s1)c1ccc(Cl)c(S(=O)(=O)N2CCOCC2)c1',
#  'CCOC(=O)Cc1nc2ccccc2sc1=O',
#  'Oc1cc(N2CCN(c3ccc(F)cc3)CC2)c(O)n1-c1ccc2c(c1)OCO2',
#  'COc1ccc(-c2ccc3ncnc(-c4cccc(C(=O)N5CCN(C(C)=O)CC5)c4)c3c2)cn1',
#  'COc1cc(C(=S)N2CCOCC2)cc(OC)c1OS(=O)(=O)c1ccc(NC(C)=O)cc1',
#  'O=C(CC1=NC2(CCCC2)Cc2ccccc21)C(=O)NN=Cc1ccccc1O',
#  'COCC(C)(C)c1ccc(Cn2c(C(=O)O)cc3ncc(Cl)cc32)cc1',
#  'CCCCCc1cc(=O)oc2c(C(=O)CC(C)C)c(O)c(CC=C(C)C)c(O)c12',
#  'Cc1ccc(-c2cc(C(=O)Nc3ccc(S(=O)(=O)N4CC(C)OC(C)C4)cc3)[nH]n2)c(O)c1',
#  'NCCC(NCCC=C(c1ccccc1)c1ccccc1)C(=O)NCc1ccc(Cl)cc1',
#  'CNC(C)C(=O)NC(C(=O)N1CCCC1C(=O)NC(c1ccccc1)c1ccccc1)C(C)(C)C',
#  'COc1ccc(C2CN(CCc3ccc(OC)c(OC)c3)CC2CNC(=O)c2ccncc2)cc1',
#  'CCCN(C(=O)C(NC(=O)c1ccccc1)C(C)C)c1c(N)n(Cc2ccccc2)c(=O)[nH]c1=O',
#  'O=C(O)C=C(C(=O)C=Cc1ccccc1)C(=O)CCc1ccccc1',
#  'COc1cc2[nH]c(N3CCCN(C)CC3)nc(=NC3CCN(C)CC3)c2cc1OC',
#  'Cc1cccc(C)c1-n1nnnc1C(c1cccs1)N1CCN(CC=Cc2ccccc2)CC1',
#  'CCCC(C(=O)O)N1C(=O)C(=Cc2ccc(-c3ccc([N+](=O)[O-])cc3)o2)SC1=S',
#  'N=c1[nH]nnn1N=Cc1cccc(OCc2ccccc2Cl)c1',
#  'CCCOc1ccc(S(=O)(=O)NCc2cccnc2)cc1',
#  'CC(C)CC(NC(=O)N1CCn2c1nc1ccccc12)C(=O)N1CCCCC1',
#  'O=C(N=c1[nH]nc(SCc2ccc([N+](=O)[O-])cc2)s1)c1ccc(F)cc1',
#  'C#CCNC(=O)c1csc2nc(-c3ccccc3)cn12',
#  'CC=CC(=O)OCCOC(=O)C=Cc1ccc(OCCCCCCCCCCCCCCCC)cc1',
#  'CCCCC(CCCC)NC(=O)c1ccc2c(c1)OCO2',
#  'NC(=O)c1cncc2[nH]c(C3CCNCC3)nc12',
#  'Cc1cccc(OCCSc2nncn2C)c1',
#  'Cc1c(F)c(Oc2cccc(C(=O)N(C)C)c2)nc(Oc2cc(C(=N)N)ccc2N)c1F',
#  'CCn1c(SCC(=O)NCc2ccc3c(c2)OCO3)nnc1-c1cccs1',
#  'CCCCOCC(C)O',
#  'Cc1nc(COc2ccc(-c3nc4cc(C(=O)O)ccc4n3C3CCCCC3)cc2)c(-c2ccc(Cl)cc2)o1',
#  'O=C(CCNCCCN=c1c2c([nH]c3ccccc13)CCCC2)Nc1ccc2c(c1)C(=O)c1cccc3ccnc-2c13',
#  'Cn1cc(C2=C(c3cn(C)c4cc(N)ccc34)C(=O)NC2=O)c2ccccc21',
#  'CN(CCN1c2ccccc2Sc2ccc(Cl)cc21)S(=O)(=O)c1ccc(Cl)cc1',
#  'Fc1cc(Cl)ccc1C(c1cccnc1)N1CCN(c2ncccn2)CC1',
#  'Cc1ccc2nc(COC(=O)c3ccc(Cl)nc3)cc(=O)n2c1',
#  'CS(=O)(=O)N1CCN(c2ccc3ccc(C(=O)NCC4CCCO4)cn23)CC1',
#  'CC1CC(=O)N1CC#CC[N+](C)(C)C',
#  'O=C(Cn1cnc2c(nnn2Cc2ccc(F)cc2)c1=O)NCc1ccc2c(c1)OCO2',
#  'O=C1NCCOC2CN(C(=O)Cc3cccs3)CCC12',
#  'O=C1N(Cc2ccccc2)C(=S)NC1(c1ccc(Cl)cc1)c1ccc(Cl)cc1',
#  'CC[n+]1cc2cc(OC)c(OC)cc2c2ccc3cc(OC)c(OC)cc3c21',
#  'COc1ccccc1C=CC(=O)c1cccs1',
#  'CCC1C(=O)OCc2c1cc1n(c2=O)C(CC)c2c-1nc1ccccc1c2Cl',
#  'CN1N(c2ccccc2)C(=O)C2=NC=C(C(=O)c3ccccc3)C(=N)C21C',
#  'N=C(N)NCCCC1NC(CNC(=O)C2Cc3ccccc3O2)CCN(CC(c2ccccc2)c2ccccc2)C1=O',
#  'Cc1cccc(CCNc2cc(=O)[nH]c(=O)[nH]2)c1',
#  'Cc1nc(C)c(-c2cc[nH]c(=Nc3ccccc3Cl)n2)s1',
#  'CCCCCC(O)c1cc(C)ccc1C=CCC(=O)O',
#  'Cn1cc(NC(=O)c2ccc3cnc(=NC4CCCCC4N)[nH]n23)c(Cl)n1',
#  'COc1ccc(Cn2ccc(C)c(NC(=O)C(Cc3ccc(CC(=O)O)cc3)NC(=O)Cc3cccc4ccccc34)c2=O)cc1',
#  'CC(=O)Nc1cccc(N2CCN(CCCN=c3[nH]c4ccccc4n3-c3ccc(Cl)cc3)CC2)c1',
#  'Cc1csc(N2CCN(Cc3ccccn3)CC2)n1',
#  'COc1cc(CNn2[nH]nnc2=N)cc(Br)c1OCC(=O)NC(C)(C)C',
#  'CC(C)N1C(=O)C(=Cc2nc3ccccc3c(=O)n2-c2ccccc2)c2ccccc21',
#  'Cn1c(=Nc2c(Cl)ccc(CNC(=O)C(C)(C)C)c2Cl)[nH]c2cc(C(=O)NCC(F)(F)F)c(N3CCC(C(C)(C)O)CC3)cc21',
#  'Cc1ccc(CN2CCC(Oc3ccc(C(=O)NCc4ccccn4)cc3)CC2)o1',
#  'Cc1ccc(OCC(=O)N2CCC(Cc3ccccc3)CC2)c([N+](=O)[O-])n1',
#  'c1csc(-c2nc(CNCCCN3CCCC3)co2)c1',
#  'CN1CCC=C(c2nsnc2OCCCOCC(=O)NCCCN=c2c3c([nH]c4ccccc24)CCCC3)C1',
#  'CN(C)C(=O)CCC(CC(N)C(=O)O)C(=O)O',
#  'CC1NN=C(c2ccccc2)C1[N+](=O)[O-]',
#  'CCCCS(=O)(=O)N1CCC(N2CCC(Oc3ccc(S(=O)(=O)c4ccc5c(c4)OCO5)cc3)CC2)CC1',
#  'O=C(CN1CCSCC1c1ccccc1)N1CCOCC1',
#  'c1ccc(OCCCSc2nc3ccccc3[nH]2)cc1',
#  'COc1c(C(=O)NCC2CCCN2C2CCCCCC2)cc(Br)c2ccccc12',
#  'CCOC(=O)C1CCCN(C(=S)Nc2cccc(Cl)c2)C1',
#  'CC(C)(OCc1cc(F)cc(-c2cc(=NC(O)c3c[nH]c(=O)[nH]3)[nH]n2-c2ccccc2)c1)C(F)(F)F',
#  'NC1(c2ccc(-c3nc4ccc(O)cn4c3-c3ccccc3)cc2)CCC1',
#  'CNC(=O)c1cc2c(nc1N(C)C)CCN(S(=O)(=O)CC(C)C)CC2',
#  'CCC(C)(C)n1nnnc1CN(Cc1ccco1)Cc1cc2cc3c(cc2[nH]c1=O)OCO3',
#  'OCCNC1c2cc(Cl)ccc2-c2c(Cl)cc(Cl)cc21',
#  'CC1CCCC2(C1)OOC1(CCCC(C)C1)OO2',
#  'COc1ccc(-c2ccc(C(N)=O)cn2)cc1OC1CCCC1',
#  'Cc1cccc(N2CCN(Cc3coc(-c4ccc(Br)cc4)n3)CC2C)c1',
#  'CCN=c1ncc(C(=O)N2CCOC(CCCc3ccccc3)C2)c[nH]1',
#  'N#Cc1cccc(-c2ccc(-c3cccc(Cl)c3)n2CC(=O)N=C(N)N)c1',
#  'CCc1n[n+]([O-])c2ccc(OCCOC)cc2[n+]1[O-]',
#  'Cc1cccc(OCC(=O)NCCNC(=O)c2cccnc2)c1',
#  'CCNC(=O)Oc1ccc2c(c1)C13CCCCC1C(C2)N(C)CC3',
#  'CC(=O)c1ccccc1NC(=O)CSCc1nc(=O)c2c(C)c(C)sc2[nH]1',
#  'Cc1ccc(S(=O)(=O)Nc2ccc(C(=O)NCCCN3CCOCC3)cc2)cc1[N+](=O)[O-]',
#  'CCC(c1ccc(O)cc1)C(CC)c1ccc(OCC(=O)CCl)cc1',
#  'O=C(N1CCC(c2cn[nH]c2)C1)N1CCNc2ccccc21',
#  'COc1cc(C#N)c(NC(=S)C#N)cc1OC',
#  'Cc1[nH]c2nc(=NC(C)c3cccc(Cl)c3)[nH]n2c(=O)c1C',
#  'CCCCCC12CC1(C(=O)OCC)C(=O)Nc1ccc(Br)cc12',
#  'CC(=O)N1CCN(c2ccc(C(N)=O)cc2[N+](=O)[O-])CC1',
#  'CN(C)CCCNC(=O)c1cc(NC(=O)c2cc(NC(=O)c3cc(NC(=O)c4cc5ccccc5cn4)cn3C)cn2C)cn1C',
#  'Cc1ccc(O)c2[nH]c(Cc3ccc(O)cc3)nc12',
#  'O=C(Nc1ccccc1)N1CCCC(c2nc(-c3ccc(F)cc3)no2)C1',
#  'Cc1cccc(CCN2C(N(C)C)=NCC2CC(C)C)c1',
#  'Cc1cc2c(=O)n(CC(=O)NCC(=O)N3CCN(Cc4ccccc4)CC3)cnc2s1',
#  'CC(=O)CC(=O)NC1CCc2ccccc21',
#  'CC1CN(C(=O)c2cc3ccccc3o2)CCN1C(=O)Nc1ccc([N+](=O)[O-])cc1',
#  'CCC(=O)N(C1CCCCCCC1)C1CCN(CCCOc2ccc(F)cc2)CC1',
#  'COC(=O)c1sc(-c2ccc(Cl)c(Cl)c2)nc1C(Br)Br',
#  'CCOC(=O)C1C(=O)NC(C)C1c1ccccc1',
#  'Clc1ccc2c(=NCCCCCCCCCCN=c3cc[nH]c4cc(Cl)ccc34)cc[nH]c2c1',
#  'CC(=O)NC1C(=O)CC(C(=O)O)OC1OCC(C)C',
#  'COc1ccc(C2C=C(c3ccccc3)CC(=O)C2)cc1',
#  'CN1C(=O)c2c(c3c4ccccc4n(CC(=O)NC(Cc4ccccc4)C(=O)O)c3c3[nH]c4ccccc4c23)C1=O',
#  'CC1(C)CC(=O)C(C2c3ccccc3S(=O)(=O)c3ccccc32)C(=O)C1',
#  'N=c1[nH][n+]([O-])c2cc(F)ccc2[n+]1[O-]',
#  'N=c1[nH]c(=O)c2ncn(C3OC4(CO)COC3C4O)c2[nH]1',
#  'O=C(NCCCNC(=O)C1CCC1)NCCn1cccc1',
#  'O=C(NCCCCCCNC(=O)c1ccc(O)c(O)c1)c1ccc(O)c(O)c1',
#  'COc1ccc(NC(=O)C2CCCN2S(=O)(=O)c2ccccc2F)cc1S(=O)(=O)N1CCCCC1',
#  'COc1cc2c(cc1OCCCCCOc1c(OC)cc(-c3cc(-c4cc(OC)c(OC)c(OC)c4)on3)cc1OC)N=CC1CCCN1C2=O',
#  'Cc1nn(C)c(C)c1N(C)S(=O)(=O)c1c(Cl)cc(CCCN2CCNCC2)cc1Cl',
#  'Cc1cccc(CN(CCC(=O)O)Cc2ccc(C(=O)O)c(C(=O)O)c2)c1',
#  'Cc1cc(=Nc2nc(Sc3ccc(NC(=O)CN4CCC(OCCCN5CCOCC5)C4)cc3)nn3cccc23)[nH][nH]1',
#  'COc1cc2c(cc1OC)C(=O)C(C(=O)OCC1CCCN1Cc1ccccc1)C2',
#  'CSc1ccc(C(=O)C#Cc2ccc(S(C)(=O)=O)cc2)cc1',
#  'CCCCN(c1sc2ccccc2c1Cl)S(=O)(=O)c1ccc(N(C)C)cc1',
#  'CC(C)(C)c1cc(C(=O)CCC2CC2)cc2c1OCC2(C)C',
#  'CN(C)CCc1ccc(N=C=S)cc1',
#  'Clc1ccccc1N=c1[nH]c(-c2ccccc2)nc2ccccc12',
#  'Cc1ccc(C(=O)NC(Cc2ccc(OCCc3ccccc3)cc2)C(=O)O)cc1',
#  'CCN(CC)CCCCCOc1ccc2c(=O)c3ccc(OCCCCCN(CC)CC)c(F)c3oc2c1F',
#  'COc1ccc(CN2C(=O)c3ccccc3C2=O)cc1C(=O)Nc1ccccc1N1CCOCC1',
#  'CCOC(=O)CC(=O)NCCCCC(NC(=O)OCc1ccccc1)C(=O)Nc1ccccc1',
#  'CC(CCCC(C)(C)O)C1CCC2C3C(O)CC4CC(O)CCC4(C)C3CCC12C',
#  'COc1cc(NC(C)CCCN)c(OC)c2c(C)cc(C)nc12',
#  'Cc1cncc(Oc2ccc(NC(=O)N=c3cc(Cl)[nH]c4ccccc34)cc2)n1',
#  'O=C(CCc1ccccc1)NC(NC(=S)Nc1ccc(Br)cc1)C(Cl)(Cl)Cl',
#  'COCc1noc(C2=CCCN(C)C2)n1',
#  'CC(C)C(=O)NNC(=O)c1c(O)c2ccccc2n(C)c1=O',
#  'CCOC(=O)c1cn2[nH]cc(C#N)c(=NCc3ccc(Oc4ccccc4)cc3)c2c1C',
#  'Cc1ccc(CNC(=O)Cn2c(=O)n(-c3ccc(C)cc3)c(=O)c3c2c2cc(C)ccc2n3C)cc1',
#  'Cc1cn(C2CC(O)C(CNC(=O)c3cccc(S(=O)(=O)F)c3)O2)c(=O)[nH]c1=O',
#  'Cc1ccc2c(c1)c(-c1ccc(=O)n(Cc3ccccc3)n1)c(C)n2CC(=O)O',
#  'CNC(C)C(=O)NC(C(=O)C1CCCC1C(=O)NC(c1ccccc1)c1ccccc1)C1CCCCC1',
#  'NC(=O)Nc1sc2c(ccc3nn(Cc4ccncc4)cc32)c1C(N)O',
#  'CC(=O)OC1CCC2(C)C(CCC3(C)C2CC=C2C4CC(C)(C)CCC4(C)CCC23C)C1(C)C',
#  'CC(C)c1cc(OC(=O)NC(CCC(=O)O)C(=O)O)ccc1N(CCCl)CCCl',
#  'Cc1ccc(C(C)C)c(OCCSc2nc(-c3cccs3)nc3cc(=O)[nH]n23)c1',
#  'CCOC(=O)C1CCN(c2ncnc3c2[nH]c2cccc(OC)c23)CC1',
#  'Cc1ccc(-n2nc3c(=O)n(CCCC(=O)NCCN4CCN(C)CC4)nc(C)c3c2C)cc1',
#  'O=S(=O)(NCCCN=c1c2ccccc2oc2[nH]c3ccccc3c12)c1ccccc1',
#  'CC12CCC3c4ccc(O)cc4CCC3C1CC(Cc1ccccc1)C2O',
#  'COCC1CCN(c2nc(C(F)(F)F)ccc2CNC(=O)C(C)c2ccc(NS(C)(=O)=O)c(F)c2)CC1',
#  'O=C(Cc1ccc(C(F)(F)F)cc1)N1CCc2ccccc2C1CN1CCCCC1',
#  'CC(Cl)=CCC(=O)N(Cc1ccc(O)cc1)CC(C)C',
#  'COc1cc(CN(CC(C)C)C(CC(=O)O)c2ccc(Cl)c(F)c2)ccc1OCCn1c(O)ccc1O',
#  'CN=c1cccc(CN=c2cccc(CCN=c3cccc[nH]3)[nH]2)[nH]1',
#  'CCCCCCCCCCCCOc1c(CC)cc(Cc2c[nH]c(=N)[nH]c2=N)cc1CC',
#  'CC(CCn1ccnc1)Oc1ccccc1[N+](=O)[O-]',
#  'Brc1ccc(SC2CN3CCC2CC3)cc1',
#  'Cn1ccc2ccccc21',
#  'COc1cc(CN2C(=O)N(Cc3cccc(C(=O)N=c4cncc[nH]4)c3)C(Cc3ccccc3)C(O)C(O)C2Cc2ccccc2)cc(OC)c1',
#  'CCN(C(=O)C=Cc1ccc(OC)cc1)C1CCCCC1',
#  'NC(=O)N1CCCc2cc(-c3cncc(C(=O)N4CCCC4)c3)cnc21',
#  'COC(=O)c1cc2cc3c(cc2c2cc(OC)c(OC)cc12)OCO3',
#  'O=C(Cn1c(C2CC2)nc2cc(Cl)c(Cl)cc21)NN=Cc1cc(Cl)ccc1O',
#  'Cc1nc(C)c(-c2csc(=Nc3ccc(C(=O)N4C5CCC4CN(c4ncc(S(C)(=O)=O)cn4)C5)cn3)[nH]2)s1',
#  'COc1ccc2cnn(-c3ccc(OC(F)(F)F)cc3)c(=O)c2c1OC',
#  'CCCCCCCCCCN1CC(=O)C(O)C1O',
#  'O=Cc1cccc(C=O)c1',
#  'O=C(NC(=O)N1CCCCC1)c1ccccc1',
#  'COc1ccccc1CN(CC(=O)NCC1CCCO1)C(=O)CNS(=O)(=O)c1ccc(C)cc1',
#  'CCCC#CC=CC#CCCCCCC1OC(C)(OC)C(C)(OC)OC1=O',
#  'CC1=NC(=O)CC(c2c(Cl)cccc2Cl)C1C(=O)OC1CCCC1',
#  'COC(=O)c1ccc(N2C(=O)NC(=O)C(=Cc3ccccc3OCc3ccc(C(=O)O)cc3)C2=O)cc1',
#  'Cc1ccc(O)c(C(=O)NCCCCN2C(C)CCC3CCCCC32)c1',
#  'CC1(c2ccc(F)cc2)NC(=O)N(CC(O)CN2CCN(c3ccccc3C#N)CC2)C1=O',
#  'CN(C)CCc1c[nH]c2ccc(CCCc3nc(Cc4ccccc4)no3)cc12',
#  'Cn1c(=O)c2nc3c4ccccc4c(=O)n(C)c3nc2n(C)c1=O',
#  'O=C(C=Cc1cncc(F)c1)NCCCCN1CCN(C(c2ccccc2)c2ccccc2)CC1',
#  'CCOC(=O)c1c(-n2c(O)c3c(c2O)CC(C)=C(C)C3)sc(C)c1C',
#  'CN(C1CCc2c(c3ncccc3n2CC(=O)O)C1)S(=O)(=O)c1ccc(F)cc1',
#  'O=C(O)CCNC(=O)c1ccc(-c2ccc(Cl)cc2CNc2ccc(-c3ccc(Cl)cc3)cc2)cn1',
#  'CCc1nc2c(C)cc(C)nc2n1Cc1ccc(O)c(Cl)c1',
#  'CC(C)(C)OC(=O)NCCCCCCOc1ccc(S(N)(=O)=O)cc1',
#  'CCOc1ccc(C=C2SC(=O)N(CCNC(=O)C3COc4ccccc4O3)C2=O)cc1OC',
#  'CC(C)(C)c1ccc(C2=CCC(C)(C)c3ccc(C#Cc4ccc(C(=O)O)cc4)cc32)cc1',
#  'Cc1cccc(CN2CCC(NC(=O)c3ccc4ccccc4c3)CC2)c1',
#  'CCC(Cc1ccccc1)N(O)C(=O)Cc1ccc(OCc2ccccc2)cc1',
#  'O=[N+]([O-])c1ccc(SCC2CCCCC2)c2nonc12',
#  'CCCCc1ccc2[nH]c(=NC(=O)OC)[nH]c2c1',
#  'Cc1ccc(C)c(-c2n[nH]c(=NC(=O)c3ccc([N+](=O)[O-])o3)o2)c1',
#  'CC(C)c1cccc(C(C)C)c1OC(=O)NS(=O)(=O)Oc1c(C(C)(C)C)cccc1C(C)(C)C',
#  'CCOC(=O)NCC(C)(C)NCC(O)COC(=O)c1ccccc1F',
#  'CCc1cc(C(=O)NCC2CCCO2)sc1C',
#  'CCOc1ccc2[nH]c(=NC(=O)CSc3nnc(-c4cc5ccccc5oc4=O)o3)sc2c1',
#  'CC(=O)Oc1cc(O)c2c(c1)CC(C)OC2=O',
#  'O=C(CCc1cccc(F)c1)c1sc2ncccc2c1-c1ccc(F)cc1',
#  'COc1ccc(C2CC(=O)CC(c3ccco3)C23C(=O)OC(C)(C)OC3=O)cc1OC',
#  'CCC(C)CC(C)CCC(=O)OC1C(O)C2(CCCC(=O)C(C)Cc3ccccc3)OC(C(=O)O)C(O)(C(=O)O)C1(C(=O)O)O2',
#  'CNS(=O)(=O)c1cccc(C(C)NCc2nccn2C(C)C)c1',
#  'Clc1ncnc2[nH]c(-c3cscn3)nc12',
#  'c1ccc(-c2cn(CC3CCC(Cn4cc(-c5ccccn5)nn4)O3)nn2)nc1',
#  'CCOC(=O)C(=O)Nc1ccc([N+](=O)[O-])cc1C#N',
#  'O=C(NCc1ccc(F)cc1)c1nc2c(Cl)cc(N3CCOCC3)cn2c(=O)c1O',
#  'CCCCCCN=c1[nH]c2ccccc2n2cncc12',
#  'C=C1C(=CC=C2CCCC3(C)C2CCC3C(C)CCCC(C)(C)O)CC(O)C(=C)C1O',
#  'CC(=O)Nc1ccc(N2C(=O)CSC2c2cccc(Br)c2)cc1',
#  'CC1(C)C=Cc2c(ccc(C(=O)C=Cc3cc(Cl)ccc3O)c2O)O1',
#  'CCOC(=O)C(C)[n+]1ccccc1',
#  'COCCN1CC2C(C1)C2c1cc(-c2c[nH]c(=N)c(Oc3ccccn3)c2)nc(C2CC2)n1',
#  'Cc1cccc(CC(=O)Nc2c(C(=O)Nc3cccc(F)c3)oc3ccccc23)c1',
#  'c1csc(-c2ccnc3ncnn23)c1',
#  'CC=Cc1ccc(C2C3CN(Cc4cccc(F)c4)CC2N3)cc1',
#  'CC1C2N=C(NC#N)NC1c1ccccc1O2',
#  'O=C(c1ccc2c(c1)N(Cc1ccc(Cl)cc1)C(=O)c1ccccc1S2(=O)=O)N1CCC(Cc2ccccc2)CC1',
#  'CCC(C)C(NC(=O)C(C=O)NC(=O)CCc1cccnc1)C(N)=O',
#  'Clc1ccc(-c2c(Cn3cncn3)c(-c3nnc(C4(c5ccc(Cl)cc5)CC4)s3)nn2-c2ccccc2Cl)cc1',
#  'O=C(Oc1ccccc1)c1cc(-c2cc3ccccc3o2)nc2ccccc12',
#  'COC(=O)CNC(=O)CN(c1ccc(OC)cc1OC)S(=O)(=O)c1ccccc1',
#  'O=C1NC(=O)C(=Cc2ccc(-c3ccc(F)c(Cl)c3)o2)S1',
#  'CN(C)CCCNC(=S)N1CCn2c(nc3ccccc32)C1',
#  'C[N+]12CCC(C1)C1(CC(c3ccccc3)=NO1)C2',
#  'COc1ccc(Cn2ccc(C)c(NC(=O)C(Cc3ccc(C(C)(C)C(=O)O)cc3)NC(=O)C(C)(C)c3ccc4ccccc4c3)c2=O)cc1',
#  'CCCCCCCCCn1c(-c2cccc(Cl)c2)n[nH]c1=S',
#  'CC(C)(C)N(Cc1ccccc1)C(=O)C=C[S+]([O-])c1ccccc1',
#  'CCCN1CCN(C(=O)C2CCN(S(=O)(=O)c3c(C)noc3C=Cc3ccc(C)cc3)CC2)CC1',
#  'COc1cc(-c2cn(C3CCCCNC3=O)nn2)ccc1-n1cnc(C)c1',
#  'CC[n+]1cccc(NC(=O)c2ccc(NC(=O)c3ccc(C(=O)Nc4ccc(C(=O)Nc5ccc[n+](CC)c5)cc4C)cc3)c(C)c2)c1',
#  'Cc1cc(CCc2cccc(C(N)Cc3cc(C)cc(=N)[nH]3)c2)[nH]c(=N)c1',
#  'O=C(O)c1ccc(O)c2nc(C=Cc3ccc(O)c(O)c3)ccc12',
#  'Cc1cccn2c(=O)nc(SCc3cccc(F)c3)nc12',
#  'COC1=CC(=O)OC(CCc2ccc3c(c2)CCC3)C1',
#  'Cc1ccc(C(C(=O)NC(C)(C)C)N(CCCN2CCOCC2)C(=O)c2ccc(-c3ccccc3)[nH]2)o1',
#  'COc1ccc(C=Nc2nc(=NC3CC3)c3ncn(C4C=CC(CO)C4)c3[nH]2)c(O)c1',
#  'CCCCCCCCCc1ccc(CC(N)(CO)CO)cc1',
#  'CN(C)c1ccc(C(CNC(=O)c2ccccc2Br)c2c[nH]c3ccccc23)cc1',
#  'CC1=Nc2cc(-c3ccccc3)cc(NN=C(N)N)c2CC1',
#  'S=C1SSCCN1CCCCC1CCCCC1',
#  'NC(=O)C1CCCCC1',
#  'CCCCCCCC(O)C1=CC(=CBr)OC1=O',
#  'O=C(O)CS(=O)(=O)c1ccc(C(=O)NCC(c2cccnc2)N2CCOCC2)cn1',
#  'Cn1cncc1C(O)(c1ccc(C#N)cc1)c1cc2cc([N+](=O)[O-])cc(-c3ccccc3)c2o1',
#  'Cn1ncc(NC(=O)c2nc(-c3c(F)cccc3F)sc2N)c1N1CCC(N)CC2(CCO2)C1',
#  'CC(C)c1cc(=NCC(O)c2ccccn2)n2[nH]ccc2n1',
#  'CC12CCC(C(=O)N3CCN(C(c4ccccc4)c4ccccc4)CC3)(OC1=O)C2(C)C',
#  'N#Cc1ccc(C2CCN(CCC(N)Cc3ccc(Cl)s3)CC2)cc1',
#  'CCCCOC(=O)c1c[nH]c2ccccc2c1=O',
#  'Cn1cc(S(=O)(=O)NCCc2ccsc2)cn1',
#  'CN(C)c1cc[n+](CCCCOc2ccc(C(=O)NCCc3c[nH]c4ccccc34)cc2)cc1',
#  'Cn1nc2c(nc1=O)c(=O)n(C)c(=O)n2C',
#  'CC(=O)N1N=C(c2ccc([N+](=O)[O-])cc2)CC1c1ccc(-c2ccc(Cl)c(Cl)c2)o1',
#  'CCOc1cc(S(=O)(=O)NCCc2c(C)[nH]c3ccc(C)cc23)ccc1F',
#  'CCn1c2nc(N(C)CCO)nc(=O)c-2cc2cc(C)ccc21',
#  'CN(O)C(=O)c1ccccc1Sc1ccc2c(C=Cc3ccccn3)[nH]nc2c1',
#  'Clc1ccc(Cn2ncc3c(=NCc4ccco4)[nH]cnc32)c(Cl)c1',
#  'Cn1cncc1C(O)(C#Cc1ccc(Cl)cc1)c1ccc(C#N)c(-c2cccc3ccccc23)c1',
#  'O=C(CCc1nc(-c2cccs2)no1)Nc1ccccc1[N+](=O)[O-]',
#  'Cc1ccc2cc3c(=NC(=O)c4cccnc4)[nH]n(C)c3nc2c1',
#  'COc1ccc(-c2noc(-c3ccc(O)cc3)n2)cc1OC',
#  'CC(C)c1ccccc1NC(=O)c1c[nH]c2ccccc2c1=O',
#  'N=c1[nH]c2cc(O)ccc2n2cc3c(F)cccc3c12',
#  'CC1CC(C)(C)CC2(C1)NC(=O)N(CC(=O)N(C)Cc1nc(=O)c3ccccc3[nH]1)C2=O',
#  'CC12Cc3cnn(-c4ccc(F)cc4)c3C=C1CCC2(O)CCc1ccccc1C(N)=O',
#  'CC(=O)c1cccc(N2C(=O)CN(c3cccc(C(F)(F)F)c3)CC2C(=O)NC2CCCC2)c1',
#  'O=C(O)CCCCCCOc1cc(O)cc2oc(-c3ccc(O)cc3)cc(=O)c12',
#  'Cc1ccc(OCCCOc2ccc(Cl)cc2Cl)c([N+](=O)[O-])n1',
#  'CC1(C)C(C(=O)NCCc2csc(Cl)c2)C1(Cl)Cl',
#  'Cc1noc(C)c1COC(=O)c1cnc(Cl)c(Cl)c1',
#  'COCCOc1nc(=NS(=O)(=O)NCc2ccccc2)c(Oc2ccccc2OC)c(OCCOc2ncc(Br)cn2)[nH]1',
#  'CC1(C)COC(CCNC(CCC(=O)O)C(=O)O)OC1',
#  'O=[N+]([O-])c1ccc2[nH]c(-c3ccccc3Cl)nc2c1',
#  'CCCC1CCCC(C=CC(O)CC(O)CC(=O)O)C1COC(=O)C(C)(C)CC',
#  'CCOC(=O)c1cn(-c2c(F)c(F)c(F)c(F)c2F)c2c(F)c(F)c(F)c(F)c2c1=O',
#  'Cc1cccc(C)c1-c1cc2c[nH]c(=Nc3ccccc3)nc2n(C)c1=O',
#  'O=C(NC1CCCCC1)N1CCN(c2ccc([N+](=O)[O-])cc2)CC1',
#  'CC1=CC(C)(C)Nc2ccc3c(c21)C(=Cc1ccc(C)cc1)Oc1ccccc1-3',
#  'CC1(C)Cc2c(ccc3ccccc23)C(c2cc3ccccc3oc2=O)=N1',
#  'O=c1cc(-n2cc(COc3ccc(C(F)(F)F)cc3)nn2)c2cc(Br)ccc2o1',
#  'C[n+]1ccn(CC(O)c2ccc(NS(=O)(=O)C(F)(F)F)cc2)c1',
#  'COc1ccc(-c2ccc(NC(=O)c3ccc(Br)o3)cc2)nn1',
#  'CS(=O)(=O)c1ccc(NN2C(=O)CSC2c2ccc(C(F)(F)F)cc2)cc1',
#  'CN=c1c(C(=O)c2ccccc2F)c(C)[nH]n1C',
#  'COC(=O)c1c(C)cc2[nH]c(C(O)OCC3CCCO3)c(C)c2c1O',
#  'NC(=O)c1c[nH]c(=NC2CCC2)c2c1[nH]c1ccc(F)cc12',
#  'CC(C)(C)CCN1CCC(CNC(=O)c2cccc(Cl)c2)CC1',
#  'CN(C)CCN(C)c1cc(-c2ccccc2)c2ccccc2n1',
#  'CC(C)(C)OC(=O)NC(C(=O)N1CC2C(C1C(=O)NC(CC1CC1)C(=O)C(N)=O)C2(C)C)C1Cc2ccccc2C1',
#  'CNC(=O)C(NC(=O)C(CC(C)C)C(NCc1ccc2ccccc2c1)C(O)=NO)C(C)(C)C',
#  'c1cc(=NCc2ccc3c(c2)OCO3)n2[nH]cc(-c3ccoc3)c2n1',
#  'CC(C)c1cc2c(cc1OC=O)C1(C)CCCC(C)(C)C1CC2',
#  'Oc1ccc(CCN=c2[nH]c(N3CCNCC3)nc(=NCCCOc3ccccc3-c3ccncc3)[nH]2)cc1',
#  'N=c1nc2c(c[nH]1)C(N1CCCCC1)Oc1ccccc1-2',
#  'O=C1CCCN1C1CCN(Cc2coc3cc(Oc4nc5ncccc5s4)ccc23)CC1',
#  'CSc1[nH]n(C)c(=NCCCN=C=S)c1C#N',
#  'CC(C)(O)C#Cc1cc2c(cc1F)C1CC(C1)n1c-2nc(C(N)=O)c1CN1CCCC1',
#  'O=C(OCC(OC(=O)c1ccccc1)C(COC(=O)c1ccccc1)OC(=O)c1ccccc1)c1ccccc1',
#  'CC(=O)N1CC2CC1CN2Cc1coc2cc(Oc3nc4cccnc4s3)ccc12',
#  'CCCC(C)C(=O)N=c1[nH]c(C)c(-c2csc(=Nc3cc(OC)ccc3OC)[nH]2)s1',
#  'CC(C)c1cccc(C(C)C)c1NC(=O)C1c2ccccc2COc2ccc([N+](=O)[O-])cc21',
# ...
#  'COC12CCC(=O)CC13CCN(CC1CC1)C2Cc1cccc(OCc2ccccc2)c13',
#  'COc1cc(Cn2c(-c3ccccc3)nc3cc(C)ccc32)cc(OC)c1OC',
#  'CC(C)(SCc1ccccc1)C(N)C(=O)NC(C(=O)O)C1OC(n2ccc(=O)[nH]c2=O)C(O)C1O',
#  'Cc1nc2ccccc2c2ncccc12',
#  'O=C(O)C1CCCN1C(=O)c1cccc(COc2ccc(-c3cccc4[nH]ccc34)cc2)c1',
#  'C=CCn1c(SCc2ccccc2C#N)nnc1-c1cc(Br)ccc1O',
#  'CCOc1ccc(N2CC(NC(=O)c3ccc(Cl)cc3)CC2=O)cc1',
#  'O=c1cnn(-c2ccc(Sc3ccc(Cl)cc3)c(Cl)c2)c(=O)[nH]1',
#  'COc1cc2c(OCC3NC(=O)C4(F)C(C)C34)nccc2cc1C(N)=O',
#  'CC1=CC(C)(C)N(Cc2ccccc2)c2ccc(OC(=O)c3ccccc3)cc21',
#  'Cc1c(-c2cc3ccccc3cn2)oc2ccccc2c1=NO',
#  'CCCC(=O)Nc1cc(C=CC(=O)N2CC(CCl)c3c2cc(OCc2ccccc2)c2[nH]cc(C)c32)n(C)c1',
#  'O=C(Cn1cc([N+](=O)[O-])ccc1=O)NCc1ccc(Cl)cc1Cl',
#  'CSc1cccc(NC(=O)CN2CCN(Cc3ccccc3C)S2(=O)=O)c1',
#  'CN1CCCN(c2cncc(-c3cccc(C=CC4=NNNN4)c3)n2)CC1',
#  'COc1cc2c(=O)c(C(=O)c3ccc(C)c(C)c3)cn(Cc3ccc(F)cc3)c2cc1OC',
#  'CC(C)C(=O)c1c(O)c(O)n(-c2ccc(-c3ccon3)cc2)c1-c1ccccc1OC(F)F',
#  'COc1ccc(N2C(=O)NC(NS(=O)(=O)c3ccc(NC(C)=O)cc3)(C(F)(F)F)C2=O)cc1',
#  'Cc1cc(=N)n(-c2ncnc3scc(-c4ccc(Cl)cc4)c23)[nH]1',
#  'N=C1NC(c2ccccc2C(F)(F)F)CO1',
#  'COc1ccc(NC(=O)C(=NNc2cc(S(=O)(=O)Nc3ccc(OC)cc3)ccc2OC)C(C)=O)cc1',
#  'CCOC(=O)c1sc(-c2ccccc2)cc1NC(=O)Nc1ccc([N+](=O)[O-])cc1',
#  'CC(C)(C)NC(=O)NCC1Cc2ccccc2CN1C(=S)NCC1CCCN1Cc1ccccc1',
#  'CCCCCCCCCCCCCC=C1CCCC(O)C1N(CC)CC',
#  'N=c1ncc(-c2cc(N3CC4CC3CO4)nc(N3CCCC3)n2)c[nH]1',
#  'Cc1cccc(C)c1C(=O)N1CCC(N2C3CCC2CC(N(Cc2ccccc2)C(=O)C2CC2)C3)CC1',
#  'O=C(N1CCCC1)n1cnc(SCc2ccccc2)n1',
#  'CN(C)CCC=C1c2ccccc2Sc2c(O)cc(Cl)cc21',
#  'CCN(CC)CCN(C(=O)c1cc2c(ccc3ccccc32)oc1=O)c1nc2cc3c(cc2s1)OCCO3',
#  'CC(=O)c1ccc(S(=O)(=O)N2CCN(C(=O)C=Cc3ccc4ccccc4n3)CC2)cc1',
#  'CC1CC1c1nc(-c2c[nH]c(=N)c(OC(F)F)c2)cc(N2CC3CC2CO3)n1',
#  'COCC#CCOc1[nH]c(-c2ncccn2)nc(=NS(=O)(=O)c2ccc(C(C)(C)C)cc2)c1Oc1ccccc1OC',
#  'O=C1CCN(Cc2ccccc2)CC1=Cc1c[nH]c2ccccc12',
#  'O=C(C=Cc1cnc2ccccc2n1)c1ccc(O)cc1',
#  'CC(C)(C)c1ccc(COc2cccc3[nH][nH]c(=NCCCC(=O)O)c23)cc1',
#  'Cc1c(C2CCCN(C(=O)c3ccncc3)C2)n2c(nc1=O)CCC2',
#  'CC1CC1C(=O)NC1CCN(CC2(c3ccccc3)CCCCC2)CC1',
#  'O=C(O)c1ccc2c(C3CCCCC3)c(-c3cnccn3)n(CC(=O)N3CCOCC3)c2c1',
#  'CC(c1ccncc1)N1CCN(Cc2ccc(-c3ccc(C(O)(C(F)(F)F)C(F)(F)F)cc3)cc2)CC1',
#  'COC(=O)C1CN=CN1CCc1ccccc1',
#  'O=S(=O)(Cc1cc(-c2ccccc2)no1)CC1CCCO1',
#  'Cc1ccc(-c2c(C#N)c(N)c(C#N)c3c2SC(c2ccc(C)cc2)C3)cc1',
#  'Cc1ccc(Cl)cc1N1CCN(C(=O)c2cn(C3CCCCC3)c(=O)c3c2c2ccccc2n3C)CC1',
#  'Cc1ccc(NC(=O)C2Cc3ccccc3N2C(=O)OC(C)(C)C)cc1',
#  'c1nc(N2CCC3(CC2)OCCO3)c2[nH]cnc2n1',
#  'N#Cc1ccsc1N1CCC(Sc2ccncc2)C1=O',
#  'Cc1ccc(S(=O)(=O)N2CCOCC2)cc1C(=O)N=c1cc[nH]cc1',
#  'Cc1c(OCC(C)C)ccnc1CCc1nc2ccccc2s1',
#  'O=S(=O)(c1cccc2ccccc12)N1CCC(CCCC(O)=NO)CC1',
#  'COc1cc(C(=O)N2CCc3ccccc32)ccc1OCc1c(C)noc1C',
#  'Cc1c(C(=O)c2ccc3ncccc3c2)c2cccc3c2n1C(CN1CCOCC1)CO3',
#  'Oc1cccc2c(O)c3c(O)cccc3cc12',
#  'OC(c1ccc(F)cc1)c1nc(-c2cccs2)cs1',
#  'CC(=O)C1CCOC1=O',
#  'CCCCC(OC(=O)CN(CC)CC)c1ccccc1C(=O)Oc1ccc(C=CC(=O)NCCCO[N+](=O)[O-])cc1',
#  'COc1cccc(C=Nc2ccc(C)c(F)c2)c1O',
#  'Clc1ccc2ccc(COc3cccc(CN4CCc5cccc(CCc6nn[nH]n6)c54)c3)nc2c1',
#  'CN(Cc1ccccc1)C(=O)c1cccc(C(=O)N(C)Cc2ccccc2)c1',
#  'CCCCCCCCCCCCCCCCN(C=O)c1ccc(C(=O)O)cc1',
#  'O=C(CCc1ccccc1)N=c1[nH]nc(CCSCCc2n[nH]c(=NC(=O)CCc3ccccc3)s2)s1',
#  'COc1cc(C(=O)N2COC(CCN3CCC(O)(c4cccnc4)CC3)(c3ccc(Cl)c(Cl)c3)C2)cc(OC)c1OC',
#  'COCCC1CCN(C2c3ccccc3C3(CCNCC3)C2O)CC1',
#  'Cc1c(NC(=O)COC(=O)CCC(=O)c2ccc(Cl)cc2)c(=O)n(-c2ccccc2)n1C',
#  'O=c1ccc(C(F)(F)F)cn1Cc1ccc(F)cc1',
#  'CCc1ncc(CN2CCC(C(=O)Nc3cccc(-c4cscn4)c3)CC2)cn1',
#  'CC1CCCCC12NC(=O)N(CC(=O)OCc1ccccc1Cl)C2=O',
#  'CC(=O)Nc1cccc(NC(=O)C2(c3cccs3)CCOCC2)c1',
#  'COc1ccc(N=c2[nH]cnc3ccc(-c4ccc(S(=O)(=O)N5CCOCC5)cc4)cc23)cc1Cl',
#  'Cc1ccc(C(=O)OCC(=O)Nc2sc3c(c2C#N)CCCCC3)cc1NC(=O)c1ccco1',
#  'Cc1nc(C)n(CC2CCCN(Cc3nnc(C(C)(C)C)o3)C2)n1',
#  'COc1ccc2c3c([nH]c2c1[N+](=O)[O-])C(C)=NCC3',
#  'COc1cc(OC)cc(N2C(=O)N(Cc3cccc(C(=O)N=c4cncc[nH]4)c3)C(Cc3ccccc3)C(O)C(O)C2Cc2ccccc2)c1',
#  'COc1ccccc1C1C(C(N)=O)C(C)=Nc2nc(-c3ccccc3Cl)nn21',
#  'CC(Cc1cc2ccccc2[nH]1)NC(=O)C(N)CC(=O)O',
#  'COc1cc(OC)c(S(=O)(=O)N2c3ccccc3CCC2C)cc1NC(=O)C1C(C)C1C(=O)O',
#  'N=C(NCCc1c[nH]cn1)NC(=O)CC(c1ccccc1)c1ccccc1',
#  'CCCCCCCCCCCCCC#CCCCCC(=O)O',
#  'O=C(CCc1ccc(-c2ccccc2)cc1)c1ncc(-c2cccnc2)o1',
#  'COc1ccc(C(=O)NCCCCCC(=O)O)cc1OC',
#  'CC1=C(C)C(=O)OC(C2(C)OC(=O)C34CCC5C(CC6OC67C(=O)CCC(=O)C57C)C3CCC24)C1',
#  'COC(=O)C1=CCCC2C13CCC(C)C21CC(c2ccoc2)OC1OC3O',
#  'Cn1cnnc1SCCC(=O)Nc1ccccc1',
#  'Cc1ccc(=NC(=O)c2ccc3c(c2)OCCO3)[nH]c1',
#  'CC12CCC(OC(=O)C3CCCCCC3)CC1=CCC1C2CCC2(C)C(Cl)=C(C=O)CC12',
#  'COc1ccccc1CC(=NC(=O)c1cccc(C)c1)C(=O)N=c1cccc[nH]1',
#  'O=C(Nc1ccc2c(c1)S(=O)(=O)N(Cc1ccc(C(O)=NO)cc1)C2=O)c1ccc(C(F)(F)F)cc1',
#  'CCNC(=O)NC(=O)C(C)OC(=O)c1c(C)nn(Cc2ccccc2)c1Cl',
#  'CCN(CC)CCn1nc2c3c(c(N)ccc31)Sc1cc(O)ccc1-2',
#  'CN1CCN(c2nc(C3=C(c4c[nH]c5cccc(Cl)c45)C(=O)NC3=O)c3ccccc3n2)CC1',
#  'COc1ccc(CC(=O)O)cc1-c1ccc(F)c2c1CN(C(=O)CC1Cc3ccccc3C1)CC2',
#  'CN(Cc1ccc(OC(F)F)cc1)C(=O)CS(=O)(=O)c1ccc(Cl)cc1',
#  'COc1ccc(Cc2[nH]c3ccccc3c2CCNC(C)=O)cc1',
#  'Cc1cn(C2CC3C(COCN3O)O2)c(=O)[nH]c1=O',
#  'O=C(Cc1ccccc1O)NCCCNCCNCCCNC(=O)Cc1ccccc1O',
#  'O=C(NC1c2ccccc2OCC1O)C(Cc1ccccc1)CC(O)CN1CCN(Cc2ncc(-c3ccncc3)o2)CC1C(=O)NCC(F)(F)F',
#  'O=C(CC1OC(=O)c2ccccc21)c1ccc(O)cc1',
#  'COc1ccc(-c2c(C)c(C(=O)NC3(C#N)CCCCC3)nn2-c2ccccc2Br)cc1',
#  'Cc1cc(C)cc(N=c2nc(-n3ccnc3-c3ccccn3)cc[nH]2)c1',
#  'Cn1c(Cc2nc3cc(C(N)=O)ccc3[nH]2)nc2ccc(C(=O)NCC(=O)O)cc21',
#  'COc1cc(-c2cccc(Cl)c2)cc2c1OCCN(C(C)=O)C2',
#  'N#CCC1C2CC3C(C2=O)C13',
#  'O=C(Cc1ccc(Cl)cc1)Nc1ccc(S(=O)(=O)N=c2cnc3ccccc3[nH]2)cc1',
#  'Cc1cc2c(F)c(Oc3ncnn4cc(OCC(C)OC(=O)c5cccc(CN(C)C)c5)c(C)c34)ccc2[nH]1',
#  'CNC(=O)COCC(=O)NCCCCCCCNC(=O)COCC(=O)NC1CCC2(O)C3Cc4ccc(O)c5c4C2(CCN3CC2CC2)C1O5',
#  'CCCCC(=O)Nc1ccc(C(=O)N2CCN(C)CC2)cc1',
#  'CC(=O)OC=C1CSC2C(F)C(=O)N2C1C(=O)OC(C)(C)C',
#  'COc1ccc(N2CCOCC2)c(NC(=O)c2cc3ccccc3o2)c1',
#  'COc1ccc2nc3c(C)n(C)ccc-3c2c1',
#  'CC(=NC(=O)C1CCCN2C1c1ccccc1S2(=O)=O)C(=O)NC(CCC(=O)O)C(N)=O',
#  'COc1ccc(NC(=O)C(=O)NCCC2CCCCN2S(=O)(=O)c2ccc(F)cc2)cc1',
#  'CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CCc4ccccc4)cccc3nc2-1',
#  'O=C1CC2(CCN(C(=O)c3ccccc3)CC2)Oc2ccc(C(O)=NO)cc21',
#  'O=c1c(C=NNS(=O)(=O)c2ccccc2)coc2ccc(Cl)cc12',
#  'Cc1cc(-c2ccc([N+](=O)[O-])cc2)c(C)n1Cc1ccccc1',
#  'CCN1CCN(c2cc(C(C)(C)C)nc3c(-c4ccccc4)c(C)nn23)CC1',
#  'COc1cc(C=CC(=O)NCCCCN=c2c3c([nH]c4ccccc24)CCCC3)ccc1OCCCCCCO[N+](=O)[O-]',
#  'CN(Cc1coc(-c2cccc3ccccc23)n1)CC1OCCO1',
#  'CC1=NC(=S)NC(c2cccc([N+](=O)[O-])c2)C1C(=O)c1ccccc1',
#  'COc1ccc2c(c1)nc1n2C(c2c(Cl)cccc2Cl)SC1',
#  'COc1ccc(C2=NNC3(S2)C(=O)N(c2ccc(Cl)cc2)c2ccc(C)cc23)cc1',
#  'Cc1csc2c(CN(C)CC=CC#CC(C)(C)C)cccc12',
#  'Cc1ccc(-n2[nH]c(C)cc2=NC(=O)c2ccc(C)s2)cc1',
#  'CCOC(=O)C1OC1C(=O)N(CCC(N)=O)NC(=O)C(CC(=O)C(CC(C)C)NC(=O)OCc1ccccc1)Cc1ccccc1',
#  'Cc1cccc(NC(=S)NNC(=O)CCn2cc(C)cn2)c1',
#  'Cn1c(-c2cccc(N3CCc4sc(C(=O)Nc5ccc(F)c(Br)c5)cc4C3)c2)nc2ccccc21',
#  'CCOC(=O)C1C(C)=NC(=S)NC1c1ccc(NC(=O)Nc2ccc(F)c(C)c2)cc1',
#  'CCc1c(C2CCCCC2)c2ccc(C(=O)O)cc2n1CC(=O)N1CCC(N(C)C)CC1',
#  'CCCCc1nc(=NCc2ccccc2)c2nccnc2[nH]1',
#  'Cc1cccc(C)c1OCc1n[nH]c(=S)n1N',
#  'CCc1ncnc(-c2cc(F)c(C(=O)N3CCC4(CC3)CN(C)C4)c(Cl)c2)c1C#Cc1ccc(=N)[nH]c1',
#  'N#Cc1c(-c2ccccc2)nc2[nH]nc(-c3cccc(Cl)c3)c2c1C1CC(F)(F)C1',
#  'Cc1nc(-c2ccc(-c3ccccc3S(=O)(=O)NC(C)(C)C)cc2F)c[nH]c1=N',
#  'COc1ccc(NC(=S)Nc2ccc(N(C)C(C)=O)cc2)cc1',
#  'N=c1[nH]cnc2c1nnn2C1OC(CSCCC(N)C(=O)O)C(O)C1O',
#  'COc1ccc(NC(=O)C2=C3C(=O)N(CCN4CCCCC4)C(C(=O)NC4CCCCC4)C34CCC2O4)cc1',
#  'COc1ccc(NC(=O)C(Cl)=C(Cl)[S+]([O-])Cc2ccc(Cl)cc2)cn1',
#  'CCCCCCCCCCCCCCCCC(C(=O)N=C(Cc1ccc(OCC=C(C)C)cc1)C(=O)O)C(O)(CC(=O)O)C(=O)O',
#  'CC12CN3CC(C)(CN(C1)C31C(=O)N(Cc3ccccc3)c3ccccc31)C2=O',
#  'CCCC(CO)NC(=O)OCc1ccccc1',
#  'N=c1[nH]c2c(c(=N)[nH]1)N=C(c1ccccc1)CO2',
#  'Cc1cc2n(n1)CCC(=O)N2Cc1ccc(C(=O)Nc2cc(Cl)ccc2C)cc1',
#  'N#CC(C#N)C(=N)c1cccnc1',
#  'C1CCC2(CC1)CCOC1(OO2)C2CC3CC(C2)CC1C3',
#  'C=CCC12C=CCC(=O)C1(O)OC(c1ccc(OC)c(OC)c1)C2C',
#  'COc1ccc(-c2cc(=O)c3cc(OC)c(O)c(OC)c3o2)cc1OC',
#  'CCN(C(=O)Cn1c(=O)oc2ccccc21)c1cccc(C)c1',
#  'O=c1[nH]c2c(O)ccc(CCNCCS(=O)(=O)CCCOCCNc3ccccc3)c2s1',
#  'COc1ccc(Cn2ccc3c(C)nc4ncnn4c32)cc1',
#  'CC1(O)CCC2CC1OOC2(C)CSc1ccccc1',
#  'O=S(=O)(NCC1CC1)c1ccc(NC2CCCCCC2)cc1C(F)(F)F',
#  'C=CC(=O)N1CCC(N(C)CCn2c(=O)c(-c3c(Cl)c(OC)cc(OC)c3Cl)cc3c[nH]c(=NC)nc32)CC1',
#  'Cc1ccc(-n2c(CSc3nc(C)cc(C)n3)nnc2SCC(=O)NCc2ccco2)cc1',
#  'CN1C(=Cc2sc3ccccc3[n+]2C)Sc2ccccc21',
#  'CCN(CC)C(=O)N1CCc2ccccc2C1CN1C(=O)c2ccccc2C1=O',
#  'N=C(N)SCc1ccc(C(=O)c2ccccc2)cc1',
#  'Cc1cc2[nH]c(-c3ccncc3)nc2cc1-n1ccnc1C',
#  'CC(NCC(Cc1ccccc1)NS(=O)(=O)c1ccccc1)c1cccc2ccccc12',
#  'O=C(CSc1nnnn1-c1ccccc1)CSc1nnnn1-c1ccccc1',
#  'Brc1cc(C2OCCCO2)ccc1OCc1ccccc1',
#  'N=C(N)NS(=O)(=O)c1ccc(NNC(=O)c2cccc3c(=O)c4ccccc4[nH]c23)cc1',
#  'O=C(CN1CCCCC1)Nc1cccc(-c2cnc3ccccc3n2)c1',
#  'NC(=O)N1CCCc2cc(-c3cncnc3)cnc21',
#  'Cc1cc(SCC(=O)Nc2cccnc2Cl)nc2ccccc12',
#  'CC(C)N(C(=O)CSc1nnc(Cc2csc(=Nc3ccccc3)[nH]2)o1)C(C)C',
#  'CC(NC(=O)C1CCC1)c1ccccc1',
#  'CC(Cl)(Cl)C(N=C(NC#N)Nc1ccc(F)nc1)NC(=O)c1cc(F)cc(F)c1',
#  'NC(=S)NN=C(c1cccc(Br)c1)c1ccc(O)c(Br)c1',
#  'CN(C)c1ccc(C=CC(=O)c2ccccc2-c2ccc(F)cc2)cc1',
#  'Oc1cc(Cl)ccc1Oc1ccc(Cl)cc1CN1CCN(c2ccccc2)CC1',
#  'Cc1ccc2ncccc2c1-n1ncc(C(=O)N=C(N)N)c1C1CC1',
#  'Nn1c(C(O)c2ccccc2)n[nH]c1=S',
#  'COc1cc(C=CC(=O)CC(C)=O)ccc1OC(C)=O',
#  'N=c1[nH]c2cc(N)ccc2s1',
#  'O=C(O)CCNC(=O)c1ccc(-c2cc(Cl)ccc2CNc2ccc(-c3ccc(Cl)cc3)c(Cl)c2)cn1',
#  'CCOc1ccc2[nH]c(O)c(NC(C)=O)c2c1',
#  'CCC1(C(=O)NCCc2csc(Cl)n2)C(C)C1(Cl)Cl',
#  'CC(C)NC(=O)c1ccc2nc(-c3ccc(Cl)cc3)c(O)c(C(=O)O)c2c1',
#  'Cc1cccc(C(=O)Nc2ccc(S(=O)(=O)N(Cc3ccccc3)c3ccccc3)cc2)c1',
#  'CCC(NC(=O)C1CCN(S(C)(=O)=O)CC1)c1ccc(OC)c(OC)c1',
#  'COc1cccc(OC)c1CNC(=O)c1cc2cc(CC(C)NCC(O)c3ccc(O)c(CO)c3)ccc2n1Cc1ccccc1',
#  'CCN(CC)CCCN1C(=O)c2oc3ccccc3c(=O)c2C1c1cccnc1',
#  'Cc1ccc(NC(=O)c2ccc(CNS(=O)(=O)c3ccc4c(c3)C(C)(C)C(=O)N4C)cc2)cc1',
#  'CC(C)(C)c1nc2c(s1)CCc1[nH]c(=NC(=O)N3CCC4CC43C(N)=O)sc1-2',
#  'C=CC(C)(C)C12CC3c4nc5ccccc5c(=O)n4C(C)C(=O)N3C1N(C(C)=O)c1ccc(-c3ccc(C)cc3)cc12',
#  'CC(C)NCCCCC(NC(=O)OC(C)(C)C)C(=O)N1CCCC(C(=O)NCCC(=O)O)C1',
#  'CC(O)C(C(=O)N1CCNCC1)n1cc(CCCCN)nn1',
#  'OC1C(O)C(n2cnc3c(=NC4CCCCCC4)[nH]c(Cl)nc32)C2CC12',
#  'CSC(=N)NN=Cc1cc(C)ccc1O',
#  'COC(=O)C=C(C)CCC1(C)C(C)CCC2(C)C(C)=CC(=O)CC21',
#  'Cc1nnc(-c2ccc(N=c3nc4c(N5CCC6(COC6)C5)nccc4c[nH]3)c(Cl)c2)o1',
#  'COc1cc2c(cc1C(C)=O)C(C)(C)CCC2',
#  'O=C1OC(c2ccc(F)cc2)CN1c1ccccc1',
#  'CCCCCCC(C)OC(=O)Nc1cccc2ccccc12',
#  'CCNC(=O)COc1ccc(F)cc1C(=O)c1cnn(-c2ccccc2)c1',
#  'CC(=NOCC1CCCC1)c1cc(Cl)ccc1NS(=O)(=O)C(F)(F)F',
#  'C=CC1(C)C=C2CCC3C(C)(C(=O)OC)CCCC3(C)C2CC1',
#  'O=C(OCCCC(O)=NO)c1ccc2c(c1)no[n+]2[O-]',
#  'CC(=O)Nc1ccccc1-c1nc2ccc(C(=O)N3CCN(c4cc(C)ccc4C)CC3)cc2[nH]c1=O',
#  'CC(=O)N1N=C(c2ccc(-c3ccccc3Cl)o2)OC1c1ccc(Br)cc1',
#  'O=C(NN=Cc1cc2cc3c(cc2nc1Cl)OCCO3)c1ccccc1O',
#  'Cc1cc(OCCCn2c(C(N)=O)cc3ccc(OCc4ccccc4C(=O)O)cc32)cc(C)c1Cl',
#  'O=C(NCCNCC(O)c1cc(O)cc(O)c1)Nc1ccccc1',
#  'CCN(C=O)Cc1ccc(NCCN(CC)CC)c2c(=O)c3ccccc3sc12',
#  'CCc1cccc2c(-c3ccccc3)nc(SCC(=O)Nc3ccccc3OC)nc12',
#  'O=C(C=CC=Cc1ccccc1)CCc1ccc(O)cc1',
#  'CCOC(=O)Nc1ccc2c(c1)CCC1C2c2cc(O)c(Cl)cc2CCN1C',
#  'O=C1c2cc(O)cc(O)c2C(c2ccc(F)cc2)C1c1cc(O)cc(O)c1',
#  'O=CNNC(=O)c1ccc2[nH]c(-c3ccc([N+](=O)[O-])o3)nc2c1',
#  'CC(C)ON=CCCOc1ccc(CC(C)(C)C)cc1',
#  'O=C(Nc1cnc(Cl)nc1)c1ccc(Cl)c(F)c1',
#  'CC1CCCC(NC(=O)c2c(Cl)cccc2Cl)C1C',
#  'N#Cc1ccc(NC(=S)NN=Cc2c(O)[nH]c(=O)[nH]c2=O)cc1',
#  'CC(C)Cn1nc(-c2cccs2)c(=O)c(C2=NS(=O)(=O)c3cc(NS(C)(=O)=O)ccc3N2)c1O',
#  'O=C1c2ccccc2C(=O)N1CCc1csc(=NN=c2[nH]c(CCN3C(=O)c4ccccc4C3=O)cs2)[nH]1',
#  'CCOC(=O)c1c[nH]c2cc(Cl)c(OC)cc2c1=NCCCN1CCOCC1',
#  'CC(N=c1nc2c(=Cc3[nH]c(=O)[nH]c3O)cnn2c(=NC2CC2)[nH]1)c1ccc(F)c(F)c1',
#  'CC(C)(C)c1nc(CN2C(=O)CC3(C2=O)C(=O)N(CC(=O)O)c2ccc(Cl)cc23)no1',
#  'COc1ccc2c(c1)OC(c1cccc(C(F)(F)F)c1)C(OC(=O)NCCc1ccc(OC)c(OC)c1)C2=O',
#  'NC(=O)C(C=[N+]([O-])Cc1ccccc1)Cc1ccccc1',
#  'Cc1ccc(OCCNC(=O)CNC(=O)c2ccc(C)cc2)cc1',
#  'N#Cc1c(NC(=O)c2cc(S(=O)(=O)N3CCOCC3)c(Cl)cc2Cl)sc2c1CCN(Cc1ccc3c(c1)OCO3)C2',
#  'COc1ccc(NC(=O)C2CCCN(C(=O)c3ccc(Cl)cc3)C2)cc1Cl',
#  'COc1ccc(CNC(=O)C2CSC(c3ccccc3)=N2)cc1OC',
#  'CCC(C)C(NC(=O)CC(O)C(CC(C)C)NC(=O)C(Cc1c[nH]cn1)NC(=O)C(Cc1ccccc1)NC(C)=O)C(N)=O',
#  'CCOc1ccc(S(=O)(=O)Nc2cc3c(C(=O)OCc4ccccc4)c(C)oc3c3ccccc23)cc1',
#  'CCC(C)CNC(=O)C(C(C)C)C(O)C(O)C(Cc1c[nH]cn1)NC(=O)COc1ccccc1',
#  'CCOC(=O)C(Cc1c[nH]c2ccccc12)NC(=O)c1ccc[n+](C)c1',
#  'CN(CCOc1ccccc1)C(=O)c1ccc2c(=O)n3c(nc2c1)CCC3',
#  'COc1ccc2c(=O)c3c(OC)cc(OC)c(-c4ccccc4OC(F)(F)F)c3oc2c1OC',
#  'COc1ccc(-n2c(CCc3ccccc3)nnc2SCC(=O)NCc2ccccc2)cc1',
#  'COc1ccc2c(c1)-c1nc3c(CN4CCCCC4)c(O)c(OC)cc3cc1CS2',
#  'CCCC#CCOCC1C2CCC(O2)C1CC=CCCCC(=O)O',
#  'NCc1ccc(CCCOCCNS(=O)(=O)c2ccc3ccccc3c2)cc1',
#  'Cc1cc(C)[nH]c(=NC(=S)N2CCN(c3cnc4nccn4c3)CC2)c1',
#  'CC(=O)Nc1ccccc1C(=O)C(=O)Nc1ccc(C(=O)N2CCOCC2)cc1',
#  'O=C(NC1CCCCC1)NS(=O)(=O)c1ccc(OCCCCN2CCCCC2)cc1',
#  'Cn1nc(-c2nccs2)cc1-c1ccc(C(=O)Nc2ccccc2Cl)s1',
#  'C=CCn1c(=O)c(=Cc2cccc(Cl)c2Cl)[nH]c(=O)c1=Cc1ccccc1OC',
#  'COc1cc(-c2[nH]ncc2CN(C)Cc2nonc2C)cc(OC)c1OC',
#  'N=c1[nH][nH]c2nc(N3CCCCC3)c3c(c12)CCN(CC1CCCCC1)C3',
#  'CC1(C)CC(O)CC(C)(CN=c2cccc(C(F)(F)F)[nH]2)C1',
#  'CC(=O)C1=C(C)N(c2cccc(C(F)(F)F)c2)C(=O)N(C)C1c1ccc(C#N)cc1-c1cnco1',
#  'COc1ccc(C(CC(=O)c2ccc3c(c2)OCO3)C(=O)O)cc1OC',
#  'Cc1ccc(-c2cc(-c3cc4ccccc4oc3=O)n(C(=O)c3ccncc3)n2)cc1',
#  'COc1ccc(N2CCN(c3ncnc4onc(C)c34)CC2)cc1',
#  'CCOC(=O)CN(C(=O)CNC(=O)c1ccco1)C(C(=O)NC1CCCCC1)c1cccnc1',
#  'Cn1nnnc1-c1ccccc1-c1ccc(Cn2cnc3ccc(N(Cc4ccccn4)C(=O)c4ccccc4)cc3c2=O)cc1',
#  'C#CCNC1CCc2cccc(OC(=O)N(C)CCC)c21',
#  'Clc1ccc2c(=Nc3ccc(N=c4nc(Cl)[nH]c(N5CCCC5)n4)cc3)cc[nH]c2c1',
#  'O=C(CCn1c(=O)oc2ccccc21)N1CCN(c2ccccc2F)CC1',
#  'COCC(C)n1cc(Cl)[nH]c(=Nc2c(Cl)cc(C(F)(F)F)cc2Cl)c1=O',
#  'O=C(NCCc1ccccc1)c1ccc(CSc2nc3ccncc3n2Cc2ccccc2)cc1',
#  'CC(C)Cn1c2ccccc2c2cc(=NC(=O)CCN3CCCC3)[nH]cc21',
#  'CSCCC(c1nnnn1Cc1ccccc1)N1CCN(CC=Cc2ccccc2)CC1',
#  'COc1ccccc1-c1cc(C(F)(F)F)nc(S(=O)(=O)CCCC(=O)O)n1',
#  'Cc1ccc(-n2[nH]c(C3CCN(Cc4ccncc4)CC3)cc2=NC(=O)c2cnn3cccnc23)cc1',
#  'C1=CSSC=CSS1',
#  'CC1CCC2CC1OOC2(C)CS(=O)(=O)c1ccccc1',
#  'COc1ccc(C=c2c(OC)nc(=Cc3ccccc3)c(=O)n2C)cc1',
#  'O=C(NCCNS(=O)(=O)c1ccc(-c2ccccn2)s1)C(=O)C(Cc1ccccc1)NC(=O)c1cc(Cl)ccc1Cl',
#  'COc1cccc(C(c2nnnn2Cc2ccco2)N2CCN(Cc3ccccc3)CC2)c1OC',
#  'Cc1nn(Cc2c(Cl)cccc2Cl)c(C)c1NC(=O)Cn1nc([N+](=O)[O-])c(Cl)c1C',
#  'N#CC(Cc1ccc(O)c(CCCF)c1)c1ccc(O)cc1',
#  'COc1ccc(S(=O)(=O)Oc2c3c(nc4ccccc24)CCCC3)cc1',
#  'O=C(Cc1ccccc1)N=c1[nH]nc(CCCCC(=O)NCCN2CCCCC2)s1',
#  'NCCCCN=c1c2ccccc2oc2[nH]c3ccccc3c12',
#  'CC(=O)N1CCN(C(=O)c2c(Cl)c3ccccc3n2C)CC1',
#  'CCCc1cc(CO)cc(=O)n1Cc1ccc(-c2ccccc2-c2nn[nH]n2)cc1',
#  'NC1CC1c1ccc(F)cc1',
#  'c1ccc2c(N3CCOCC3)nc(-c3ccncc3)nc2c1',
#  'Cn1nc(C(N)=O)c2c1-c1[nH]c(=NCc3ccccn3)ncc1CC2',
#  'CCc1ccc(C(O)(c2ccccc2OC)C(CN2CCOCC2)c2ccccc2)cc1',
#  'CCOC(=O)C(Cc1ccc(C)cc1)=NC(=O)c1ccccc1',
#  'CC1CCCCN1S(=O)(=O)CCN=c1[nH]c(N2CCN(C)CC2)nc2ccc(Cl)cc12',
#  'CCCCCNC(=O)N(CCN1C2CCC1CC(c1cccc(O)c1)C2)CC1CCCCC1',
#  'CCOC(=O)c1cn2[nH]cnc(=Nc3cc(C(=O)NOC)c(F)cc3F)c2c1C(C)C',
#  'Nc1ccc2c(c1)C13CCCCC1C(C2)N(CC1CCC1)CC3',
#  'O=C(N=c1[nH]c(CCN=c2[nH]cnc3ccsc23)cs1)Nc1cccc(Cl)c1',
#  'O=C(Nc1cnn(S(=O)(=O)c2cnc3ccccc3c2)c1)c1ccccn1',
#  'CCCNC(=O)c1cc(C#N)c2c3c([nH]c2c1C)C(CCC)(CC(=O)O)OCC3',
#  'CNC1CN(c2c(F)cc3c(=O)c(C(=O)O)cn(-c4cc(N)c(F)cc4F)c3c2Cl)C1',
#  'COc1cc(C=C2CC3C4CC=C5CC(N6CCCC6)CCC5(C)C4CCC3(C)C2OC(C)=O)cc(OC)c1OC',
#  'Cc1n[nH]c(C)c1C(=O)CC1(O)C(=O)N(CCc2ccccc2)c2ccc(Br)cc21',
#  'Cc1ccc(CN=c2[nH]c(=O)c3cc(C(F)(F)F)cc([N+](=O)[O-])c3s2)n1C',
#  'CC12CCC3c4cc(-c5ccc(OC(F)(F)F)cc5)c(O)c(-c5ccc(OC(F)(F)F)cc5)c4CCC3C1CCC2=O',
#  'O=S(=O)(O)c1ccc2c(N=Nc3ccc(S(=O)(=O)O)c4ccccc34)c(O)c(S(=O)(=O)O)cc2c1',
#  'C=CCn1c(SCC(=O)Nc2cc3oc4ccccc4c3cc2OC)nnc1-c1cnccn1',
#  'Nn1c(N2CCCCC2)nc2ccccc21',
#  'CN(C(=O)C1=C(c2ccccc2)C1c1ccccc1)C1CCCCC1N1CCCC1',
#  'CN(C)c1ccc(C=CC(=O)C=Cc2ccc[nH]2)cc1',
#  'Cc1ccccc1-n1c(=O)ncc2c1=CCC(Sc1ccc(F)cc1Cl)N=2',
#  'COc1ccc(C=CC(=O)c2ccc(OCOc3ccc(C(=O)C=Cc4ccc(OC)cc4OC)cc3)cc2)c(OC)c1',
#  'O=c1[nH]cnc2c(CNCc3ccccc3)nccc12',
#  'COc1cc2cc(O)oc2cc1-c1ccccc1',
#  'CN1CCC(OC(=O)c2cccs2)CC1',
#  'Cc1oncc1CN=C1CC(=O)CC(C)C1',
#  'COc1cc(OC)[nH]c(=Nc2nc3cc(C4(O)c5ccccc5C(=O)N4c4cccc(Cl)c4F)ccc3[nH]2)n1',
#  'COc1ccc2c(c1)-c1[nH]c(=NC(=O)c3cc(OC)c(OC)c(OC)c3)sc1CC2',
#  'COC1(NC(=O)Cc2ccc(O)cc2)C(=O)N2C(C(=O)N3CCCC3)=C(CSc3nnnn3C)COC21',
#  'CS(=O)(=O)N1CC2(CCN(C(=O)C(Cc3ccccc3)NC(=O)C(N)Cc3c[nH]cn3)CC2)c2ccccc21',
#  'O=C(N=c1[nH]c2c(Br)cc(Br)cc2c(=O)s1)c1ccco1',
#  'N#CC1(c2ccccc2C(F)(F)F)CCC(CN=c2[nH]cccc2NC(=O)CC(F)(F)F)CC1',
#  'CCCCCCCCCCCCc1ccccc1C(SCC(=O)O)SCC(=O)O',
#  'CC(=O)Nc1cc2c(=O)cc(-c3ccc(C(=O)NC(CC(C)C)C(N)=O)cc3)oc2cc1NC(C)C1CCCCC1',
#  ...]

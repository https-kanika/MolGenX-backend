# %%
from rdkit import Chem
import numpy as np
import pandas as pd
import os
import time

def preprocess_smiles(smiles_list, canonical=True, show_progress=True):
    """
    Process a list of SMILES strings and return valid ones
    
    Args:
        smiles_list: List of SMILES strings to process
        canonical: Whether to convert to canonical SMILES
        show_progress: Whether to show progress updates
    
    Returns:
        List of valid SMILES strings
    """
    clean_smiles = []
    invalid_count = 0
    total = len(smiles_list)
    
    start_time = time.time()
    
    if show_progress:
        print(f"Processing {total} SMILES strings...")
    
    # Process in batches of 5000 for progress reporting
    batch_size = 5000
    for i in range(0, total, batch_size):
        batch = smiles_list[i:i+batch_size]
        
        for smi in batch:
            mol = Chem.MolFromSmiles(smi)
            if mol:
                if canonical:
                    clean_smiles.append(Chem.MolToSmiles(mol, canonical=True))
                else:
                    clean_smiles.append(smi)
            else:
                invalid_count += 1
        
        if show_progress and i > 0:
            progress = min(i + batch_size, total) / total * 100
            elapsed = time.time() - start_time
            est_total = elapsed / progress * 100
            remaining = est_total - elapsed
            
            print(f"Progress: {progress:.1f}% ({i+batch_size}/{total}) | "
                  f"Valid: {len(clean_smiles)} | Invalid: {invalid_count} | "
                  f"Time remaining: {remaining:.1f}s")
    
    # Final stats
    if show_progress:
        print(f"Completed in {time.time() - start_time:.1f}s")
        print(f"Total SMILES: {total}")
        print(f"Valid SMILES: {len(clean_smiles)} ({len(clean_smiles)/total*100:.1f}%)")
        print(f"Invalid SMILES: {invalid_count} ({invalid_count/total*100:.1f}%)")
    
    return clean_smiles

def process_smi_file(file_path, output_path=None):
    """Process a .smi file and save valid SMILES"""
    # Read the file
    with open(file_path, 'r') as f:
        smiles_list = [line.strip() for line in f if line.strip() and not line.startswith('//')]
    
    print(f"Loaded {len(smiles_list)} SMILES from {file_path}")
    
    # Process SMILES
    clean_smiles = preprocess_smiles(smiles_list)
    
    # Save results with "cleaned" in filename
    if output_path is None:
        base_name, ext = os.path.splitext(file_path)
        output_path = f"{base_name}_cleaned{ext}"
    
    with open(output_path, 'w') as f:
        for smi in clean_smiles:
            f.write(f"{smi}\n")
    
    print(f"Saved {len(clean_smiles)} valid SMILES to {output_path}")
    return clean_smiles

process_smi_file('./data/chembl.mini.smi')
# Out:
# Loaded 171548 SMILES from ./data/chembl.mini.smi
# Processing 171548 SMILES strings...
# Progress: 5.8% (10000/171548) | Valid: 10000 | Invalid: 0 | Time remaining: 54.3s
# Progress: 8.7% (15000/171548) | Valid: 15000 | Invalid: 0 | Time remaining: 52.2s
# Progress: 11.7% (20000/171548) | Valid: 20000 | Invalid: 0 | Time remaining: 50.4s
# Progress: 14.6% (25000/171548) | Valid: 25000 | Invalid: 0 | Time remaining: 48.7s
# Progress: 17.5% (30000/171548) | Valid: 30000 | Invalid: 0 | Time remaining: 46.9s
# Progress: 20.4% (35000/171548) | Valid: 35000 | Invalid: 0 | Time remaining: 45.2s
# Progress: 23.3% (40000/171548) | Valid: 40000 | Invalid: 0 | Time remaining: 43.6s
# Progress: 26.2% (45000/171548) | Valid: 45000 | Invalid: 0 | Time remaining: 41.9s
# Progress: 29.1% (50000/171548) | Valid: 50000 | Invalid: 0 | Time remaining: 40.2s
# Progress: 32.1% (55000/171548) | Valid: 55000 | Invalid: 0 | Time remaining: 38.6s
# Progress: 35.0% (60000/171548) | Valid: 60000 | Invalid: 0 | Time remaining: 36.9s
# Progress: 37.9% (65000/171548) | Valid: 65000 | Invalid: 0 | Time remaining: 35.3s
# Progress: 40.8% (70000/171548) | Valid: 70000 | Invalid: 0 | Time remaining: 33.6s
# Progress: 43.7% (75000/171548) | Valid: 75000 | Invalid: 0 | Time remaining: 31.9s
# Progress: 46.6% (80000/171548) | Valid: 80000 | Invalid: 0 | Time remaining: 30.3s
# Progress: 49.5% (85000/171548) | Valid: 85000 | Invalid: 0 | Time remaining: 28.6s
# Progress: 52.5% (90000/171548) | Valid: 90000 | Invalid: 0 | Time remaining: 27.0s
# Progress: 55.4% (95000/171548) | Valid: 95000 | Invalid: 0 | Time remaining: 25.3s
# Progress: 58.3% (100000/171548) | Valid: 100000 | Invalid: 0 | Time remaining: 23.7s
# Progress: 61.2% (105000/171548) | Valid: 105000 | Invalid: 0 | Time remaining: 22.0s
# Progress: 64.1% (110000/171548) | Valid: 110000 | Invalid: 0 | Time remaining: 20.4s
# Progress: 67.0% (115000/171548) | Valid: 115000 | Invalid: 0 | Time remaining: 18.7s
# Progress: 70.0% (120000/171548) | Valid: 120000 | Invalid: 0 | Time remaining: 17.1s
# Progress: 72.9% (125000/171548) | Valid: 125000 | Invalid: 0 | Time remaining: 15.4s
# Progress: 75.8% (130000/171548) | Valid: 130000 | Invalid: 0 | Time remaining: 13.7s
# Progress: 78.7% (135000/171548) | Valid: 135000 | Invalid: 0 | Time remaining: 12.1s
# Progress: 81.6% (140000/171548) | Valid: 140000 | Invalid: 0 | Time remaining: 10.4s
# Progress: 84.5% (145000/171548) | Valid: 145000 | Invalid: 0 | Time remaining: 8.8s
# Progress: 87.4% (150000/171548) | Valid: 150000 | Invalid: 0 | Time remaining: 7.1s
# Progress: 90.4% (155000/171548) | Valid: 155000 | Invalid: 0 | Time remaining: 5.5s
# Progress: 93.3% (160000/171548) | Valid: 160000 | Invalid: 0 | Time remaining: 3.8s
# Progress: 96.2% (165000/171548) | Valid: 165000 | Invalid: 0 | Time remaining: 2.2s
# Progress: 99.1% (170000/171548) | Valid: 170000 | Invalid: 0 | Time remaining: 0.5s
# Progress: 100.0% (175000/171548) | Valid: 171548 | Invalid: 0 | Time remaining: 0.0s
# Completed in 56.8s
# Total SMILES: 171548
# Valid SMILES: 171548 (100.0%)
# Invalid SMILES: 0 (0.0%)
# Saved 171548 valid SMILES to ./data/chembl.mini_cleaned.smi
# ['CC1(COC(C(=O)Nc2cccc(Cl)c2)=C(C=N)N2CCN(S(=O)(=O)NCc3nc4cc(Cl)ccc4o3)CC2)CC1',
#  'CC(=O)C(NC(=O)C(CCCCNC(C)=S)NC(=O)C(CC(=O)O)NC(=O)C(N)CO)C(O)NC(C)C(=O)O',
#  'Cc1cc(S(=O)(=O)NC(C)c2nnc3ccccn23)ccc1Br',
#  'Cc1cc(=NC(=O)c2ccc3c(-c4nc5ccccc5[nH]4)[nH]nc3c2)[nH][nH]1',
#  'O=C1CC(c2ccc(Br)cc2)Nc2c(Br)cc(Br)cc21',
#  'CCCCC1=NC2(CCN(C(C)=O)CC2)C(=O)N1Cc1ccc(-c2ccccc2C(=O)O)cc1',
#  'CCOC(Cc1ccc(OCC=C(C)c2ccc(-c3ccc(C(C)=CCOc4ccc(CC(OCC)C(=O)O)cc4)cc3)cc2)cc1)C(=O)O',
#  'Cc1ccc(C(=O)CSc2ncc3c(n2)-c2ccccc2N(Cc2ccc(Cl)cc2)S3(=O)=O)cc1',
#  'CC(NCC1OC(CO)C(O)C1O)c1ccc(Cl)cc1',
#  'O=C(N=c1[nH]cc(Cc2ccccc2)s1)c1ccccc1',
#  'CC(C)c1cc2c(cc1O)C1(C)CCCC(C)(C)C1CC2CC1=CCC(O)(C(C)C)CC1',
#  'O=C(Cn1cnc(-c2ccccc2)cc1=O)N=c1cc[nH]cc1',
#  'Clc1ccc(CN2CCN(CCCOc3cccc4cccnc34)CC2)cc1',
#  'O=C(O)C=CC1CC=NCC1',
#  'N=c1nc2ccnc(-c3ccccc3)n2[nH]1',
#  'O=C(N=c1cc[nH]cc1)C(=O)c1cn(-c2cccnc2)c2ccccc12',
#  'CCON=C1CCN(c2c(F)cc3c(=O)c(C(=O)O)cn(CCF)c3c2F)CC1(C)CN',
#  'c1coc(CN(Cc2cccs2)Cc2nnnn2C2CCCCC2)c1',
#  'O=C(NC(=S)NC1CCCCC1)c1cccc(Cl)c1',
#  'CN=c1[nH]c2ccc(S(=O)(=O)N(CC(C)C)CC(O)C(Cc3ccccc3)NC(=O)OC3COC4OCC(O)C34)cc2o1',
#  'COCCOc1ccc(NC(O)c2cc(O)n(C3CC3)c2)cn1',
#  'COc1c(OC)c(OC)c2c(c1OC)c(=O)c1ccccc1n2C',
#  'Cn1ncc2c1NC(=O)CC2c1ccccc1Br',
#  'COCCNC(=O)NC12CC3(C)CC(C)(CC(C)(C3)C1)C2',
#  'C=CCNC(=S)N(Cc1ccccc1)Cc1ccc(F)cc1',
#  'COc1ccc(C(=O)C[n+]2ccc3ccccc3c2C)cc1',
#  'Cc1ccc(C2=C(C#N)C(=O)NC(c3ccc(OCCCC(F)(F)F)cc3)(C(F)(F)F)C2)cc1F',
#  'CN1CCN(Cc2ccc(-n3cc4cccc(C(N)=O)c4n3)cc2)CC1',
#  'N=c1[nH]cnc2c1cnn2CCC(=O)O',
#  'CC1(C)OC(=O)Nc2ccc(-c3cc(F)cc(Cl)c3)cc21',
#  'Cc1cc(=NC2Cc3ccccc3C2)c2nncn2[nH]1',
#  'Cc1cccc(C)c1NC(=O)C1CCCCN1CCO',
#  'CS(=O)(=O)c1cc(C(=O)O)cc(SCc2ccccc2)c1Sc1ccccc1',
#  'CCn1c(Cn2nc(Cc3ccccc3)c3onc(C)c3c2=O)n[nH]c1=S',
#  'COC(=O)C12CCC(C)(C)CC1C1=CCC3C4(C)C=C(Br)C(=O)C(C)(C)C4CCC3(C)C1(C)CC2',
#  'O=C(C=Cc1ccccc1)Nc1ccc(C(=O)N2CCCCC2)cc1',
#  'COc1cc(C(=S)NC2CCCCC2)ccc1O',
#  'CC(NC(=O)C(C)OC1C(O)C(CO)OC(O)C1NC(=O)CO)C(=O)NC(CCC(=O)O)C(N)=O',
#  'CCOC(=O)c1c(C)[nH]c2cc(Br)c(OC)cc12',
#  'CCC(=O)N(C)c1cc(C(=O)NC(C)COC)cc(-c2ccc(C)cc2)c1',
#  'O=C1C(c2ccccc2)=C(c2ccccc2)C2C3CCC(C3)C12N1CCOCC1',
#  'O=C(NCc1ccc(S(=O)(=O)c2cc(F)cc(F)c2)cc1)c1cnc2[nH]ncc2c1',
#  'CCN(c1ccc(C(O)(C(F)(F)F)C(F)(F)F)cc1)C(C)(C(=O)N(C)C)c1ccccc1',
#  'Cc1cc(C)cc(-c2[nH]c3c(c2C(C)CNCCc2ccncc2)CN(C(=O)C2CCCC2)CC3)c1',
#  'O=C(c1cccc(F)c1)N1CCN(c2ccc([N+](=O)[O-])c3cccnc23)CC1',
#  'CCOC(O)c1cc2cc(-c3ccc(=O)[nH]n3)ccc2[nH]1',
#  'CCC(=O)N(c1ccccc1)C1(C(=O)OCCF)CCN(CCc2ccccc2)CC1',
#  'CCCCOC1=C(C(=O)O)C(c2ccc3c(c2)OCO3)Oc2ccccc21',
#  'Cc1ccccc1-c1cc(C(OCc2ccccc2Cl)c2cncn2C)ccc1C#N',
#  'C=CCn1c(=O)c(C2C(C(=O)OCC)C(=N)N(NC(=O)c3ccncc3)C3=CCCC(=O)C32)cc2cc(Cl)ccc21',
#  'Cc1cccc(C)c1NC(=O)C(NC=O)c1ccc(N(C)C)cc1',
#  'Cc1ccc(S(=O)(=O)Nc2cc(C)c(O)c(Sc3n[nH]c(C)n3)c2)cc1',
#  'CCC(C(=O)NCC1=CCN(C)CC1)c1ccccc1',
#  'CN(c1cccc(NC(=O)c2ccc(C(C)(C)C)cc2)c1)S(C)(=O)=O',
#  'O=S(=O)(c1ccc(-c2ccc3[nH]ccc(=Nc4ccc5[nH]nnc5c4)c3c2)cc1)N1CCOCC1',
#  'O=C(Cc1cc(CCC2CCNCC2)no1)NCC(NC(O)OCc1ccccc1)C(=O)O',
#  'O=C(NN=Cc1ccc(CS(=O)(=O)C2CCCC2)c2ccccc12)c1ccc(O)c(Cl)c1',
#  'Cc1ccc2nc(C)c(C(=O)O)cc2c1',
#  'Cc1cc(COc2cccc(C#N)c2)nc(-c2ccccn2)n1',
#  'O=C1CCCCN1C1CCN(c2nc3ccccc3n2Cc2ccc(F)cc2)CC1',
#  'CCc1nn(CC)c(C2CCN(C(=O)CN3CN(c4ccccc4)C4(CCN(C(=O)c5ccc(C(C)(C)C)cc5)CC4)C3=O)CC2)c1CC',
#  'CCOC(=O)c1c[nH]n(CCOC(=O)c2cccs2)c1=NC(=O)c1cccs1',
#  'CC(c1cccc(F)n1)c1c(CCN(C)C)sc2ccccc12',
#  'CC(C)(C)OC(=O)N1CCCC1c1nnc(SCc2ccc(Cl)cc2Cl)o1',
#  'COc1cccc(C=C(C#N)C(=O)NCCCCCCNC(=O)C(C#N)=Cc2cccc(OC)c2)c1',
#  'CC(C)=CCCC(C)=CC1OC(=O)CC12CC(OC(=O)c1cccc(F)c1)=CCC2=O',
#  'Cc1ncsc1C(=O)N=c1[nH]c2c(s1)CCCC2',
#  'CCOC(=O)C1=C(C)N(CCO)C(=O)NC1c1cccc(O)c1',
#  'COc1ccccc1-c1nnc2sc(-c3ccc(N(C)C)cc3)nn12',
#  'CON=C1C2CCCC1C(c1ccccc1OC)N(C)C2c1ccccc1OC',
#  'Cc1ccc2cc(CN(Cc3ccco3)S(=O)(=O)c3c(C)ccc4nsnc34)c(=O)[nH]c2c1',
#  'CSCCC(N=c1nc(C)cc(C)[nH]1)C(=O)NCC1CCOCC1',
#  'CCCc1cc(=O)c2c(O)cc(OC)cc2o1',
#  'Nc1c[nH]ccc1=NC(=O)c1ccc2ncsc2c1',
#  'COc1cccc2c(CCN3CC=C(c4c[nH]c5ccc(F)cc45)CC3)coc12',
#  'CC(c1ccccc1)n1c(SCC(=O)Nc2ccccc2)n[nH]c1=O',
#  'CN(C)CC(C)(C)CNC(=O)c1cnn(-c2ncc3c(n2)-c2ccccc2CC3)c1-c1ccco1',
#  'CCCn1c(C)nnc1C(Cc1ccccc1)NS(=O)(=O)c1ccc(Cl)cc1',
#  'N#CCC1(n2cc(-c3ncnc4[nH]ccc34)cn2)CN(C2CCN(C(=O)Nc3cc(F)cc(F)c3F)CC2)C1',
#  'CCC(C)C(NC(N)=O)C(=O)NNC(=O)c1ccc(COc2cccc3cccnc23)cc1',
#  'CC(=O)OCCCC1=CCN(NC(=O)c2ccccc2)CC1',
#  'Cn1c(N2CCOC(c3ccc(N(C(=O)c4ccccc4)C4CCCCC4)cc3)C2)nc(-c2ccncc2F)cc1=O',
#  'CC(C)N(c1cc(F)ccc1F)S(=O)(=O)c1ccc(Cl)cc1',
#  'CCCCC(=O)Nc1ccccc1C(=O)OCc1cc(=O)n2nc(C3CCCCC3)sc2n1',
#  'O=S(=O)(c1ccc(-c2ccc3[nH]cnc(=Nc4ccc(OCc5ccccc5)c(Cl)c4)c3c2)cc1)N1CCOCC1',
#  'CCCN(CCN1CC(c2ccc3c(c2)OCO3)C(C(=O)O)C1c1ccc(OC)cc1)S(=O)(=O)CCOC',
#  'Cc1c(C(=O)N2CCOCC2)sc(NC(=O)c2ccc([N+](=O)[O-])cc2)c1C#N',
#  'O=C(COc1ccc(Br)cc1)N(Cc1ccco1)C1CCS(=O)(=O)C1',
#  'CCCCc1ccc(N=CC2C(=O)OC3(CCCCC3)OC2=O)cc1',
#  'Cc1cc[nH]c(=NS(=O)(=O)c2ccc(NC(=O)Cc3ccc(F)cc3)cc2)n1',
#  'CN(C)C(=O)c1cccc2c1nc(-c1c(F)cccc1F)n2Cc1c(F)cccc1F',
#  'COC(=O)C=C(C)n1nc2ccccc2n1',
#  'CC(C)c1cccc(-c2csc(C(O)c3ccco3)n2)c1',
#  'Cc1c2c(=O)n(-c3nc(-c4ccccc4)cs3)[nH]c2cc(=O)n1C',
#  'NCc1ccc(Cl)cc1CNC(=O)C1CCCN1C(=O)C1c2ccccc2CS1(=O)=O',
#  'Oc1cc(C=Cc2csc(-c3ccccc3)n2)cc(O)c1O',
#  'CC(=Cc1ccc(OCCN2CCOCC2)cc1)c1ccc2c(c1)C(C)(C)CCC2(C)C',
#  'CCc1ccc(-n2c(O)c3c(c2O)C2(NC3Cc3ccc(OC(C)(C)C)cc3)C(=O)N(Cc3ccccc3)c3ccc(F)cc32)cc1',
#  'CCCOc1ccccc1C(=O)OCC(O)CNC(C)C',
#  'COCCOC1CCC(Nc2cc(=O)n(C)c3c(C)cc(-c4cncs4)cc23)CC1',
#  'NC(=O)C1CCN(C(=O)CCCc2nnc(-c3ccccc3)o2)C1',
#  'COc1ccc(Cl)cc1NC(=O)CN1c2ccccc2S(=O)(=O)c2ccccc21',
#  'NC(=O)CN1CCC(c2ccccc2)C1=O',
#  'COC(=O)C(Cc1ccccc1)N(C(=O)c1ccccc1)C1CCN(Cc2cncn2Cc2ccc(C#N)cc2)CC1',
#  'Cn1c(=O)n(Cc2ccccc2F)c(=O)c2c1[nH]c(=NCc1cccnc1)n2C',
#  'COc1ccc(C=CC(=O)CC(=O)C=Cc2ccc(OC)c(C)c2)cc1C',
#  'Cc1cc2c(cc1C)NC1(CC3CCCC(=O)N4CCC(C1)C34)C(=NCc1ccccc1)N2',
#  'CC(C)N1C(=O)C(=CC(=O)c2cccnc2)c2c(Cl)cccc21',
#  'CCOC(=O)c1cc2cc(N=c3[nH]cnc4cc(OC)c(OCCCN5CCCC5)cc34)ccc2s1',
#  'CC(C)CCC1OC(C)(C)OC1(C)C1CCC2(O)C3=C(C(O)CC12C)C1(C)CC(O)C(O)CC1C(=O)C3',
#  'O=C(Nc1ccc(Br)cc1F)C1CCN(c2nnc(-n3cccc3)s2)CC1',
#  'OC(Cn1ccnc1)(c1ccccc1)c1ccc(-c2ccncc2)cc1',
#  'Cc1cc(-c2cccc([N+](=O)[O-])c2)c2ncc(CSCCc3ccccc3)n2c1',
#  'Fc1ccccc1C(N=c1[nH]nc(-c2c[nH]c3ncccc23)o1)C1CC1',
#  'COCCOc1cc2[nH]cnc(=Nc3cc(O)c(Cl)cc3F)c2cc1OC',
#  'COc1ccc(C)cc1S(=O)(=O)N1CCN(Cc2ccccc2)CC1',
#  'COC(=O)CCC(=O)N=CC(N)C(=O)OCC(N)=O',
#  'COC(=O)CC(CC(=O)Oc1ccc([N+](=O)[O-])cc1)c1ccccc1',
#  'O=C(CCCc1ccccc1-c1ccc(CSCCc2ccccc2)cc1)NS(=O)(=O)c1cccs1',
#  'COc1ccc2cc(C(=O)C3CCCN(C(=O)c4cnccn4)C3)ccc2c1',
#  'O=C(NC1CCCCC1)C(c1cccnc1)N(CCc1ccccc1)C(=O)Cc1cccs1',
#  'CC(C)(C)OC(=O)c1ccc(CCN=c2[nH]c(=N)c3ncn(C4OC(CO)C(O)C4O)c3[nH]2)cc1',
#  'CCC(Sc1ccccc1C(=O)O)C(=O)O',
#  'Cc1ccccc1OCC(=O)Nc1sc(C(=O)Nc2cccc(C)c2C)c(C)c1C#N',
#  'C1=C(c2ccco2)CC[N+](C2CC2)=C1',
#  'COc1ccc(-c2ccc(CCC(=O)O)n2Cc2ccco2)cc1',
#  'CS(=O)(=O)c1c[nH]c2ccc(-c3cc(F)c(O)c(Cl)c3)cc2c1=NC1CCC(CN2CCCC2)CC1',
#  'CCOc1ccc(NC(=O)CN(C)C(=O)c2ccc(NC3CC3)c([N+](=O)[O-])c2)cc1OCC',
#  'COc1ccc(OC)c2[nH]c(=O)c(CCNC(=O)COc3ccccc3)cc12',
#  'O=C(N=c1c2c([nH]n1-c1cccc(Cl)c1)CS(=O)(=O)C2)C1CC1',
#  'CCn1c(COc2c(OC)ccc3cc4[n+](cc23)CCc2cc3c(cc2-4)OCO3)nc2ccccc21',
#  'Cc1cc(-c2ccccc2)cc(C)n1',
#  'COC(=O)C(C(=O)N=c1[nH]nc(CCSCCc2n[nH]c(=NC(=O)C(C(=O)OC)c3ccccc3)s2)s1)c1ccccc1',
#  'Cn1c(C2CCCCC2)nc2c(-c3ccccc3)nc(-c3ccccc3)nc21',
#  'Cc1ccc(NCc2nnc(SCC(=O)c3ccccc3)n2Cc2ccco2)c(C)c1',
#  'CCCCN(CCCC)S(=O)(=O)c1ccc(NC(=O)c2c(-c3ccccc3)noc2C)cc1',
#  'COc1cc(C=CC(=O)C(=Cc2ccc(O)cc2)C(=O)C=Cc2ccc(O)c(OC)c2)ccc1O',
#  'COc1cnn(CCN2CCOCC2)c(=O)c1-c1ccc(CC(NC(=O)c2c(Cl)cccc2Cl)C(=O)O)cc1',
#  'N=c1c2c([nH]c(=S)n1-c1ccccc1)N=C1CCCCC1C2c1ccc(Cl)cc1',
#  'N=C(N)NCCCCCN(CCC(N)C(=O)O)CC1OC(n2cnc3c(=N)[nH]cnc32)C(O)C1O',
#  'O=C(NS(=O)(=O)c1ccccc1)c1ccc(F)c2c(C(=O)C(=O)N3CCN(C(=O)c4ccccc4)CC3)c[nH]c12',
#  'COCN1C=Nc2cccc3cccc1c23',
#  'O=C(O)CC(CC(=O)Nc1ccc(OCc2ccc(Cl)cc2)cc1)c1ccccc1',
#  'Cc1cccc(N=Nc2c(O)c3cc(-c4ccccc4)ccc3oc2=O)c1',
#  'CC(C)=CCCC(C)CC1Cc2[nH][nH]c(=O)c2C(c2ccc(F)cc2)O1',
#  'c1ccc(CN2CCC3(CC2)CN(c2ccccn2)CCO3)nc1',
#  'Cc1cc[nH]c(=NCC(O)CON=C(C2CC2)C2CC2)c1',
#  'Cc1ncc(CNC2CC(=O)N(CCc3ccc(F)cc3)C2)n1C',
#  'Cc1cc(=O)cc(C)n1-c1ccc(Br)cc1',
#  'COc1ccc(O)c(C(=O)c2cnc3c(c2)c(C)nn3CCO)c1',
#  'CN1CCc2c(O)ccc3c2C(CCC3)C1',
#  'CN(C)CCNC(=O)c1ccccc1NC(=O)c1ccc2cc3n(c2c1)CCCNC3=O',
#  'Cc1c(-c2ccc(N3CCC3C(=O)NC(C)(C)C)cc2)[nH]c2cc(F)cc(F)c2c1=O',
#  'CC(C)(C)OC(=O)C=Cc1cn(C(=O)C=Cc2ccc3c(c2)OCO3)c2ccccc12',
#  'O=C(O)c1c(N2CCCCC2)ccc([N+](=O)[O-])c1N1CCCCC1',
#  'O=c1[nH]c2ccccc2c(O)c1-[n+]1ccccc1',
#  'COc1ccc(C2=Nn3c(nnc3-c3ccccc3C(F)(F)F)SC2)cc1OCC1CC1',
#  'COc1ccc(CNC(=O)C2CSC(c3ccc(OC)cc3)N2C(C)=O)cc1',
#  'CCOC(=O)c1[nH]c(C)c(CCC(=O)N2CCN(c3cccc(OC)c3)CC2)c1C',
#  'COc1cc(NC(=O)CSc2nnc(-c3ccncc3)o2)cc(OC)c1OC',
#  'CC(C)(C)OC(=O)NN(CC1CCCC1)c1nc(C#N)ncc1Br',
#  'CC(C)(C)c1cnc(CSc2c[nH]c(=Nc3ccccn3)s2)o1',
#  'O=C1CC(c2ccco2)Sc2ccccc2N1Cc1ccccc1',
#  'CCCOCCCCCCNC(=O)NC12CC3CC(CC(C3)C1)C2',
#  'COc1ccc2[nH]c(C)c(CCNC(=S)Nc3cc(C)cc(C)c3)c2c1',
#  'CC12c3[nH]c4ccccc4c3CCN1C(=O)C(CC(=O)NCc1cccc(C(F)(F)F)c1)CC2C(=O)N1CCCCC1',
#  'OC(CN1CCC(OCc2ccccc2F)CC1)(Cn1cncn1)c1ccc(F)cc1F',
#  'CC(N=c1nc(-c2c(-c3ccc(F)cc3)nc3cc(CN(C)C(C)C)ccn23)cc[nH]1)c1ccccc1',
#  'O=[N+]([O-])c1cn2c(n1)OCC(OCC#Cc1ccc(C(F)(F)F)nc1)C2',
#  'N#Cc1cc([N+](=O)[O-])ccc1C(=O)O',
#  'CC(C(=O)NCc1ccco1)N1CCN(Cc2nccn2C)CC1',
#  'Fc1ccc2c(c1)[nH]c(=NN=CC1CC=Nc3ccccc31)c1nccn12',
#  'COc1cc(C=NN=c2nc(N3CCOCC3)c3c([nH]2)CCS(=O)(=O)C3)cc(OC)c1O',
#  'CNC(=O)Oc1ccc2c(c1)CCC1CCN(C)C21',
#  'Cc1cc(N2CCOCC2)ccc1N=c1nc(N2CCOCC2)c2[nH]cnc2[nH]1',
#  'Cc1cc[nH]c(=NC(=S)N2CCN(c3ncc(C(F)(F)F)cc3Cl)CC2)c1',
#  'CCCc1c(C(=O)NC2CCCC2)nnn1-c1ccc(OC)cc1',
#  'CC(=O)CCC(NC(=O)C(CC(=O)O)NC(=O)CS)C(N)=O',
#  'Cn1cnc(S(=O)(=O)N2CC3CCC(NC(=O)c4ccc(F)cc4)C3C2)c1',
#  'CCCOc1ccc2ccc(=O)oc2c1',
#  'CC(=O)NCc1cc(=O)cc(-c2ccccn2)[nH]1',
#  'Cc1[nH]n(C(=O)c2cccs2)c(=N)c1-c1ccccc1',
#  'CC1=Nc2nc3ccccc3n2C(c2cccc(Cl)c2)C1C(=O)N1CCCCC1',
#  'O=C(N=c1[nH]c2c(F)cccc2s1)C1=COCCO1',
#  'CSC1=Nc2ccccc2C2=NC(CN3CCN(c4ccccc4Cl)CC3)CN12',
#  'Cc1cc(C)cc(NC(=O)COc2coc(CN3CCc4ccccc43)cc2=O)c1',
#  'CNC1Nc2cc(-c3cccc(CCC(=O)O)c3)sc2-n2c(C)cnc21',
#  'CC(C)CCOC(=O)C(C#N)=Cc1ccc(O)c(O)c1',
#  'Cc1c[nH]c(-c2ccccc2C(F)F)nc1=NCC1CN(c2cnccn2)C1',
#  'COc1ccc(C2=CCC(=O)CC2)c(OC)c1',
#  'CC(C)(C)OC(=O)Nc1ccc(C(NC(=O)OC(C)(C)C)C(=O)OC(C)(C)C)cc1',
#  'Cc1oc(=O)n(CC(N)c2ccccc2)c(=O)c1-c1ccccc1F',
#  'O=C1C(=Nc2cccc(S(=O)(=O)N3CCc4ccccc4C3)c2)C(Cl)C(=O)c2ccccc21',
#  'CC1=NC(=O)CC(c2ccc(F)cc2F)C1C(=O)OC1CCCC1',
#  'Cc1ccccc1-n1c(-c2cc(-c3ccc(Cl)cc3)c(N3CCOCC3)s2)nc2ccccc2c1=O',
#  'N#CC1C(=NCCN)N(c2ccccc2)C(=O)N2CCCC12',
#  'O=C1CCC2C(CCN2Cc2ccccn2)N1CC1CC1',
#  'Cn1c(=O)oc2cc(S(=O)(=O)Nc3ccc4c(c3)OCO4)ccc21',
#  'FC(F)(F)c1cc(COCC2(c3ccccc3)CCNCC2)cc(-c2ccco2)c1',
#  'N=C(N)NCCCC(NC(=O)C(Cc1ccc(O)cc1)NC(=O)CS)C(N)=O',
#  'CC(NC(=O)OC(C)(C)C)C(=O)OCOC(=C1C(=O)N(C(N)=O)c2cc(Cl)c(F)cc21)c1cccs1',
#  'CC(=O)c1cccc(NC(=O)C(CC(C)C)NS(=O)(=O)c2ccc3c(c2)CCN3C(C)=O)c1',
#  'CC(N=c1nc(N=c2cc(C3CCC3)[nH][nH]2)cc[nH]1)c1ccc2[nH]ccc2c1',
#  'COc1ccc2c(ccc(=O)n2CC(=O)O)c1',
#  'COc1ccc(C)c(-c2cc3ccc(C)cc3c(=N)[nH]2)c1',
#  'CS(=O)(=O)c1ccc(C(=O)NCCCC(=O)N2CCN(c3ccccc3F)CC2)cc1[N+](=O)[O-]',
#  'CC(C)CC(C(=O)N=c1[nH]ccs1)N1Cc2ccccc2C1',
#  'COc1ccc(-c2nc3ccccc3c(=O)n2NC(=O)Cc2ccccc2)cc1',
#  'Cc1[nH]c(=NS(=O)(=O)c2cccc([N+](=O)[O-])c2)sc1C(C)(C)C',
#  'COc1ccc(C2SCC(=O)Nc3[nH]ncc32)c(OC)c1OC',
#  'OC(COc1ccccc1)CN1CCC(Cc2ccccc2)CC1',
#  'COc1cccc2c1OCC(CO)C2N(C)C(=O)Nc1ccc(Cl)cc1Cl',
#  'O=C(NCc1ccccc1)C1CC1C(=O)NC(Cc1ccccc1)C(O)C(O)C(Cc1ccccc1)NC(=O)C1CC1C(=O)NCc1ccccc1',
#  'CCOc1cccc2cc(-c3n[nH]c(=NCc4ccco4)s3)c(=O)oc12',
#  'Nc1ccccc1C(=O)Nc1ccc(CCN2CCc3ccccc3C2)cc1',
#  'CN(Cc1ccc(Cl)cc1)c1cc(C(=O)N=c2cc[nH]cc2)ncn1',
#  'Cn1cnnc1C1CCN(C(=O)CCCOc2ccccc2F)CC1',
#  'O=C(O)c1c(-c2ccc[nH]c2=O)c2cc(C(F)(F)F)ccc2n1Cc1ccc(OC(F)F)cc1',
#  'CCc1ccc(CN2CCc3[nH]nc(C(=O)N4CCNC(=O)C4)c3C2)o1',
#  'CC(C)CCn1nnc(O)c1C(N)=O',
#  'COc1ccc2cc(CC3CCCCN3)c3cc(OC)c(OC)cc3c2c1',
#  'CC(C)CN(CC(O)C(Cc1ccccc1)NC(=O)OC1COC2OCCC12)S(=O)(=O)c1ccc2[nH]c(=NCCCN(C)C)sc2c1',
#  'COc1ccc2cc(Br)c(=O)oc2c1',
#  'CCN(CC)C(=O)C1=C(c2ccc(Cl)c(Cl)c2)CCC1',
#  'Cc1cc(=O)oc2cc(NC(=O)CCCCCCNC(=O)c3cccnc3)ccc12',
#  'CC(=O)NCC1CC(c2ccc(-n3ccnc3)c(F)c2)=NO1',
#  'COC(=O)CSc1ccc(CC2CCN(C3CCN(C(=O)c4cccc5ccccc45)CC3)CC2)cc1',
#  'CSC(=N)Nc1ccc(CCc2csc(=NC(C)=O)[nH]2)cc1',
#  'CC(C)n1ncc2c(C(=O)N=c3nccc[nH]3)cc(-c3ccsc3)nc21',
#  'CC(C)(C)c1cc(C(=O)CCCC2CC2)cc2c1OCC2(C)C',
#  'O=S(=O)(O)CCCCCCn1ccnc1',
#  'Cc1noc(C)c1-c1cccc(CNCc2ccc(-c3ccc(-c4nc5cc(C(F)(F)F)ccc5[nH]4)s3)cc2)c1',
#  'Cc1cccc(CNC2CCCc3c2cnn3C)c1',
#  'COc1ccc(NC(=O)Nc2ccc3c(c2)C(=O)N(C(C)CO)CC(C)C(CN(C)S(=O)(=O)c2cccs2)O3)cc1',
#  'N#CC1CCCN1C(=O)C(N)Cc1ccc(-c2cn(Cc3cccc(Cl)c3)nn2)cc1',
#  'Cc1noc(C)c1S(=O)(=O)NCc1ccc(-c2ccccc2)s1',
#  'COc1ccccc1N1CCN(c2cc3c(cc2C#N)[n+]([O-])c2cc(Cl)ccc2[n+]3[O-])CC1',
#  'CC(C)(C)CC(C)(C)NC(=O)NC1CCCCC1',
#  'O=c1c2c([nH]c3ccccc13)CCCCC2',
#  'Cc1ccn2c(Nc3ccc4c(c3)OCCO4)c(-c3ccc(C)o3)nc2c1',
#  'CCCCCn1cc(C(=O)NC(C)C23CC4CC(CC(C4)C2)C3)c(=O)c2ccccc21',
#  'O=C(NCCN1CCOCC1)c1sc2cc(Cl)ccc2c1Cl',
#  'COc1cccc(CN2C(=O)C(=O)c3cc(OC(F)(F)F)ccc32)c1',
#  'O=C(CCn1ncc2c(Cl)cccc21)NCC1CC1',
#  'Nc1ccc(-n2ccc(=O)c3c(=O)n(Cc4ccccc4)ccc32)cc1C(F)(F)F',
#  'CCCCOc1ccc(CC(=O)O)cc1-c1cc(-c2cccc(OC)c2OC)n(Cc2ccccc2)n1',
#  'O=C1c2cc(CCc3ccc(C(F)(F)F)cc3)ccc2OCCN1Cc1ccccn1',
#  'CC1(C)CCC2(C(=O)O)CCC3(C)C(=CCC4C5(C)CCC(OC(=O)CCN6CCOCC6)C(C)(C)C5CCC43C)C2C1',
#  'CC1=Nc2ncnn2C(c2cn(-c3ccccc3)nc2-c2ccc(Cl)cc2)C1C(=O)N=c1cccc[nH]1',
#  'O=C1N=C(C=C2COc3ccc(Br)cc3C2)C(=O)N1',
#  'CN(C)S(=O)(=O)c1ccc(Cl)c(C(=O)NNC(=O)Cn2ccc(C(F)(F)F)n2)c1',
#  'Cc1c(C(C)N=c2[nH]cnc3sccc23)cnn1C',
#  'Cc1ccc(NC(=O)COC(=O)C2COc3ccccc3O2)cc1S(=O)(=O)N1CCOCC1',
#  'O=[N+]([O-])c1ccc2c(c1)c(OCc1ccccc1)nn2CCOCCN1CCCCC1',
#  'O=C(NC(=S)N1CCCC1)c1ccccc1Cl',
#  'CCCC(=O)N1CCC(S(=O)(=O)c2ccc(CNC(=O)c3cc4ccncc4o3)nc2)CC1',
#  'COc1ccc(CCC(=O)NCCc2ccc(O)c(O)c2)cc1OC',
#  'CC(=O)OCC1OC(Oc2ccc(-c3nnc(-c4cccc(C#N)c4)o3)cc2)C(OC(C)=O)C(OC(C)=O)C1OC(C)=O',
#  'CCCCn1cc(CO)[n+](CCC)n1',
#  'O=C(CCN1C(=O)c2ccccc2S1(=O)=O)Nc1ccc(Cl)cc1',
#  'COc1ccc(NC(C)=O)cc1-c1nn(C(C)c2ccc(Cl)cc2)c(=O)c2c(C3CC3)noc12',
#  'CC(=O)Nc1c(N)cc(C(=O)O)cc1O',
#  'O=c1cc(-c2cc[nH]c(=NC3CCOCC3)n2)ccn1C(CO)c1cccc(F)c1',
#  'CN(Cc1nnc(C2CC2)n1C)C1CCN(Cc2ccccc2F)C1',
#  'CCC1(CC)OC2COC3(COS(N)(=O)=O)OC(C)(C)OC3C2O1',
#  'CCCCCNC(=O)CCc1c[nH]c2ccccc12',
#  'Cc1cccc(N=c2c(C(=O)O)c[nH]c3c2cnn3-c2ccccc2)c1',
#  'CC(C)N=c1cc(-n2ncc3cc(C#N)cnc32)[nH]cc1C(=O)NCCc1ccc(S(N)(=O)=O)cc1',
#  'C[S+]([O-])(=NS(=O)(=O)c1ccc(Cl)cc1)c1ccccc1',
#  'O=C(c1ccccn1)C12Cc3cnn(-c4ccc(F)cc4)c3CC1CCN(S(=O)(=O)c1cccc(C(F)(F)F)c1)C2',
#  'O=S(=O)(c1ccc2c(c1)CCN2S(=O)(=O)c1cccc(F)c1)c1ccc2c(c1)OCCO2',
#  'O=C(NCc1ccc(O)cc1)c1cc2ccc(O)cc2cc1O',
#  'Cc1ccc(-n2nnc3c2CCN(C(=O)c2cccc(C(F)(F)F)c2Cl)C3C)nc1',
#  'CCOC(=O)c1c(CSc2cc(C)cc(C)c2)n(C)c2ccc(O)cc12',
#  'COc1ccc2[nH]c(C)c(CC(=O)NC(CCCCCC(=O)O)C(=O)NCCc3c(-c4ccccc4)[nH]c4ccccc34)c2c1',
#  'CN(C)CCN=C1c2ccccc2C2C(c3ccccc31)C2(F)F',
#  'COc1ccccc1CNC(=O)c1nn(-c2ccc(C)cc2)c(=O)c2c1c1ccccc1n2C',
#  'COc1cc2ncc(SC3CCCCC3)nc2cc1OC',
#  'COc1cc2oc(=O)cc(C)c2cc1-c1ccc(C#N)n1CC1CCCCC1',
#  'COC(=O)NC(c1cccc(F)c1)C(C(C)=O)C(=O)OC',
#  'CCCCCCCCCCCCCCCCCCOCC(COC(=O)N(CC[N+](C)(C)C)C(C)=O)OC(C)=O',
#  'CCC12CCCN3CC(Br)C4(c5ccccc5NC4C(Cl)(C(=O)OC)C1)C32',
#  'CCc1cc2cc(NS(=O)(=O)c3ccc(C#N)cc3OC)ccc2n(C)c1=O',
#  'OCC1(Cc2cccc(Cl)c2)CCCN(c2ncccn2)C1',
#  'O=S(=O)(N=c1nccc[nH]1)c1ccc(N=c2[nH]cnc3ccccc23)cc1',
#  'Cc1ccccc1C(=O)NCCCCCC(=O)O',
#  'CCOC(=O)c1ccc(NC(=O)C2C(C)=Nc3nc(CCCO)nn3C2c2cccc(C)c2)cc1',
#  'O=C(Cn1cccc1C(=O)c1ccccc1)NCCc1ccccc1',
#  'Fc1ccc(C=Cc2cc3ccccc3nc2Cl)cc1',
#  'CCc1cc(C(=O)Cc2ccccn2)c(O)cc1O',
#  'CC1CCN(C(=O)C(N)CCNCc2ccc(Cl)cc2)CC1',
#  'O=C1C=CC2CCC1C2',
#  'O=C(CC(c1ccccc1)C(C(=O)O)C(=O)O)c1ccc(Br)cc1',
#  'Cc1cc(=Nc2cccc(Cl)c2Cl)n2[nH]cnc2n1',
#  'CC1OC(=O)C(CCCCCCCCCCCCCCCCCc2ccccc2)C1O',
#  'COc1c(C(=O)NC2CCCCC2O)cc(Cc2ccc(C)nc2)c2ccccc12',
#  'CC(C)C(NC(=O)c1ccc(Cl)cc1Cl)C(=O)NNc1cccc(C(=O)O)c1',
#  'O=C(NCc1cccs1)N1CCC(c2nc(-c3ccc(F)cc3)no2)CC1',
#  'CCN(C=Nc1ccn(C2CCC(CO)O2)c(=O)n1)CC',
#  'O=C(NCCC(c1ccccc1)c1ccccc1)c1ccncc1',
#  'c1csc(-c2noc(CCCN3CCCC3Cn3cccn3)n2)c1',
#  'CC(=O)N=c1[nH]n(C(C)=O)c2nnc(-c3ccccc3)c(-c3ccccc3)c12',
#  'Cc1ccc(N)c(C)c1OC(C)C1=NCCN1',
#  'CCCN(CC1CC1)c1cc(C)[nH]c(=Nc2c(Cl)cc(Cl)cc2Cl)n1',
#  'Cc1nn(-c2ccccc2)c2c1cnc1c(C(=O)Nc3sc4c(c3C(N)=O)CCCC4)c(=Nc3ccccc3)[nH]n12',
#  'CC(C)c1cc(C(=O)N2CCC(N3CCOCC3)C2)[nH]n1',
#  'CC(=O)OCOC(=O)C1CC(C)(C)N(OC(C)=O)C1(C)C',
#  'CCC(NC(=O)C1CC(S(=O)(=O)c2ccc(F)cc2)CN1C(C)=O)C(=O)c1nc2ccccc2o1',
#  'Cn1nc(-c2ccc(F)cc2)c(-c2ccc3nc(NC(=O)c4ccnc(F)c4)cn3n2)c1N1CCN(CC(O)C(F)(F)F)CC1',
#  'CCN1CCN(C(C)CCc2ccccc2)CC1',
#  'Cc1cc2c(c(C(N)=O)c1C)-c1cccc(F)c1C2=O',
#  'CC(C)CNC(=O)C(CCO)CC(O)C(Cc1ccccc1)NC(=O)CC(NC(=O)CC(C)C)C(=O)O',
#  'COC(=O)Cn1c(CN2CCOCC2)nc2c1c(=O)n(C)c(=O)n2C',
#  'CN(CCCCCCCCCCCCOc1ccc2c(=O)cc(-c3ccc(N(C)C)cc3)oc2c1)Cc1ccccc1',
#  'CCC(=O)N1CCCC(n2nc(-c3ccc(Oc4ccccc4)cc3)c3c(=N)[nH]cnc32)C1',
#  'COC(=O)C1=CCC23CCC(C(C)(C=CC=C(C)C(=O)N4CC4)OC2=O)C3(OC(C)=O)CC1',
#  'CCCN1C(=O)C(C)(C)COc2cc(NS(=O)(=O)Cc3ccc(C)cc3)ccc21',
#  'Cc1cn2cc(C#N)cc2c(C#Cc2cccc(F)c2)n1',
#  'COc1ccc2c(c1)CCN1C(=O)C3CCCC(C21)N3S(=O)(=O)N1CC(C)OC(C)C1',
#  'Fc1cccc(-c2nc(CN3CCOC(Cn4cncn4)C3)co2)c1',
#  'NC(=O)CSc1nnc(Cn2cnc3ccccc32)o1',
#  'FC(F)(F)C1CCN(c2nccnc2C2CN(c3ccc4ccccc4n3)C2)CC1',
#  'COc1cc2[nH]c(=Nc3ccc(C(=O)O)cc3)[nH]c(=O)c2cc1OC',
#  'CCCCCc1cc2c(CCCN)cccc2[nH]c1=N',
#  'CC(C)C1=CC2CC3(C=O)C4CCC(C)C4CC2(CSC2CCCCC2)C13C(=O)O',
#  'CC(CCc1ccccc1)NC(=O)c1ccccc1F',
#  'CS(=O)(=O)NC(Cc1ccccc1)C(=O)N1CCCC1C(=O)NCC1CCC(N)CC1',
#  'OC(c1ccccc1)C1OC1c1ccc(-c2ccccc2)cc1',
#  'COc1ccccc1OCCN(C)CC(O)COc1cccc2[nH]c3ccccc3c12',
#  'Fc1ccc(C2N=C(N3CCCC3)N=C3c4ccccc4CCC32)cc1',
#  'COc1ccc(C=O)cc1Oc1ccc(CC2c3c(cc(OC)c4c3Oc3cc5c(cc3O4)CCN(C)C5=O)CCN2C)cc1',
#  'Cc1ccc(C(=O)C=Cc2cc(C=CC(O)=NO)n(C)c2)cc1',
#  'Cc1ccc(C(C(=O)NCCC(c2ccccc2)c2ccccc2)c2ccccc2)cc1',
#  'CCCSc1nc(SC(CC)C(N)=O)nc2c1ncn2-c1ccccc1',
#  'O=C(COC(=O)c1cnc(Cl)c(Cl)c1)NCc1ccc2c(c1)OCO2',
#  'CCCCNC(=O)c1ccc2c(c1)nc(-c1cccc(Oc3ccccc3)c1)n2C(CCCN=C(N)N)C(N)=O',
#  'CC(=O)NC(C)Cc1ccc(C#Cc2cnc(OCc3ccccn3)nc2)cc1',
#  'CC(C)(C)n1nnnc1C(c1ccccc1O)N1CCc2ccccc2C1',
#  'CNC(=O)c1ccc(CCC(=O)N=CC(=O)N(C)c2ccc(Cl)c(COc3cccn4c(Br)c(C)nc34)c2Cl)cc1',
#  'CC(=O)c1cccc(NCC(=O)NC(N)=O)c1',
#  'CCN(CC)c1cc2[nH]c(C3CCCCC3)nc2cc1NC(=O)c1ccc(N(C)C)cc1',
#  'CCOC(=O)CCN(C(=O)c1ccc2c(c1)nc1n2CCN(C(=O)OC(C)C)C1Cc1ccc(C(=N)NC(=O)OC(C)C)cc1)c1ccccc1',
#  'CC1COc2c(NCCN=c3cccc[nH]3)c(F)c(N)c3c(=O)c(C#N)cn1c23',
#  'O=C(CCCN1C(=O)C(c2ccccc2)Oc2cccnc21)Nc1ccccc1C(F)(F)F',
#  'CCCCCCCn1c2c(c(=N)c3c1CCC3)CCCC2',
#  'Cc1cccc(N=c2[nH]c(N)c([N+](=O)[O-])c(=NCCO)[nH]2)c1',
#  'O=C(O)c1ccccc1C(=O)Nc1ccc2c(c1)C(=O)c1ccccc1-2',
#  'Cc1nn(Cc2c(F)c(F)c(F)c(F)c2F)c(C)c1NC(=O)c1ccc(COc2ccccc2Cl)cc1',
#  'C#Cc1cccc(N=c2[nH]cnc3ccc(-c4ccc(CO)o4)cc23)c1',
#  'COc1ccc(-c2nc(CNCc3ccc(C(C)(C)C)cc3)co2)cc1',
#  'CC(C)c1nnc2sc(CC3CN(C(C)C)CCO3)nn12',
#  'CN1CN(C)c2nc3n(Cc4ccc(F)cc4)c(=O)cc(O)n3c2C1=O',
#  'CN=c1[nH]c(-c2ccc(CCN3CCN(c4nc5ccccc5nc4Cl)CC3)cc2)c(C)s1',
#  'O=C1NC(Cc2ccccc2)c2nc3ccc(Cl)cc3c(=O)n2-c2ncccc21',
#  'CCCCCC=CCC=CCC=CC=CC(CCCC(=O)O)C(O)=NO',
#  'COCC#Cc1c[nH]c(=N)c2oc(-c3csc4cnccc34)cc12',
#  'NS(=O)(=O)c1cc(C(=O)NC(Cc2ccccc2)C(=O)O)ccc1Cl',
#  'CN(C)NC(=O)Nc1cccc2c1C(=O)c1c(-c3ccco3)n[nH]c1-2',
#  'Cc1cc(Cl)c(Oc2ccncc2C(=O)N2CCN(C3CC3)c3ccccc32)cc1Cl',
#  'CN(C)c1ccc(N=Nc2ccc(C=Cc3ccnc4ccccc34)cc2)cc1',
#  'CC(c1ccccc1)N(C(=O)c1ccc(O)cc1O)c1ccc(C(=O)N(C)C)cc1',
#  'CCCCCCCCNC(=O)C(Cc1ccc(OCc2ccc3ccccc3n2)cc1)NC(=O)C1CCC(CN)CC1',
#  'N#Cc1cccc(-n2cnc(-c3ccccn3)c2)c1',
#  'O=C(NCCN1CCC(C(=O)c2ccc(F)cc2)CC1)Nc1ccccc1',
#  'Cc1ccc(S(=O)(=O)NC(=O)Nc2ccc(Cl)cc2C(F)(F)F)cc1',
#  'CCn1nc(-c2ccc(C)o2)nc2c(=O)n(C)c(=O)nc1-2',
#  'N#Cc1cccc(-c2ccc3c(cnn3-c3ccc(F)cc3)c2)c1',
#  'CC(F)(F)c1ccc(Cc2cc(C3OC(CO)C(O)C(O)C3O)c3c(c2Cl)OCC3)cc1',
#  'CCN(C)CCN1C(=O)C(OC)C(c2ccc(OC)cc2)Sc2cc(Cl)ccc21',
#  'CC1=CCCC(C)(C)C1CCC(=O)C=Cc1cccc([N+](=O)[O-])c1',
#  'CC(C)Oc1cc(-c2[nH]nc3ccc(C(=O)NN4CCCC4CCc4ccccc4)cc23)ccn1',
#  'CN(C)CCOc1cccc(C2=C(c3c[nH]c4ccccc34)C(=O)NC2=O)c1',
#  'Cc1cccc(SC2CCN(C(=O)C3CCC(=O)N(C4CC4)C3)CC2)c1',
#  'Cn1cncc1CN1CC(N(CC2CCNCC2)S(=O)(=O)c2ccccn2)Cc2cc(C#N)ccc21',
#  'NC(=O)C12CC3CC(C1)C(N1CCC(Cc4ccccc4)C1=O)C(C3)C2',
#  'COC(=O)C1Cc2c([nH]c3ccccc23)C(c2ccc(C)cc2)N1C(=O)C(=O)c1c[nH]c2ccccc12',
#  'C=CC(=O)Nc1cc2c(=Nc3cc(F)c(Br)cc3F)[nH]cnc2cc1OCCNC(C)=O',
#  'Oc1cc(-c2ccc(Cl)cc2)c(O)n1CN1CCN(c2ncccn2)CC1',
#  'NC(=O)c1sc2nc3c(c(-c4ccc(C(F)(F)F)o4)c2c1N)CCCCCC3',
#  'COCC(C)NC(=O)CCSc1nc(-c2ccc(OC)cc2)cc(C(F)(F)F)n1',
#  'O=C(N=c1[nH]nc(-c2c(Cl)cccc2Cl)s1)c1ccc2c(c1)NCCO2',
#  'CC(NC(=O)NC(C(=O)N1CCCC1C(=O)NC(C(=O)c1nc2ccccc2o1)C(C)C)C(C)C)C(=O)O',
#  'CCCCCCC#Cc1c(CCCCCC)oc2nc(=O)n(Cc3cn(Cc4ccccc4)nn3)cc12',
#  'Cc1ccc(-n2c(CSc3nc(C)cc(C)n3)nnc2SCC(=O)N2CCCC2)cc1',
#  'O=C(Cc1cccc(OCC(F)(F)F)c1)N=c1ccc(CCCCc2n[nH]c(=NC(=O)Cc3ccccc3)s2)n[nH]1',
#  'COc1ccc(-c2n[nH]c3nc(=O)c4ccccc4n23)cc1',
#  'C=C(C)C1CCC2(C(=O)NCCN(CC)CC)CCC3(C)C(CCC4C5(C)CC=C(c6ccc(C(=O)O)cc6)C(C)(C)C5CCC43C)C12',
#  'CCC(CC)N=c1c2c([nH]c3c(-c4ccc(OC)cc4C)c(C(F)(F)F)nn13)CCC2',
#  'CCCCC(CC(CCc1ccc(-c2ccc(-c3ncc[nH]3)cc2)cc1)C(=O)NC(C(=O)NC)C(C)(C)C)C(=O)O',
#  'O=C(N=c1[nH]c2ccc(F)cc2s1)c1cccc(O)c1O',
#  'Cc1cc(C)n(CCCNC(=O)c2ccc(S(=O)(=O)NCc3ccco3)cc2)n1',
#  'O=C(CNc1ccc(F)cc1)NN=C1CCCc2ccccc21',
#  'O=C(Cc1ccccc1)Nc1cccc2c1C(=O)C(=O)NC2=O',
#  'c1cc2oc(-c3cnc4ccc(OCCC5CCCN5)nn34)cc2cn1',
#  'N=C(N)NC(=O)c1nc(Cl)c(=NCCc2ccc(F)cc2)[nH]c1N',
#  'COc1cccc(CNCCCN=c2cc[nH]c3cc(Cc4ccc(F)cc4Cl)ccc23)c1O',
#  'CC(C)C(NC(=O)Cn1c(-c2ccc(F)cc2)ncc(N)c1=O)C(=O)c1nnc(-c2cccnc2)o1',
#  'NC1CC(N)CN(c2cc(=Nc3ccc(NC(=O)c4ccc5ccccc5c4O)cc3)cc(N3CC(N)CC(N)C3)[nH]2)C1',
#  'CC(C)c1ccccc1SC1C(=O)CC(CCC(=O)N2CCNCC2)(c2ccccc2)OC1=O',
#  'Cc1c(O)n(-c2ccc(S(=O)(=O)C(F)(F)F)cc2)c(=O)n1Cc1cccnc1',
#  'Cc1c(C(=O)NCCCCN)nn(-c2ccc(Cl)cc2Cl)c1-c1ccc(Cl)cc1',
#  'Cc1cc(C)cc(N=C2CC(=O)CC(c3ccco3)C2)c1',
#  'CCn1c(C)nnc1CN(C)C1CCN(CC2CCC2)C1',
#  'CC=CC(CC(=O)O)CC(=O)NCCC1CN(S(=O)(=O)C(F)(F)F)c2ccccc21',
#  'Cc1cc(=Nc2cccc(C(=O)O)c2)n2[nH]cnc2n1',
#  'CCC(=NNC(=O)c1ccc(F)cc1)c1ccccc1',
#  'Cn1c2ccccc2c2n[nH]c(=O)c(-c3ccccc3)c21',
#  'Cc1nc2ccccc2c(=O)n1-c1ccc(NC(=O)CNN=Cc2ccc(Cl)cc2)cc1',
#  'CC(C)c1ccc(-n2cc(C(=O)c3ccc(N)cc3)nn2)cc1',
#  'Fc1ccc(Cn2c(=NC3CCN(CCc4ccncc4)CC3)[nH]c3ccccc32)cc1',
#  'Cc1ccc2c(N3CCN(CCc4cccc(NC(=O)C(C)C)c4)CC3)cccc2n1',
#  'C=CC(CC(O)c1ccc(OC)cc1)c1cccc(OC)c1',
#  'Cc1nnc(C(C)N2CCc3[nH]c4ccc(Cl)cc4c3C2)o1',
#  'COC(=O)c1cc(OC)c(OC)cc1-n1cnc2cc(OC)c(OC)cc2c1=O',
#  'O=C(CN1CCCN(S(=O)(=O)c2ccc(F)cc2)CC1)Nc1c(Cl)cccc1Cl',
#  'COc1ccc2c(c1)CCc1c(C(=O)Nc3c(C)nn(Cc4ccc(Cl)c(Cl)c4)c3C)noc1-2',
#  'C=C1C2CCC3C4(C)CC(O)CC(C(=O)OC)C4CCC3(C2)C1O',
#  'Cc1cc(=O)oc2cc(OCCCCCCCN3CCN(CC(=O)N=c4c5c([nH]c6ccccc46)CCCC5)CC3)ccc12',
#  'Cc1c(F)cccc1N1CCN(Cc2ccc(F)cc2Cl)C(=O)C1=O',
#  'O=C1c2ccccc2C(=O)C12C(c1ccccc1)C1CSCN1C21C(=O)Nc2ccccc21',
#  'Clc1cccc(N=c2[nH]c(=Nc3cccc(Cl)c3)[nH]c(=Nc3cccc(Cl)c3)[nH]2)c1',
#  'O=S(=O)(N=c1[nH]ccs1)c1ccc2c(c1)OCCC2Oc1ccc(C(F)(F)F)cc1-c1ccc(F)cn1',
#  'O=C(Nc1ccccc1)N(CCCN1CCOCC1)Cc1ccccc1F',
#  'O=C(c1ccc2cc(Oc3ccc(C(F)(F)F)cn3)ccc2n1)N1CCc2ccncc2C1',
#  'COc1cc(CC2=NC(=O)N(CC(=O)Nc3ccc(C)cc3)C2=O)ccc1Oc1ccc([N+](=O)[O-])cn1',
#  'CSc1nc2c3c(nn(C4OC(CO)C(O)C4O)c3n1)C(=N)NN2C',
#  'O=C1CN(C(=O)CN(CC2CCC2)CC(F)(F)F)CCN1',
#  'Clc1ccc2c(=NCCNc3ccc(Br)cc3)cc[nH]c2c1',
#  'O=C(NCc1ccccc1)c1nc(-c2ccccc2)[nH]c1C(=O)O',
#  'C=CC(=O)N1CCCC(n2nc(-c3ccc(OCc4ccccc4)cc3)c3c(=N)[nH]cnc32)C1',
#  'CCN(CC)N=Cc1c2ccccc2cc2ccccc12',
#  'Cc1c(O)c(=O)ccn1CCCn1ccnc1',
#  'CC1(C)CC=C(c2cc(CCO)ccc2NC(=O)c2nc(C#N)c[nH]2)CC1',
#  'CCOC(=O)C1C(C=NCc2ccc(Cl)cc2)NC(=O)NC1c1ccccc1',
#  'CCC[S+]([O-])c1cc(=NC(Cc2ccc(NC(=O)c3c(Cl)cncc3Cl)cc2)C(=O)O)[nH]cc1Cl',
#  'O=C(CSc1nncs1)N=c1cc(-c2ccccc2)[nH]n1-c1ccccc1',
#  'Cc1nc2cc3[nH]c4ccccc4c(=O)c3cc2s1',
#  'CCC(CC)(c1ccc(OCC(O)=NO)c(C)c1)c1cc(C)c(CCC(O)C(C)(C)C)s1',
#  'CCCCCOC(=O)N1CCN(C(=O)C(CCC(=O)O)NC(=O)c2cc(N3CCN(CCOCCC)CC3)cc(-c3ccccc3)n2)CC1',
#  'O=c1sc2ccccc2n1CCCCCN1CCN(CCn2c(=O)sc3ccccc32)CC1',
#  'CCn1c(=NC(=O)c2ccc3cc4n(c3c2)C(C)CCNC4=O)[nH]c2ccccc21',
#  'N=c1[nH]cc(CC(C(=O)O)c2c[nH]cn2)cc1Cl',
#  'N#CCn1nnnc1CNC(=O)c1ccc(-c2ccccc2)cc1',
#  'C=C(C)C1CCC2(NC(=O)NCCO)CCC3(C)C(CCC4C5(C)CCC(O)C(C)(C)C5CCC43C)C12',
#  'O=C(Nc1cnn(S(=O)(=O)c2ccc3c(c2)OCCCO3)c1)c1ccccn1',
#  'CCn1cc(C(=O)NCc2ccco2)c2cc(OC)c(OC)cc2c1=O',
#  'COc1cc(O)c2c(=O)c3cc4c5c(c(O)cc(O)c5c3oc2c1)OC4(C)C',
#  'CCCCNC(CC)CN=C1CC(c2ccc(Cl)cc2Cl)Cc2[nH]c3ccc(Cl)cc3c(=O)c21',
#  'O=C(Nc1ccc(Br)cc1F)c1cc(CN2CCOCC2)on1',
#  'CCNC(=S)NN=C(c1ccccc1)c1cccc(C)n1',
#  'CCOC(=O)NC(Cc1ccc(N)cc1)C(=O)NC(C(=O)NC(C)C(=O)NC(CC(C)C)C(N)=O)C(C)C',
#  'N=c1nc(SC2CCCC2)c2ncn(C=C3CC3(CO)CO)c2[nH]1',
#  'COc1ccc(N(C)c2nc(=NCCCO)c3ccccc3[nH]2)cc1',
#  'CN(C)C(=O)COC(=O)c1ccc(S(=O)(=O)NCc2ccco2)cc1',
#  'COc1cccc(C=NN=c2[nH]c(=N)c3ncn(C4OC(CO)C(O)C4O)c3[nH]2)c1',
#  'CCOC(=O)C1(Cc2ccc(OC)cc2)CCN(C(=O)C2CCCN2C(C)=O)CC1',
#  'CCC(C)N=c1[nH]c2c(c(=O)[nH]c(=O)n2C)n1CCOc1ccccc1',
#  'Oc1c2c(c(O)n1Cc1ccccc1)C1C=CC2C1=C1CCCCC1',
#  'COc1cc(-c2nnc(COCC3CC(c4ccc(C)cc4)=NO3)o2)cc(OC)c1OC',
#  'O=C(Nc1ccc(N2CCOCC2)nc1)c1n[nH]c(=Nc2ccccc2F)o1',
#  'O=C(c1cc(CO)ccc1-n1nccn1)N1C2CCC1C(COc1ccc(F)cn1)C2',
#  'CC1CCN(S(=O)(=O)c2cn(CC(=O)Nc3ccc(F)c(Cl)c3)c(=O)c3ccccc23)CC1',
#  'CCN(CC)CCNC(=O)c1cccc(S(=O)(=O)N=c2[nH]nc(S(N)(=O)=O)s2)c1',
#  'O=C1c2cccnc2S(=O)(=O)N1c1ccc([N+](=O)[O-])cc1',
#  'O=C(O)C(=O)N(Cc1cc(C(F)(F)F)cc(C(F)(F)F)c1)c1ccc(-c2ccc(OC(F)(F)F)cc2)cc1',
#  'O=S(=O)(Nc1ccc2[nH]cc(CCN3CCOCC3)c2c1)c1ccc2ccccc2n1',
#  'CCNC(=O)Nc1cn2c(-c3ncc(S(C)(=O)=O)cn3)cc(-c3cccnc3)cc2n1',
#  'CNc1ccc2[nH]cnc(=Nc3cccc(Br)c3)c2c1',
#  'COc1ccc(N=NC(=Nc2ccc(F)cc2)c2ccc(N(CCC#N)CCC#N)cc2)cc1',
#  'CC(C)(C)NC(=O)c1cn(C2CCCCC2)cc(C(=O)NC2CCN(Cc3ccccc3)C2)c1=O',
#  'Cc1cc(=O)oc2c1ccc1occc12',
#  'N#Cc1c(N2CCOCC2)nsc1-c1ccc(C(F)(F)F)cc1',
#  'Cn1nc(CC(=O)Nc2ccc(Br)c(Cl)c2)c2ccccc2c1=O',
#  'CCC(=O)NC1(C(F)(F)F)C(=O)N=C(C)C1C#N',
#  'Cc1ccc(Cn2c(C(C)N=c3[nH]c(-c4ccc(C)cc4)cs3)nc3cc(Cl)c(Cl)cc32)cc1',
#  'N#CC1CCCN1C(=O)CNC(=O)c1cccc2ccncc12',
#  'CCC(C)n1cc(C#N)c2cc(-n3cc(C(=O)O)cn3)ccc21',
#  'CC(C(=O)NCc1ccc(C(F)(F)F)nc1OCc1cc(Cl)cc(Cl)c1)c1ccc(NS(C)(=O)=O)c(F)c1',
#  'Clc1ccc(N2CCN(CCc3cc4cccnc4[nH]3)CC2)cc1',
#  'CCOC(=O)c1cn(C2CC2)c2cc(N3CCN(CCC45CC6CC(CC(C6)C4)C5)CC3)c(F)cc2c1=O',
#  'COc1ccc(C2CC3CSC(=N)NC3(c3ccc(F)cc3F)CO2)cc1',
#  'CC(C)=NOC(c1ccccc1)c1ccc(Cl)cc1',
#  'c1ccc(Cn2c(CN3CCCC3)nc3ccccc32)cc1',
#  'CCn1c(O)c2c(c1O)C1(C(=O)OC)CCCN1C2c1ccc(-c2ccc(F)cc2)cc1',
#  'CCc1c(C#N)c(-c2ccc(-c3ccccc3SC)cc2)c(C(=O)O)n1C',
#  'COc1ccc(C(CNC(=O)Cc2ccc3ccccc3c2)N(C)C)cc1',
#  'CC(OC(=O)CN1C(=O)c2ccccc2C1=O)C(=O)NC1CCCCC1',
#  'N#Cc1cn(CC(=O)N2CCc3ccccc3C2)c2ccccc12',
#  'COc1cccc(NC(=O)NCC2(c3ccccc3)CCCCC2)c1',
#  'CC(C)(C)c1c(Cl)c(=O)c(-c2ccccc2)c(O)n1-c1ccccc1',
#  'O=C1NC(=O)C(=C(C=Cc2c[nH]c3ccccc23)c2ccc(Cl)cc2)C(=O)N1',
#  'O=C(Nc1cc(Cl)ccc1N1CCOCC1)c1cccnc1',
#  'c1ccc2c(c1)c(N1CCCCC1)cc1nc3c(cc(N4CCCCC4)c4ccccc43)nc12',
#  'CCON=C(C(=O)NC1C(=O)N2C(C(=O)O)=C(C=CC[n+]3ccc(-c4c[nH]c(C(=O)NC#N)c4C)cc3)CSC12)c1csc(=N)[nH]1',
#  'Cc1ccn2c(NC3CCCC3)c(-c3ccccn3)nc2c1',
#  'CC(C)c1ccc(NC(=O)N=c2[nH]c(C(N)C3CCCCC3)cs2)cc1',
#  'COc1ccc(-n2c(O)cc(Nc3ccc(F)cc3)c2O)c([N+](=O)[O-])c1',
#  'O=C(OC1(C2COCC(C3CC3)N2S(=O)(=O)c2ccc(Cl)cc2)CC1)N1CCC(O)C1',
#  'CC(=O)N1c2ccc(S(=O)(=O)N3CCCCC3)cc2CC1C(=O)Nc1ccc(C)cc1',
#  'Cc1ccc2nc(Cl)c(C=Nn3c(C)nnc3C)cc2c1',
#  'COc1cc(-c2cc(C#N)ccc2C)c(F)cc1-n1c(=O)ccc2cc(S(=O)(=O)N=c3cco[nH]3)ccc21',
#  'O=C(c1cccc(F)c1)N1CCC2(CC1)CN(c1ccc(-c3ccccc3)cc1)C2',
#  'CS(=O)(=O)c1ccc(-c2cnc3ccc(-c4ccc(C(F)(F)F)nc4)nn23)cc1',
#  'OCCN1CCN(C2CC(c3ccccc3)c3ccc(C(F)(F)F)cc32)CC1',
#  'Cc1ccc(Cc2c[nH]c(=NCCCCc3ncc(Br)cc3C)[nH]c2=O)cn1',
#  'C=CC(=O)Nc1ccc(NS(=O)(=O)c2ccc(N=c3nc4c(c[nH]3)N(C)C(=O)c3cc(C)ccc3N4C)cc2)cc1',
#  'Cc1cccc(C)c1N1CCN(C(=O)N2CCOCC2)CC1',
#  'Cc1ccc(-c2onc(C)c2C)cc1S(=O)(=O)Nc1cccc(Cl)c1C',
#  'COc1ccc(Cl)cc1N(C(C)C(=O)NC1CCCC1)S(C)(=O)=O',
#  'COc1ccc(NC(=O)CN(C)S(=O)(=O)c2ccc3nc(C)sc3c2)cc1Cl',
#  'CCOC(=O)C1CCCN(C(=O)c2cncc(Br)c2)CC1',
#  'NS(=O)(=O)c1cc(Cl)c(N=c2[nH]c3ccncc3c3c(=O)[nH]ccc23)c(Cl)c1',
#  'O=C(Nc1ccccc1Cl)c1cc(S(=O)(=O)N2CCOCC2)cs1',
#  'N#Cc1c(N)[n+]([O-])c2ccc(Cl)cc2[n+]1[O-]',
#  'Cc1ncc([N+](=O)[O-])n1CCSc1nnc(-c2ccccn2)o1',
#  'Oc1cc(C(O)N=c2cc(-c3cccc(OC(F)(F)F)c3)n(CCC3CCCCC3)[nH]2)c[nH]1',
#  'OCC1OC(n2cnc3c(=NC4CCCCC4)[nH]c(Sc4ccccc4)nc32)C(O)C1O',
#  'CC(C)c1[nH]nc(C(N)=O)c1N=NN(C)C',
#  'CC(Oc1c[nH]c(=O)c(C(=O)NCc2ccc(N3CCOCC3)cc2)c1)c1c(Cl)ccc(F)c1Cl',
#  'O=c1c(-c2ccc(Cl)cc2)n[nH]c2nc3ccccc3n12',
#  'CC1(C)CC(=O)C2C(=NC(=O)C23c2cc(Br)ccc2OC(=N)C3C(=O)OC(C)(C)C)C1',
#  'CCCCCCCCCCCCCCCCCCNC(=O)OCC(COC(=O)N(Cc1cccc[n+]1CCCC)C(C)=O)OC',
#  'COC(=O)c1cccc(-c2cc(=O)cc(N3CCOCC3)o2)c1',
#  'COC(=O)CN1C(=O)N(CCCCN2CCN(c3cccc(Cl)c3Cl)CC2)C(c2ccccc2)(c2ccccc2)C1=O',
#  'CN(C(=O)C(C)(C)C)c1ccccc1SSc1ccccc1N(C)C(=O)C(C)(C)C',
#  'CN(C)C(=O)c1cc2c[nH]c(=Nc3ccc(C(=O)N4CC5CNCC5C4)cn3)nc2n1C1CCCC1',
#  'CCCn1c(-c2ccc(Cl)cc2)cc(C(=O)NCCCN2CCN(c3cccc(C)c3C)CC2)c1C',
#  'CCCC(C(=O)O)c1cnc2sc(C)cc2c1-c1ccc(C)cc1',
#  'Cc1ccc(-c2cnc(N(Cc3ccc(C(O)=NO)cc3)CC(C)C)s2)cc1',
#  'N#Cc1cccc(C23CCC(N(CC4CCN(C5CCOCC5)CC4)C(=O)Nc4ccc(F)c(Cl)c4)CC2C3)c1',
#  'CCCCCNC(=O)Nc1c(C)cccc1OCCCn1cnc(-c2ccccc2C)c1',
#  'Cc1ccc(NC(=O)c2ccc(OCc3c(C)noc3C)cc2)cc1',
#  'CC(C)(C)CCN1CCC(CN2CCNC(=O)C2=O)CC1',
#  'COc1ccc(C2=CC(=Cc3cccnc3)C(=O)O2)cc1OC',
#  'O=C(CC1(O)C(=O)Nc2ccccc21)c1ccc(O)cc1',
#  'COc1ncc(-c2ccc3nccc(-c4ccc(Cn5cncn5)cc4)c3c2)cc1NS(=O)(=O)c1ccc(F)cc1',
#  'Cc1ccc(C2OC3(C(=O)c4ccccc4C3=O)c3c2c(O)n(-c2ccc4c(c2)OCO4)c3O)cc1',
#  'O=C(O)Cc1ccc(OCCCCCOc2ccc(CC(=O)O)cc2)cc1',
#  'COc1ccc(C=CC(=O)c2cc3ccc(OCc4cccc(OC)c4)cc3oc2=O)cc1',
#  'CCCCC12C3CC4C5C(C)=C(c6oc(O)c(C)c6OC)OC5(O3)C1CCN42',
#  'Cc1ccc(S(=O)(=O)NCCSS(=O)(=O)c2ccc(C)cc2)cc1',
#  'O=C(NC1CC1)C1CCCN1C(=O)NC1CCCCC1',
#  'COc1ccnc2c1cnn2C1OC(CO)C(O)C1O',
#  'O=C(O)c1ccc(NC(=O)c2ccc3cc(C(=O)O)ccc3c2)cc1',
#  'COc1c(N(C)C(=O)C=NC(=O)CCc2ccc(C(F)(F)F)cc2)ccc(SC)c1COc1cccc2ccc(C)nc12',
#  'O=C(O)C=Cc1ccc(N=c2c3ccccc3[nH]c3ccccc23)cc1',
#  'CCOCCCn1c(=N)c(C(N)=S)cc2c(=O)n3cccc(C)c3nc21',
#  'Cc1ccc(-n2cc(C(O)OCC(=O)Nc3c(C)cccc3C)cc2O)cc1',
#  'CN1CCN(c2ccc(=Nc3cc(-c4cccc(-n5ccc6cc(C7CC7)ncc6c5=O)c4CO)cn(C)c3=O)[nH]c2)CC1',
#  'Cc1c(C(=O)Nc2cccc(C(F)(F)F)c2)cc(-c2ccccc2)n1CCCN',
#  'O=C(O)C1(N(CCc2ccccn2)S(=O)(=O)c2ccc(-c3ccc(Cl)cc3)cc2)CC1c1ccccc1',
#  'CS(=O)(=O)Nc1ccccc1-c1ccc2[nH]c(C=Cc3cccc(C(F)(F)F)c3)nc2c1',
#  'Cc1nc(-c2cccc3ccccc23)sc1C(=O)N(C)CCO',
#  'CCCCCN(CCCCC)C(=O)N1CCN(C(=O)N(c2ccccc2)c2ccccc2)CC1',
#  'C=CCSc1nncn1N=Cc1ccc(OC)cc1',
#  'O=C(NCc1ccc(S(=O)(=O)c2cncc(Cl)c2)cn1)c1cc2ccncc2o1',
#  'COc1cc(NC(C)CCCN)c2nc(C(C)(C)C)ccc2c1',
#  'CN(CCOc1ccc(CC(=O)O)cc1Cl)C(=O)CCCCC1CCSS1',
#  'O=C(C[n+]1ccc2c(c1)nnn2-c1ccccc1)c1ccc(Cl)cc1',
#  'CCOC(=O)c1c(N=CC2C(=O)CC(C)(C)CC2=O)sc(C(C)=O)c1C',
#  'CCOC(=O)c1c(NC(=O)Cc2ccccc2)sc2c1CCNC2',
#  'Cc1nc(C(=O)NC2CCC3(O)C4Cc5ccc(O)c6c5C3(CCN4CC3CC3)C2O6)cc2ccccc12',
#  'C=c1c(C#N)c(O)n(-c2c(C)cccc2C(C)(C)C)c1=C',
#  'O=C(N=c1cnc(-c2ccncc2)c(-c2cccnc2)[nH]1)C1CC1',
#  'Cc1ccc(-c2n[nH]c(=O)n2N2C(=O)C=CC2=O)cc1',
#  'COc1ccc(S(=O)(=O)N2CCCCC2)cc1NS(=O)(=O)c1ccc(CNC(C)=O)cc1',
#  'Cc1ccc2c(OCCN3CCN(Cc4ccc5[nH]ccc5c4)CC3)cccc2n1',
#  'Cc1ccc2c(c1)C(O)(C#CC1CC1)C(=O)N2C',
#  'Cn1cncc1C(OCc1ccc(C#N)cc1C=Cc1ccccn1)c1ccc(C#N)cc1',
#  'CC(=O)Nc1ccc(N(CC2CCCCC2)C(C)=O)c(SCC2CCCCC2)c1',
#  'COc1ccc2c(c1)[nH]c1cc(OC)c(C)cc12',
#  'CC(=NNC(=O)C(O)c1ccccc1)c1cccnc1',
#  'CS(=O)(=O)Nc1ccc(-c2coc3cc(C#CC4CCOCC4)ccc3c2=O)cc1',
#  'Cc1ccc(CN=c2[nH]c(C)cs2)cc1',
#  'Cc1nc2cc(N=c3[nH]c(=Nc4ccc(O)cc4)[nH]c(=Nc4ccc(F)cc4)[nH]3)ccc2n1Cc1ccccc1',
#  'N=C(N)NC(Cc1ccccc1)C(=O)NCCCCCCCCOc1ccc(OCc2ccccc2)cc1',
#  'CC(C)CC(NC(=O)c1ccc(NCC(N)CS)cc1-c1ccccc1)C(=O)O',
#  'C=C(C)C1C=C2CC(=O)CCC2(C)CC1',
#  'Cc1cc(C)c2oc(-c3ccc(NC(=O)COc4cccc(C(F)(F)F)c4)cc3)nc2c1',
#  'CC(C)C1NC(C(=O)O)Cc2c1[nH]c1ccccc21',
#  'CCOC(=O)C1C(C(=O)NC(CC(C)C)C(=O)N2CCCC2C(=O)OCc2ccccc2)N1C(=O)C(Cc1ccccc1)NC(=O)OC(C)(C)C',
#  'O=C(c1cccc(C(F)(F)F)c1)C1CCCN(C(=O)c2cc(C3CC3)[nH]n2)C1',
#  'COc1cccc(C(=O)Nc2ccc(O)c(C)c2)c1',
#  'N#Cc1nc(-c2ccc(COc3ccc(Cl)cc3)o2)oc1N1CCC(C(N)=O)CC1',
#  'COc1cc(OCc2cccc(-c3ccc4nncn4c3)c2)c2cc(-c3cn4nc(OC)sc4n3)oc2c1',
#  'O=C1N(c2ccccc2)CC2CN(C3CCC3)CCN12',
#  'Cc1n[nH]c(SCC(=O)N2N=C(c3ccc(Cl)cc3)CC2c2ccco2)nc1=O',
#  'COc1ccccc1CNC(=NO)c1ccnc(Oc2cccc(F)c2)c1',
#  'Cc1cccc(N2CCN(CCCNC(=O)C3CCCN(c4ncnc5c4nc4n5CCCCC4)C3)CC2C)c1',
#  'O=C(NNC(=O)c1ccc([N+](=O)[O-])cc1C(=O)O)c1ccncc1',
#  'CN1CCC23c4c5ccc(O)c4OC2C(=O)C(C)(C)CC3C1C5',
#  'COc1cc(OC)c(Cl)c(-c2ccc(C(=O)N=c3ccc(C(=O)N4CCN(C)CC4)c[nH]3)c3nccnc23)c1Cl',
#  'COC(=O)C1C(C)=NC(=O)C1(N=c1[nH]ccs1)C(F)(F)F',
#  'COc1nc(N(C)C)ncc1-c1cc2c(n1C(C)C)C(c1ccc(Cl)cn1)N(c1cccc(Cl)c1F)C2=O',
#  'COC1CCN(c2nc(-c3cc(C)ccc3C)nc3c2CN(c2cc(C(C)C)ccc2C)CC3)C(C)C1',
#  'O=C(NCCNCCO)c1cccc2ccc(-c3ccccc3)nc12',
#  'NC(=O)C1CCC(CN=c2[nH]c(-c3ccccc3)cc(=NCc3ccc(Cl)cc3)[nH]2)CC1',
#  'Clc1cccc2c1[nH]c1c2ncc2[nH]c3ccccc3c21',
#  'N=c1[nH]cnc(N2CCN(C(CN3CCCCC3)c3ccc(C(F)(F)F)cc3)CC2)c1Br',
#  'O=S1(=O)NCC2(CC2)CN1Cc1ccccc1',
#  'FC(F)(F)c1ccc(-c2ccc(CN3C4=NCCN4c4ccccc43)cc2)cc1',
#  'COc1cc2c(c(Cl)c1OC)CCN(Cc1ccccc1)CC2c1ccc(C(N)=O)cc1',
#  'COc1ccc(N=C(C)c2c(O)c(C(C)=O)c(O)oc2=O)cc1',
#  'Cc1cccc(Nc2cc(=O)oc3c2ccc2ccccc23)c1',
#  'CCOC(=O)CCCCON=C(c1cccnc1)c1cccc(CN2CCc3c(sc4c3C(c3ccccc3Cl)=NCc3nnc(C)n3-4)C2)c1',
#  'Clc1ccc(-c2nc(-c3ccccc3)c(-c3ccccc3)n2CCCCCCCN=c2c3c([nH]c4ccccc24)CCCC3)cc1',
#  'Cc1cc(C(=O)CN2C(=O)NC(C)(c3ccc(F)c(F)c3)C2=O)c(C)n1C1CC1',
#  'COc1ccccc1-n1c(CSCc2cc(C(C)(C)C)c(O)c(C(C)(C)C)c2)n[nH]c1=S',
#  'CN1CCC=C(c2nsnc2OCCCCCC2CCN(CCCN3C(=O)CCc4ccccc43)CC2)C1',
#  'O=c1c(SC(=S)N2CCCC2)coc2ccccc12',
#  'COc1cc2c(Cc3ccc4nc(C)ccc4c3)cnc(C3CC3)c2cc1OC',
#  'COc1cccc(CN2CCCN(Cc3cccc(NC(=O)c4ccc(-c5ccccc5)cc4)c3)CC2)c1',
#  'N=c1[nH][nH]c2cc(-c3ccncn3)ccc12',
#  'CCOc1cccc(NN=C2CCC(C)n3c2ncc(C(=O)O)c3=O)c1',
#  'CCCCCCCOC1C(O)C(CC(C)C)OC(OCc2ccccc2)C1OCc1ccccc1',
#  'COc1ccc(CCC(=O)N=C(C)C(=O)O)cc1',
#  'CCOC(=O)C(O)C(O)c1cccc(-c2ccc(Oc3ccc(C(F)(F)F)c(C#N)c3)cc2)n1',
#  'CC(=O)c1cccc(NC(=O)CC2CCCC2)c1',
#  'CCCCCCCCCCC1C(=O)OC1CCCS(=O)(=O)CCCN(C)C',
#  'Oc1cccc(C2CN3CCCCC3CO2)c1',
#  'CC(C)N=c1[nH]c(-c2ccc(NCCCN3CCN(C)CC3)c(S(C)(=O)=O)c2)cc2ncn(C)c(=O)c12',
#  'CCCOc1ccc(-c2ccc(NC(=O)N3CCCC3C(=O)N3CCC4C3C(C)C(=O)N4C(=O)C3CC3)cc2)cc1',
#  'Cc1ccc(N(CCC#N)C(=O)CSc2ccc3c(c2)OCCO3)cc1',
#  'COc1[nH]c(=Nc2ccc(S(C)(=O)=O)cc2OCCF)ncc1Cl',
#  'CCOc1[nH]c(N=Cc2ccco2)c(C#N)c1C#N',
#  'CC(=NNC(=O)c1ccc(-c2ccccc2)cc1)c1cccc(N)c1',
#  'CN=C1SCCN1C',
#  'CC(C)Cc1cc(=O)n(C(=O)N(C)C)o1',
#  'Nc1ccc(-c2nnc(-c3ccc(Cl)cc3)o2)cc1',
#  'CN(C)C(=S)C1CSCN1N=O',
#  'C=CCn1ncc2cnc(C)n2c1=O',
#  'O=C(c1ccc(N=c2nccc[nH]2)c(Cl)c1)N1CCC(N2CCCCC2)CC1',
#  'CC(C)(O)c1ccc2c(c1)C(=O)CC1C(C)(C(=O)O)CCCC21C',
#  'Cn1cccc1C=NNC(=O)c1sc2cc(Cl)ccc2c1Cl',
#  'CCCC(=O)C=Cc1c(O)c(O)c2cc(O)c(O)c(O)c2c1O',
#  'CCC(NC(=O)N1CC(=O)NCC(Cc2cc(Cl)ccc2OC)C1=O)C(=O)N=c1nn[nH][nH]1',
#  'COc1ccc2c(=O)c3c(=O)n(-c4ccccc4)c(-c4ccc(C)cc4)nc3oc2c1',
#  'COc1ccc(C2CC(c3cc4ccccc4oc3=O)=NN2c2ccccc2)cc1OC',
#  'O=C1CC(c2ccc3c(c2)OCO3)CC2=Nc3ccccc3NC(c3cccnc3)C12',
#  'CCOc1ccc(-n2c(=O)[nH]c(O)c(N=Nc3c(C)n(C)n(-c4ccccc4)c3=O)c2=O)cc1',
#  'COc1cccc(-c2c(F)c(F)c(N=c3[nH]cccc3C(=O)O)c(F)c2F)c1',
#  'CN(CCCCCCCCN(C)C(=O)CCCCCNCC(=O)N1c2ccccc2C(=O)Nc2cccnc21)C(=O)CCCCCN',
#  'COc1cccc(F)c1CN1CC(NC(=O)c2ccc3[nH]nc(-c4ccnc(C)c4)c3c2)CCC1C(=O)NCCCNC(=O)OC(C)(C)C',
#  'COc1ncc(-c2ccc(N3CCC(N4CCc5ccc(F)cc54)CC3)nn2)cn1',
#  'CCS(=O)(=O)C1CC2=C(c3ccc(O)cc3)C(c3ccc(O)cc3)C1O2',
#  'COc1cccc(CN2C3CC4CC(C3)CC2C4)c1',
#  'O=C(c1ncoc1C1CCCO1)N1CCCC2(CCCCC2)C1',
#  'CC(C)Oc1cc(N=C(N)c2ccccn2)ccc1-c1ccc(-c2ccco2)o1',
#  'CC(NC(=O)C1CC2CC2N1C(=O)Cn1nc(C(N)=O)c2ccccc21)C1CC1(Cl)Cl',
#  'CCC1(CC)CC(NC(=O)Nc2ccc3c(c2)NC(=O)CC3)c2ccc(C(F)(F)F)cc2O1',
#  'Clc1ccc2c(c1)c1ccccc1n2CN1CCOCC1',
#  'CC(C)Oc1ccc(-c2nc(-c3cccc4c3OCCNC4CCC(=O)O)no2)cc1Cl',
#  'O=C(NCCc1c2n(c3ccccc13)Cc1ccccc1-2)C1CCC1',
#  'COc1ccc(CC(N)C(=O)N(C)C2C(CO)OC(n3cnc4c(N(C)C)ncnc43)C2O)cc1',
#  'O=C(C=Cc1ccc(Cl)c(Cl)c1)NCCCCCN1CCC(NC(=O)c2cccc(Cl)c2)CC1',
#  'COc1ccccc1N1CCN(CCC(=NO)c2csc3ccccc23)CC1',
#  'CNC(=O)c1ccc(-c2cc(C(=O)NC3CCCNC3)c(NC(N)=O)s2)cc1',
#  'COc1ccc(CN=Cc2c(=O)[nH]c(O)c3cccc(Br)c23)cc1O',
#  'O=C(Nc1sc2c(c1C(=O)O)CCCCC2)c1ccc(Cl)cc1',
#  'COc1cc2c(cc1OC)C1C(=O)c3cc4c(cc3C1N(C)C2=O)OCO4',
#  'O=C(CSc1nc(C2CC2)nc2ccccc12)Nc1ccccc1Cl',
#  'CCNC(NC(C)=O)C(=O)NCc1ccccc1',
#  'COc1ccc2ncc(S(=O)(=O)c3cccc(Cl)c3)c(N3CCC(C)CC3)c2c1',
#  'C1=NN(Cc2coc(-c3cccc4ccccc34)n2)CC1',
#  'CC(=NNC(=O)c1ccc(-n2c(C)ccc2C)cc1)C(=O)Nc1c(Cl)cccc1Cl',
#  'O=c1sc(=Nc2cccc(F)c2)[nH]c2c1[nH]c1ccccc12',
#  'Cc1[nH]c2ccccc2c1C(O)CN1CCN(c2cccc(C(F)(F)F)c2)CC1',
#  'CC(C)(Nc1ccc(Cl)c(NC(=O)OCCO)c1)C(=O)N=c1[nH]c2c(C(F)(F)F)cc3[nH]ncc3c2s1',
#  'NS(=O)(=O)c1ccccc1NS(=O)(=O)c1cccc(-c2ccc(CO)cc2)c1',
#  'CC(C)OCC(ON=C(C(=O)NC1C(=O)N(OS(=O)(=O)O)C1(C)C)c1csc(=N)[nH]1)c1cc(=O)c(O)cn1O',
#  'Cc1ccc(C(=O)NCC(C)N=Cc2cc(Cl)cc(Cl)c2O)c(O)c1',
#  'CCCCc1cc(C(=O)N=c2nn[nH][nH]2)nc(-c2ccc(CC)cc2)c1',
#  'CC(=O)c1sc(=Nc2nc3ccc(F)cc3s2)[nH]c1C',
#  'COC(=O)NC(C(=O)NN(CCCC(O)(Cc1ccccc1)C(=O)NC1c2ccccc2CC1O)Cc1ccccc1)C(C)(C)C',
#  'Cc1cc(=NC(=O)c2cccc(-n3c(O)ccc3O)c2)[nH]o1',
#  'CCOc1ccc(NC(=O)CN(C)C(=O)c2ccc(COc3ccccc3)o2)cc1OCC',
#  'CN1CCC1COc1cncnc1',
#  'CN1C(=O)c2cccnc2N(C2CC2)c2ncc(Cl)cc21',
#  'COc1ccc(C(=O)Oc2ccc(C(O)CNC(C)(C)C)cc2OC(=O)c2ccc(OC)cc2)cc1',
#  'O=C(CC1CC2(CCNCC2)c2ccccc21)NCC1CC1',
#  'O=c1c2ccccc2nnn1CCCCN1CCN(c2nsc3ccccc23)CC1',
#  'COc1ccc(C2(NC(=O)c3ccc(=O)n(C)n3)CCCC2)cc1',
#  'COCCNC(=O)C(C(=O)c1ccc(F)cc1)n1cc(C)ccc1=O',
#  'CCCCc1nc2ccccc2n1Cc1nnc2n1-c1ccccc1SC2',
#  'COc1ccc(CN=c2ccc3ncc(-c4cccc(OC(F)(F)F)c4)n3[nH]2)cc1',
#  'COc1ccc(Cl)cc1C(=O)CCCCN1CCC2(CC1)NC(=O)NC2=O',
#  'CNC(=O)C(NC(=O)c1ccc(C2CC2)c(OCC2CCOCC2)n1)C(C)(C)C',
#  'FC(F)(F)c1ccc(-c2nc3cc(-c4ncccc4C(F)(F)F)ccc3[nH]2)cc1',
#  'O=C1CC(c2ccccc2F)n2ncnc2N1',
#  'COc1ccc2c(c1O)C13CCN(C)C(C2)C1CC(=O)C(=O)C3',
#  'COC(=O)c1ccccc1OCCCCCCn1c2ccc(OC)cc2c2c(C)ccc(C)c21',
#  'COc1ccc(-n2nccn2)c(C(=O)N2CCC3CN(c4cc(C(F)(F)F)ccn4)C3C2)c1',
#  'CC(=O)c1c(O)c(C(C)=Nc2ccc(O)c(NS(C)(=O)=O)c2)c(O)oc1=O',
#  'CN1CCc2c(cc(O)c(O)c2F)C(c2ccc(O)cc2)C1',
#  'N=C(N[N+](=O)[O-])N1CCN(C(=O)OC2CCCC2)CC1',
#  'O=C(N=c1[nH]cnc2sc3c(c12)CCC3)c1ccco1',
#  'CC1=NN(c2ccc(Br)cc2Br)C(=O)C1=O',
#  'COc1ccc(CCN=c2[nH]c(C)nc3c2nnn3Cc2ccccc2)cc1',
#  'O=C1C(=Cc2ccc([N+](=O)[O-])cc2)Oc2cccc(OCC3CCCCC3)c21',
#  'Cn1nc(C(=O)Nc2ccc3c(c2)OCCO3)c2ccccc2c1=O',
#  'COc1cccc(-c2cc3c(=NC(C)c4ccccc4)[nH]cnc3o2)c1',
#  'CC(C=CCC(=O)N(C)C)N(C)C',
#  'NCC(=O)NC1(c2cc3ccccc3s2)CCCCC1',
#  'CCOCCCNCc1cn(-c2ccc(F)cc2F)nc1-c1ccccc1C',
#  'NC(=O)CCCCCCCCn1nc(-c2ccccc2)c(-c2ccccc2)c1-c1ccccc1',
#  'CCCCCc1nc2[nH]cnc2c2nc(-c3ccccc3)nn12',
#  'O=C(CCCCl)Oc1ccc2cc(-c3ccc4ccccc4n3)c(=O)oc2c1',
#  'Cc1ccc(C)c(NC(=O)CSc2ncnc3[nH]cnc23)c1',
#  'CSc1ccccc1OCc1cc(C(=O)NC2CCCCNC2=O)no1',
#  'NC(CCC(=O)NC(CSC(C(=O)O)c1ccccc1)C(=O)NCC(=O)O)C(=O)O',
#  'CC(NC(=O)c1ccnn1C)c1ccc(OCC2CC2)c(F)c1',
#  'CN1CCN(C(=O)c2cc3cc(N=c4nc(-c5cc(OCc6ccccc6CO)ccn5)cc[nH]4)ccc3[nH]2)CC1',
#  'O=C(NC(Cc1ccccc1)C(=O)NC1CCCCC1)c1ccc(O)c(-c2cccc(C(F)(F)F)c2)c1',
#  'CNS(=O)(=O)c1ccc(C(=O)NCCc2ccccn2)cc1',
#  'CCSC1SC(c2ccccc2)(c2ccccc2)c2ccccc21',
#  'CCOc1ccc(CCNC(=O)CN2CCN(Cc3ccccc3C)C2=O)cc1OCC',
#  'CC(C)c1c(C(=O)NCc2cccc(C#N)c2)nn(-c2ccc(F)cc2)c1CCC(O)CC(O)CC(=O)O',
#  'COc1ccc(NC2CCCN(C(=O)c3cccc(N4CCNC4=O)c3)C2)cc1',
#  'COc1ccc(C2N=C(N=c3[nH]c4ccccc4o3)N=C3CCCC(=O)C32)cc1',
#  'O=C(OCCN1CCN(c2cccc(Cl)c2)CC1)c1ccccc1N=c1cc[nH]c2c(C(F)(F)F)cccc12',
#  'NCCCC1NC(CNC(=O)c2ccc3ccccc3c2)CCN(Cc2cc(Cl)ccc2Cl)C1=O',
#  'CC(c1ccccc1)N1CCn2c(nc3cc(NC(=O)NC4CCCCC4)ccc32)C1',
#  'CC(C(=O)NCCC(c1ccc(F)cc1)c1ccc(F)cc1)c1ccc(NS(C)(=O)=O)c(F)c1',
#  'Cc1nn(C)c(C)c1NS(=O)(=O)c1ccc(=NCCCN2CCN(C)CC2)[nH]c1',
#  'CC(CC(O)N1CCCC(Cc2ccc(F)cc2)C1)NC(=O)Nc1cc(-c2nnnn2C)cc(C(C)C)c1',
#  'O=C(O)c1cc(S(=O)(=O)NCCN2CCNC2=O)ccc1O',
#  'Nc1cccc(N=c2[nH]cnc3c2ncn3CC2CC2)c1',
#  'CC(N)c1cccc(N2CCc3ccccc32)c1',
#  'COc1cccc(N2CCN(c3nc(-c4cc(C(=N)N)sc4SC)cs3)CC2)c1',
#  'COc1cc2c(-c3ccccc3Cl)nc3c(c(C)nn3-c3ccccc3)c2cc1OC',
#  'COc1ccc(C2CC(=O)C(=NO)C2c2cc(OC)c(OC)c(OC)c2)cc1Cl',
#  'NCCCCC(NC(=O)C(Cc1ccccc1)NC(=O)C(Cc1ccc2ccccc2c1)NC(=O)c1cc(CN)cs1)C(N)=O',
#  'COc1cc(Br)cc2cc(-c3cn4ccsc4n3)c(=O)oc12',
#  'COCCCN=c1[nH]nc(Cc2ccc(Cl)cc2)c(=O)[nH]1',
#  'C=CCNC(=S)N=CC(C(=O)OCC)C(=O)C(=O)OCC',
#  'O=c1[nH]c(=S)[nH]c2cc(-c3ccc(F)cc3)nn12',
#  'COc1cc(OC)cc(C(=O)NC2CCN(CCCOc3ccccc3)CC2)c1',
#  'CC(C)CCCC(C)C1CCC2=C(CC(=O)Nc3cccc(O)c3)CCCC21C',
#  'CCc1nn(C)c(Cl)c1CN1CCCC2(C1)CN(C)C(=O)O2',
#  'Cn1cc(C(=O)Nc2ccc(Oc3ccc4nc(NC(=O)C5CC5)cn4n3)c(F)c2)c(=O)n1-c1ccccc1',
#  'CC(C)c1nc(CN(C)NC(C(=O)NC(Cc2ccccc2)CC(O)C(Cc2ccccc2)NC(=O)OC2CCOC2)C(C)C)cs1',
#  'CCCn1cnnc1CNC1CSCCSC1',
#  'Cc1nnc(CO)n1-c1ccc(Cl)cc1C(N)c1ccccc1Cl',
#  'Cc1cccc2cc(CN(Cc3nnnn3C3CCCCC3)C3CCCC3)c3nnnn3c12',
#  'O=C1CSC(c2ccccc2Cl)N1c1nc(C23CC4CC(CC(C4)C2)C3)cs1',
#  'CCN(CC)C(=O)N(CC)Cc1cc(N=c2cc[nH]c3cc(Cl)ccc23)ccc1OC',
#  'O=C(CCC1CCCCC1)NCCN1C2=NCC(Cc3ccc(O)cc3)N2CC1Cc1ccc(O)cc1',
#  'CCCN(CCC)S(=O)(=O)c1ccc(C(=O)N=c2[nH]c3ccc(-c4cc(=O)[nH]c(=Nc5ccccc5Cl)[nH]4)cc3[nH]2)cc1',
#  'CCc1c(C)sc2nc(SCC(=O)N=c3cc(C)o[nH]3)n(CCOC)c(=O)c12',
#  'CCOC(=O)C1C(c2ccc(-c3cccn3CC)cc2)CC2CCC1N2C',
#  'O=C(c1ccc2ncsc2c1)N1CCC(N2C(=O)OCc3ccccc32)CC1',
#  'N=c1[nH]cc(-c2ncccc2C(F)(F)F)nc1C(=O)N=c1[nH]cccc1N1CCC(N)(CCO)CC1',
#  'CCCCC(NC(=O)NC(Cc1ccccc1)C(=O)Nc1ccc([N+](=O)[O-])cc1)C(=O)NC(CCCCN)C(=O)OC',
#  'N#Cc1ccc(-c2ccc(OCCCCC(O)=NO)cc2)cc1',
#  'COc1ccccc1-c1c(SCCN(C)C)nc2ccccc2c1C',
#  'COc1cc(F)cc2c1nnc1c(C)nc(-c3cccc(F)c3C)n12',
#  'O=C(Nc1ccccc1Br)c1ccccc1-c1ccccc1',
#  'O=C(O)c1nc2n(c1C(=O)N1CCOCC1)-c1ccccc1OC2',
#  'Cc1nc(-c2ccc(F)cc2)c(C(=O)N2CCCN(c3cc(Cl)cc(Cl)c3)CC2)o1',
#  'CCN1c2ncccc2C(=O)Nc2c(C)cc(N(C)CCO)nc21',
#  'Cc1ccc2cc(CN(CCN3CCCC3)C(=O)Nc3ccc(F)cc3)c(=O)[nH]c2c1C',
#  'CCN(CC)CCn1c2c(c(SCC(=O)N=c3[nH]ccs3)nc1=O)CCCC2',
#  'N=c1[nH]cc(Cc2ccccc2Br)c(=N)[nH]1',
#  'CC(C)N=c1cc(-n2ccc3cc(CNC(=O)CC4CCCC4)cnc32)[nH]cc1C(=O)NCC(F)C(C)(C)O',
#  'Cc1[nH]oc(=NS(=O)(=O)c2ccccc2-c2cc3ccccc3[nH]2)c1C',
#  'C#Cc1cn2c(-c3ccc(C(=O)NC4(C#N)CC4)c(C)c3)cnc2c(=NCCC(F)(F)F)[nH]1',
#  'CCCC(=O)Nc1ccccc1NC(=O)CN(C)S(=O)(=O)c1ccc(C)cc1',
#  'CCC(C)NC(=O)COC(=O)c1ccc(Cl)cc1O',
#  'COc1ccccc1N1CCN(C(=O)c2cccc(Oc3ccccc3)c2)CC1',
#  'O=C1C(=NCCc2ccccc2)C(Cl)C(=O)c2ccccc21',
#  'CC1COCCN1c1nc(N2CCOCC2C)c2ccc(-c3ccc(CNCC(N)=O)o3)nc2n1',
#  'NC(CS)C(=O)Nc1ccc(NC(=O)Cc2cccc(Cl)c2Cl)c(C(=O)c2ccccc2)c1',
#  'CCOc1ccc2[nH]c(SCc3ccccn3)nc2c1',
#  'O=c1c2cc(NC(=S)NC3CC3)ccc2nc2n1CCCCC2',
#  'O=C(C1CCC2C(CCN2C2CCCC2)O1)N1CCOCC1',
#  'COC(CN(C)Cc1coc(-c2ccc(Cl)cc2Cl)n1)OC',
#  'Cn1nccc1CNS(=O)(=O)c1cc(F)ccc1Br',
#  'O=C1C(=Cc2ccccc2Cl)c2ccccc2N1c1c(Cl)cccc1Cl',
#  'Cc1cc(OCc2cnc(Cl)s2)nc(C(C)C)n1',
#  'Cc1cc(Oc2ccccc2)nc(N2CCOCC2)n1',
#  'CCC(C)C(=O)c1c(O)c(C)c2oc3c(C)c(O)c(C(=O)CC(C)C)c(O)c3c2c1O',
#  'COC(=O)CC1CC2c3cc(NC(=O)c4cccnc4)ccc3OC2C(CO)O1',
#  'O=C(NCC(c1cnc(C2CC2)nc1)N1CCC(F)(F)CC1)c1cccc(Cl)c1Cl',
#  'CNC1CCN(c2nc3c(c(C)c2F)c(=O)c(C(=O)O)cn3-c2ccc(F)cc2F)C1',
#  'Cc1cccc(Cn2c(=NCC(C)O)[nH]c3c2c(=O)n(C)c(=O)n3C)c1',
#  'N#Cc1ccc(N=c2[nH]cc(Cc3c(F)cc(F)cc3F)o2)cc1Cl',
#  'O=C(c1ccc(-c2cnc3c(c2)N(Cc2ccccc2)CCN3)cc1)N1CCCC1CN1CCCC1',
#  'CN(C)c1ccc(N=C2C(=O)N(C)c3cccc4c(O)c5ccccc5c2c34)cc1',
#  'COc1ccc(F)cc1NC(=O)NCC1(CN2CCOCC2)CC1',
#  'ON(Cc1ccc(OC(F)(F)F)cc1)c1ccccn1',
#  'CCN(CC)c1ccc2c(C(F)(F)F)cc(=O)[nH]c2c1',
#  'CN1Cc2ccccc2CC2(CCN(c3ncc(F)cn3)CC2)C1=O',
#  'CCC(=C(CC)c1ccc(C(C)=O)c(C(C)=O)c1)c1ccc(C(C)=O)c(C(C)=O)c1',
#  'COCCn1c(SCC(=O)c2c[nH]c3ccccc23)nnc1-c1ccncc1',
#  'CCN(CC1NC(CC)(C(=O)OC)c2c1c(O)n(C)c2O)S(=O)(=O)c1ccc(-c2ccccc2)cc1',
#  'Cc1cc(=NCCO)c2ccccc2[nH]1',
#  'CCCCCCNC(=O)Nc1ccc(S(=O)(=O)Nc2ccc3cc(CC4NCCc5cc(O)c(O)cc54)ccc3c2)cc1',
#  'CC1CCc2cc(F)ccc2N1C(=O)C1(C)CC1(Cl)Cl',
#  'CCN(CC)S(=O)(=O)c1ccc(N=Nc2c(C)[nH]n(C(N)=S)c2=O)cc1',
#  'CC(Cl)C(=O)NNC(=O)CNS(=O)(=O)c1ccccc1',
#  'COc1ccc(N=c2[nH]cc(C(C)(C)O)cc2-c2nc(=N)nc(C)[nH]2)cn1',
#  'CCN(CC)S(=O)(=O)c1ccc2[nH]c(=N)[nH]c(=N)c2c1Cl',
#  'NN=c1nc2c(n[nH]1)n(-c1ccc(Cl)cc1)c(=O)n2-c1ccc(Cl)cc1',
#  'CCOC(=O)c1cc(-c2cccs2)nc2onc(C)c12',
#  'COc1ccc(NC(=O)CSc2nc(-c3ccc(F)cc3)c3cccc(C)c3n2)cc1',
#  'CC(NC(=O)COc1ccc(N(C)S(=O)(=O)c2ccccc2)cc1)c1ccccc1',
#  'Oc1c2c(c(O)n1-c1ccccc1)C13C(=CC2c2c1c(O)n(-c1ccccc1)c2O)c1ccccc1N3c1ccccc1',
#  'O=C(Cc1cccc(Oc2cccnc2)c1)N1CCNc2nc(C(F)(F)F)ccc2C1',
#  'CS(=O)(=O)c1ccc(-c2cncn2-c2ccccc2F)cc1',
#  'CCOC(=O)c1c(Nc2ccccc2)c(O)n(C2CCCCC2)c1C',
#  'CC(C)CCOc1ccc(C=C2CCn3c2nc2cc(C(=O)O)ccc2c3=O)cc1',
#  'COCC(NC(=O)N=c1cc2[nH][nH]c(=Nc3ccccc3)c2c[nH]1)c1ccccc1',
#  'Cn1c(=O)c(=O)n(C)c2cc(S(=O)(=O)CCC(=O)Nc3c(F)c(F)c(F)c(F)c3F)ccc21',
#  'CCCCCCNC(=O)OC1C(N)CC(N)C(OC2CCC(N)C(CN)O2)C1OC(=O)NCCCCCC',
#  'CC1CCN(c2nc(C(F)(F)F)ccc2CNC(=O)NCc2ccc(NS(C)(=O)=O)c(F)c2)CC1',
#  'CN(C)c1ccc(C(=O)OCC2(CO)CC(=CC3CCCCC3)C(=O)O2)cc1',
#  'CCc1cn(CCN)c(CC)c1Oc1ccc(C#N)cc1',
#  'COC(=O)c1c(NC(=O)CN2C(=O)C(=O)N(C(C)C)C2=O)sc(C)c1C',
#  'COc1cc2[nH]c(=O)n(C3CCCCC3)c(=O)c2cc1OC',
#  'Cc1noc(C)c1-c1ccc2[nH]cnc(=NCc3ccoc3)c2c1',
#  'N=c1c(C(=O)O)c[nH]n1-c1ccc(CC(C(=O)c2ccc(F)cc2)c2ccc(F)cc2)cc1',
#  'COc1ccccc1N1CCN(C(=O)COc2ccc(-c3cc4c([nH]3)c(=O)n(C)c(=O)n4C)cc2)CC1',
#  'Cc1ccc(C(=O)N2CCc3c(CNS(C)(=O)=O)cncc3C2)o1',
#  'CC(C)NCC(O)CCN1c2ccccc2N(c2ccccc2)S1(=O)=O',
#  'Cn1cnc2cc(-c3ccc(N4CCOCC4)cc3)[nH]c(=NCC3CCC(C)(O)C3)c2c1=O',
#  'N=C(NC(=O)OCc1ccccc1)c1ccc(-c2ccc(-c3ccc(C(=N)NC(=O)OCc4ccccc4)cc3)o2)cc1',
#  'O=C(O)c1cn(C2CC2)c2cc(N3CCN(C(=O)CN4CCN(c5cccc(O)c5)CC4)CC3)c(F)cc2c1=O',
#  'COc1ccc(OC)c2c1CCN1C(=O)c3ccccc3C21O',
#  'CN(CCOc1ccc(CC(Nc2ccccc2C(=O)c2cccc(OCc3ccccc3)c2)C(=O)O)cc1)c1nc2ccccc2o1',
#  'CCCCCCCCCCC#Cc1cc2cn(C3CC(O)C(CO)O3)c(=O)nc2o1',
#  'COc1ccc(O)c(C(=O)NC2CCN3C(C)CCCC3C2)c1',
#  'O=c1[nH]cnc2c1ccn2C1C=C(CO)C(O)C1O',
#  'CC(C)CNCC(O)COc1cccc2ccccc12',
#  'CC(N)C(=O)NC1C(C)OC(=O)C2C(=O)CC(O)C(O)C21',
#  'CC(C)=NN=c1[nH]c2ccccc2[nH]c1=O',
#  'CNS(=O)(=O)c1ccc(-c2c[nH]c(=N)c(-c3ccc(OC)nc3)c2)cc1',
#  'CC1(C)c2cc(OCCCCCC(=O)O)ccc2C(=O)c2c1oc1ccccc21',
#  'COc1ccc(C2C3CCC(CC3)C2CN)cc1',
#  'CC1=CCCC1NC(=O)Nc1ccc(Cl)c(S(=O)(=O)C2CC3(COC3)C2)c1O',
#  'CCOC(=O)c1c(C)[nH]n(Cc2ccccc2)c1=N',
#  'O=c1cc(O)n(CC2CCCO2)c(=O)n1CCc1cccc(Cl)c1',
#  'CSc1ccc2c(c1)Nc1ccccc1S2',
#  'COc1ccc(C2=NOC(c3cc(OC)c(OC)c(OC)c3)C2)cc1O',
#  'O=C(NCCCN1CCOCC1)c1ccc2ccccc2c1',
#  'CCC1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(Cl)c4c(cc3nc2-1)OCO4',
#  'CCNCC1=C(C(F)(F)F)OC2OC3(C)CCC4C(C)CCC1C24OO3',
#  'CC(O)Nc1cc(Cl)ccc1C=NN=C(N)NN=Cc1ccc(Cl)cc1NC(C)O',
#  'CCCC(=O)N=c1[nH]c2ccc(NC(=O)CSc3ccc(Cl)cc3)cc2s1',
#  'COc1ccc2ccc(S(=O)(=O)NC(CCCN=C(N)N)C(=O)N3CCCCCC3C(=O)O)cc2c1',
#  'NCC[S+]([O-])C(c1ccccc1)c1ccccc1',
#  'Cc1ccccc1SCC(=O)NNC(=O)c1ccncc1',
#  'Cc1ccccc1NC1=CC(=O)C(Nc2ccccc2C)=CC1=O',
#  'Cc1cccc(-c2cccc(C(=O)N3CCc4c([nH]c5ccccc45)C3)c2)c1',
#  'CON=C1c2cc(OC)ccc2-c2cnc3ccccc3c21',
#  'CCC(O)c1nc2ccccc2n1Cc1cc(C)ccc1C',
#  'CN=C(NC#N)N1CCOC(COc2cc3[nH]cnc(=Nc4ccc(Cl)c(C)c4)c3cc2OC)C1',
#  'CC(C)=C(C(=O)OCc1ccccc1)N1C(=O)C(NC(c2ccccc2)(c2ccccc2)c2ccccc2)C1[S+]([O-])CC(=O)OC(C)(C)C',
#  'c1ccc(OCCn2ccnc2)cc1',
#  'COCCNC(=O)c1cccc(OC2CCN(Cc3ccc(F)c(OC)c3)CC2)c1',
#  'CC(C)=CCCC(C)=CC1OC(=O)CC12CC(OC(=O)c1cccc(Br)c1)=CCC2=O',
#  'O=S(=O)(c1ccc2c(c1)OCCO2)N1CCc2ccccc21',
#  'COc1cc2c(cc1OCc1ccccc1)C(c1ccccc1)=NCC2',
#  'COc1ccc(C(c2nnnn2C2CCCCC2)N2CCC3(CC2)C(=O)NCN3c2ccccc2)cc1',
#  'CCCCn1c(=O)c2ccc(=NC)[nH]c2n1Cc1ccc(-c2ccccc2-c2nn[nH]n2)cc1',
#  'CC(C)(C)CC(C)(C)Nc1c(-c2ccccc2OC(=O)c2cccc(C(F)(F)F)c2)nc2ccccn12',
#  'CC(NO)c1c[nH]c2ccc(Br)cc12',
#  'CC(=O)C1CCC2C3C(O)CC4CC(=O)CCC4(C)C3C(OC(=O)c3ccccc3)CC12C',
#  'COc1cc(CN2CCOC(COc3cccc(F)n3)C2)ccc1Cl',
#  'COc1ccc(Cl)cc1NC(=O)N1CCN(c2ncccc2C(F)(F)F)CC1C',
#  'CC(C)(O)C#Cc1c(C=O)[nH]c2ccccc12',
#  'COC(=O)c1ccccc1-c1ccc(C=C2SC(=S)N(Cc3ccccc3)C2=O)o1',
#  'COc1ncc(-c2nc3c(n2C(C)C)C(c2ccc(Cl)cc2)N(c2cc(C)nn2C)C3=O)c(OC)n1',
#  'CC(C)(C)c1ccc(S(=O)(=O)NCCN2CCOCC2)cc1',
#  'CN(C)c1nnc(-c2cccc(-c3ccccc3)c2)n1-c1cccc(O)c1',
#  'COc1ccc(-c2sc3c(c2CN(C)Cc2ccccc2)c(=O)n(-c2ccccc2OC)c(=O)n3Cc2c(F)cccc2F)cc1',
#  'O=C(C1CC1)N1CC(c2ccc(O)cc2)Cc2ccc(O)cc21',
#  'COc1ccc2nccc(C(O)CN3CCC(NCc4ccc5c(c4)N(C)C(=O)CO5)CC3)c2c1',
#  'CNC(=O)C1CC2CN(C(=O)c3cnc(C)cn3)CC2N1C',
#  'CC(CCC(=O)O)C(=O)N1c2ccccc2CC1C(=O)O',
#  'Cc1ccc(C(=O)N2N=C(CC(C)C)CC2(O)C(F)(F)F)o1',
#  'CN1C(N)=NC2(c3cc(NC(=O)c4ccc(C(F)(F)F)cn4)ccc3F)COCC2S1(=O)=O',
#  'CC(NC(=O)c1nn(-c2ccc(Cl)c(Cl)c2)c2c1CN(C(=O)Cn1cnnn1)CC2=Cc1ccc(F)cc1)c1ccccn1',
#  'OC1(c2ncc(-c3cc(N=c4nc(C(F)(F)F)cc[nH]4)cc(-c4nn[nH]n4)c3)s2)CCC1',
#  'Cc1ccc(OCC2CN(CCN3CCc4ccccc43)CCO2)cn1',
#  'O=C1c2ccccc2-c2c1c1ccccc1c(=O)n2Cc1ccco1',
#  'Cn1c(=O)[nH]c2c(Oc3ccc(NC(=O)Nc4ccc(Cl)c(C(F)(F)F)c4)c4ccccc34)ccnc21',
#  'Cc1ccccc1Nc1cc(N=NC(=N)SCc2ccccc2)c(=O)[nH]c1Nc1ccccc1C',
#  'N=C1COCC(c2cc(NC(=O)c3cc4cncnc4[nH]3)ccc2F)(C(F)F)N1',
#  'CC(C)NC1(C(N)=O)CCN(Cc2ccccc2)CC1',
#  'CC1CN(C(C)CO)C(=O)c2cccc(NC(=O)c3ccncc3)c2OC1CN(C)Cc1ccccc1C(F)(F)F',
#  'CN(C)CCC1CCN(C(=O)C(Cc2nc3ccccc3s2)NS(=O)(=O)c2cccc3c2NCC(C)(C)C3)CC1',
#  'COC(=O)C=Cc1ccc2c(c1)N(Cc1ccc(OC)cc1)C(=O)C2=O',
#  'CCN(CC)CC1(c2ccc(N3CCc4c(C(F)(F)F)nn(-c5ccc(OC)cc5)c4C3=O)cc2)CC1',
#  'O=C(CC1C(=O)NCCN1Cc1cccc(Oc2ccccc2)c1)NCCc1ccccn1',
#  'CC(=O)Oc1ccccc1C(=O)OCOC(=O)c1cccc(OCCCO[N+](=O)[O-])c1',
#  'Cc1cc(=O)c(-c2ccc(Oc3ccc(OC(F)(F)F)cc3)cc2)c(C)[nH]1',
#  'CCC(C)C(N)C(=O)NC(C(=O)O)C(C)C',
#  'CCNc1ccccc1-c1ccccc1NC(=O)Cc1ccc(O)cc1',
#  'N=c1[nH]c2c(c(=O)[nH]1)-c1cc(Br)c(N)cc1CC2',
#  'CN(C)C(=O)C(CCCCN)NC(=O)C(Cc1ccccc1)N(C)C(=O)C(Cc1ccc2ccccc2c1)N(C)C(=O)C=CCC(C)(C)N',
#  'O=[N+]([O-])c1ccccc1S(=O)(=O)Nc1ccc2c(c1)ncn2Cc1ccccc1',
#  'CCOC(=O)C(C)Oc1ccc(N(C)c2cc3ccc(Cl)cc3cn2)cc1',
#  'Cn1c(OC2CCCCC2)nc(-c2ccncn2)cc1=O',
#  'N=c1c(C(=O)NC2CCCCC2)cc2c(=O)n3ccccc3nc2n1CC1CCCO1',
#  'CCC(N=c1[nH]nnn1-c1ccccc1)C(=O)NCc1ccsc1',
#  'COc1ncc(-c2nc3c(n2C(C)C)C(c2ccc(Cl)cc2F)N(c2cc(Cl)cn(C)c2=O)C3=O)c(OC)n1',
#  'O=[N+]([O-])c1ccc(S)cc1',
#  'Cc1noc(C)c1CSCC(=O)OCC(=O)N1CC(=O)Nc2ccccc21',
#  'O=C(C=Cc1ccc(-c2ccc(F)cc2)o1)N1CCCC1',
#  'Cc1ccc(C)c(Cn2c(=O)n(Cc3ccc4c(c3)OCO4)c(=O)c3oc4ccccc4c32)c1',
#  'c1cc(-c2ccncc2)c2nc(=Nc3ccc(N4CCOCC4)cc3)[nH]n2c1',
#  'Cc1cn(C2CC(N=[N+]=[N-])C(CO)O2)c(=O)n(CC2COC(C)(C)O2)c1=O',
#  'CCN(CC)Cc1ccc2c(c1)CCC(N1CCN(CCC3CCCS3)CC1=O)C2',
#  'CN(CCn1nnc2c(C(N)=O)ncn2c1=O)c1ccc([N+](=O)[O-])cc1',
#  'CN(C)c1cccc2c(S(=O)(=O)NCCNC(=O)CCCCCN3CC(O)C(O)C(O)C3CO)cccc12',
#  'CSc1nnc2n(Cc3ccccc3)c(=O)c3c4c(sc3n12)COC(C(C)C)C4',
#  'CCCCC=CCCCCCCCCNC(=O)Cc1ccc(O)c(OC)c1',
#  'O=C(CSC(=S)NC1CCOC1=O)Nc1ccc(C(=O)C=Cc2ccccc2)cc1',
#  'CCOC(=O)c1sc(N(Cc2cncn2Cc2ccc(C#N)cc2)Cc2cncn2Cc2ccc(C#N)cc2)c(C#N)c1-c1ccc(Cl)cc1',
#  'O=[N+]([O-])c1ccc2[nH]c(SCCN3CCC(Cc4ccccc4)CC3)nc2c1',
#  'N#Cc1c(Cl)cccc1OCC(O)CN1CCCC(Cc2ccccc2)C1',
#  'Cc1noc(C)c1CN(C)C(=O)NCCOc1ccc(F)cc1F',
#  'CCOC(=O)CS(=O)(=O)c1ncc(Cl)cc1Cl',
#  'CC1CCCCC1NC(=O)CN1C(=O)NC(Cc2ccccc2)(Cc2ccccc2)C1=O',
#  'Nc1cc(C=C2COc3ccccc3C2=O)ccc1O',
#  'COc1ccc(S(=O)(=O)N(C)CC(=O)NC2CCCCC2)cc1Cl',
#  'CCCCCC(Cc1ccc(C(=O)NCCC(=O)O)cc1)C(=O)c1cc2cc(C(F)(F)F)ccc2n1-c1cccc(C(F)(F)F)c1',
#  'N=c1[nH]c(F)nc2c1ncn2C1CCC(CO)C1',
#  'CCN(CC)CCCOC(=O)C(O)(c1ccccc1)C1CCCCC1',
#  'CCC(=O)C(CCCCCCOc1ccc(C(C)=O)cc1OC)C(=O)CC',
#  'COc1ccccc1NC(=S)NC(=O)c1cn(CCO)c2c(cc(O)c3ncccc32)c1=O',
#  'CCN1CCCC1CNC(=O)c1c(Br)c(OC)cc(O)c1OC',
#  'O=C(NNC(=O)c1ccc(Br)cc1)c1ccncc1',
#  'O=C1COc2c(cccc2C2CCN(CC(O)COc3ccccc3C(=O)c3ccccc3)CC2)N1',
#  'COC(=O)C1=C(c2ccccc2OCc2ccccc2)CC2CCC1N2C(=O)NCCCOC(C)C',
#  'Cc1cc(C)cc(S(=O)(=O)c2c(C(N)=O)[nH]c3cc(Cl)ccc23)c1',
#  'CN(C)c1nc(-c2sc(=NC(=O)c3ccco3)[nH]c2-c2ccccc2)[nH]c(=N)n1',
#  'CCOC(=O)C1=NN(c2ccc(Cl)cc2)C2=CC(C)=NN(C)C(=S)N21',
#  'COc1ccccc1-n1c(CCC(=O)O)ccc1-c1ccccc1',
#  'O=C1CCCCN1CC(=O)N1CCCC(Nc2ccc(F)cc2)C1',
#  'CCn1ncc2c(N3CC4CCC(C3)O4)nc(-c3ccc(NC(=O)Nc4ccc(CCO)cc4)cc3)nc21',
#  'Cc1ccc(CCNC(=O)CN(C)S(=O)(=O)c2ccc3c(c2)c(=O)n(C)c(=O)n3C)cc1',
#  'CCCCCCCCCCCCCCC(CNCCCCCC)NC(=O)OC(C)(C)C',
#  'CC(C)(O)c1cnc(-c2nn(-c3ccc(F)cc3)cc2Sc2ccc(Cl)cc2)cn1',
#  'CSCc1cccc(S(=O)(=O)N2CCCC2)c1',
#  'O=C(O)C(=O)CC(=O)c1cn(Cc2ccc(F)cc2)cc1-c1ccccc1',
#  'CC(C)N(C(=O)C1CCC2C3CC=C4N(C)C(=O)CCC4(C)C3CCC12C)C(C)C',
#  'Cc1cc2cccnc2c2ncccc12',
#  'CC1=NNC(=O)CC1c1ccc(OC2CCN(C3CCC3)CC2)cc1',
#  'CC1CCc2[nH]c3ccc(C(=O)O)cc3c2C1',
#  'COCC(N=c1[nH]cnc2c(C(N)=O)cccc12)c1cccc(NC(=O)c2ccc(OC)cc2)c1',
#  'Cc1cc(C)cc(CC(=O)N2CCC2(C)C(=O)NCc2ccc(Cl)cc2)c1',
#  'COCc1cc(N2CCN(S(=O)(=O)NC3(C(=O)O)C(C)C3c3ccccc3)CC2C)no1',
#  'c1ccc(-c2nc(-c3ccccc3)n(-c3ccccc3)n2)cc1',
#  'CCCCCCCCCCCC(=O)c1ncc(CCCCSCCC[N+](C)(C)C)o1',
#  'Cc1ccc(-n2nc(C)c3c(C)c(CCC(=O)Nc4ccc5[nH]c(-c6cccnc6)nc5c4)c(C)nc32)cc1C',
#  'CC=C1C=CC2=NCCC(=O)C12',
#  'N=C1Sc2cc(-c3ccc(C(F)(F)F)cc3)ccc2C2=NCCCN12',
#  'COc1ccc2cc(CCC(C)OC(C)=O)ccc2c1',
#  'O=c1nc(-c2ccccc2)[nH]c(-c2ccccc2)n1',
#  'COc1ccc(COCC(O)CN2CCC(C(N)=O)CC2)cc1',
#  'COCCCOc1cc2[nH]c(N3CCCC3)nc(=NCCCCCN3CCCC3)c2cc1OC',
#  'N#Cc1ccc2nc(N3CCNCC3)cnc2c1',
#  'Cc1ccc(CC(=NC(=O)c2ccc(C)cc2)c2n[nH]c(=S)[nH]2)cc1',
#  'COc1ccccc1C(=O)c1ccc2nc(N)c(C(=O)c3c(F)cccc3F)n2c1',
#  'NS(=O)(=O)c1n[nH]c(=NC(=O)CNCC2C(O)CC(O)C2CC=CCCCC(=O)O)s1',
#  'COc1ccc(SCC(=O)Nc2ccccc2Cl)cc1',
#  'Cc1cnc(Cl)nc1-c1ccc(N(Cc2ccc(CNC(=O)CC(F)(F)F)cc2)C(=O)c2ccc(O)cc2O)cc1',
#  'CCOCn1c(C(=O)c2cccc3ccccc23)c(CC)c(=O)[nH]c1=O',
#  'CCC(=O)N1CCC2(CC1)CN(Cc1cc(F)ccc1F)C(CO)c1[nH]c3cc(OC)ccc3c12',
#  'O=C(O)c1ccc(NC(O)c2cc(=O)n(Cc3ccc(Cl)cc3)c(=Nc3ccc(Cl)cc3)s2)cc1',
#  'Cc1cccc(N(CC(=O)NCCSc2ccc(Cl)cc2)S(=O)(=O)c2ccccc2)c1C',
#  'Cc1noc(C)c1CSc1ccccc1C(=O)N(C)CC(=O)Nc1cccc(F)c1',
#  'CCN(CC)CCNC(=O)c1cccc2[nH]ccc12',
#  'O=C(Nc1ccc(F)cc1F)c1ccccc1NC(=O)C1C=CCCC1C(=O)O',
#  'Cc1ccccc1S(=O)(=O)NC(CNC(=O)CC1CC(c2ccc(C(=N)N)cc2)N(C)O1)C(=O)O',
#  'N#CNC(=O)C(Cc1ccccc1)NC(O)c1ccc(O)[nH]1',
#  'Cc1nc(-c2ccc(C(=O)Nc3ccc(F)cc3)cc2)cs1',
#  'Cc1ccccc1CSc1ccc(-c2cccs2)nn1',
#  'O=C(CO)N1CC=C(c2cc3c(cc2F)N2C(=O)OC(Cn4ccnn4)C2CO3)CC1',
#  'NC(=O)c1n[nH]c(=NC2CCCCC2N)[nH]c1=Nc1cncc(C2CC2)c1',
#  'Cc1ccc(-n2nnc(CC(=O)N3CCN(C(C)C)CC3)c2C)cc1',
#  'COc1ccc2c(c1)c1c(n2C(=O)c2c(Cl)cc(Cl)cc2Cl)CCN(CCCOc2cc(F)cc(C3(OC)CCOCC3)c2)C1',
#  'Cc1[nH]n(C(N)=S)c(=O)c1N=Nc1c(C)n(C)n(-c2ccccc2)c1=O',
#  'O=C1C(=O)N(CCn2cc(CN3C(=O)C(=O)c4cc([N+](=O)[O-])ccc43)nn2)c2ccccc21',
#  'N=c1c2c(=O)[nH]c(C3CCNCC3)cc2[nH]n1-c1ccccc1',
#  'CN1C(=O)N(c2cccc(C(F)(F)F)c2)C2=C(C(=O)CC2)C1c1ccc(C#N)cc1C(=O)NCc1cocn1',
#  'CCCCNC(=O)C(Cc1ccccc1)NC(=O)c1ccc(O)c(-c2ccc(Cl)c(Cl)c2)c1',
#  'Cc1cccc(NC(=O)NC2N=C(c3cccc(OC(=O)NCCCC(=O)NCCCOc4cccc(CN5CCCCC5)c4)c3)c3ccccc3N(C)C2=O)c1',
#  'CC(C)(O)C1CCC(C)(C2C(O)C(O)C3(C)C4CCC5C(C)(C)C(OC6OCC(O)C(O)C6O)CCC56CC46CC(O)C23CO)O1',
#  'COc1ccc2c(c1)CCN1OC3(CC21)C(=O)OC1OC2(C)CCC4C(C)CCC3C14OO2',
#  'NC(=O)c1nc(C#CC2(O)CCCC2)n(COCCO)n1',
#  'Cn1c(N)c(C(=O)CSc2nnc(Cc3cccs3)n2C2CC2)c(=O)n(C)c1=O',
#  'COc1ccccc1N1CCN(CCN2C(=O)CC3(CCCC3)CC2=O)CC1',
#  'Cc1[nH]c(=O)[nH]c(=S)c1C(=O)NC(C)(CO)CO',
#  'CCC(NC(=O)N1CC(=O)NCC(Cc2cc(Cl)ccc2OC)C1=O)c1cc(C(=O)O)cs1',
#  'CC(C)C1CSSC1',
#  'CCC(C)C(NCc1ccccc1)C(OCc1ccccc1)C1COC(C)(C)O1',
#  'CS(=O)(=O)On1c(O)cc(Cc2ccccc2)c1O',
#  'CCN1CCN(CC#CC(=O)Nc2ccc3[nH]cnc(=Nc4cccc(Br)c4)c3c2)CC1',
#  ...]
